# %% [markdown]
# # Cosine Similarity Matrix of Words for pos & neg regarding creativity

# %%
from nltk.corpus import stopwords
import gensim
from gensim.parsing.preprocessing import remove_stopwords
import pandas as pd
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize
import numpy as np
import scipy

# %%
creativity_dict = ['creative', 'new', 'novel', 'interesting', 'genius', 
                   'imaginative', 'ingenious','innovative', 'inventive']

# %%
# # Stemming
# ps = PorterStemmer() 
  
# for w in creativity_dict: 
#     print(w, " : ", ps.stem(w))

# %%
# Lemmatization with gensim requires python 3,6!

# Lemmatization
lemmatizer = WordNetLemmatizer()

# print(lemmatizer.lemmatize('creatively'))

# %%
df_full = pd.read_csv('/Users/nessyliu/Desktop/RA/AllReviews_26thNov2019.csv')

# df = df_full.head(10000)
df = df_full

review_list = []
for review in df['review_text']:
    # tokenize review, lower case, remove accented, remove stopwords
    tokens = [lemmatizer.lemmatize(w) 
              for w in gensim.utils.simple_preprocess(remove_stopwords(review), deacc=True, min_len=3)]
    review_list.append(tokens)
print(len(review_list))
# Out:
# 1010251

# %%
model = gensim.models.Word2Vec(min_count=5, size=300, window = 5)

model.build_vocab(review_list)
model.intersect_word2vec_format("/Users/nessyliu/Desktop/RA/GoogleNews-vectors-negative300.bin", 
                                  binary=True, lockf=1.0)
model.train(review_list, total_examples=len(review_list), epochs=model.epochs)

print(len(list(model.wv.vocab)))
# Out:
# 21316

# %%
df_pos = pd.DataFrame()
for base_word in creativity_dict:
    top_similar_list = list(set(model.wv.most_similar(positive=[base_word], topn=100)))
    for pair in top_similar_list:
        df_pos.at[pair[0], base_word] = pair[1]

df_pos.loc[:,'Row_Mean'] = df_pos.mean(numeric_only=True, axis=1)
df_pos.loc[:,'Num_NaN'] = df_pos.isnull().sum(axis=1)
df_pos
# Out:
#                creative  new     novel  interesting    genius  imaginative  \
# tinkered       0.401562  NaN       NaN          NaN       NaN          NaN
# neat           0.402275  NaN  0.307337     0.471488  0.440187          NaN
# tweek          0.370045  NaN       NaN          NaN       NaN          NaN
# opportunity    0.365450  NaN       NaN          NaN       NaN          NaN
# challenging    0.354656  NaN       NaN          NaN       NaN          NaN
# ...                 ...  ...       ...          ...       ...          ...
# unpredictable       NaN  NaN       NaN          NaN       NaN          NaN
# grest               NaN  NaN       NaN          NaN       NaN          NaN
# inexspensive        NaN  NaN       NaN          NaN       NaN          NaN
# classy              NaN  NaN       NaN          NaN       NaN          NaN
# girard              NaN  NaN       NaN          NaN       NaN          NaN
#
#                ingenious  innovative  inventive  Row_Mean  Num_NaN
# tinkered             NaN         NaN        NaN  0.401562        8
# neat            0.504657         NaN        NaN  0.425189        4
# tweek                NaN         NaN        NaN  0.370045        8
# opportunity          NaN         NaN        NaN  0.365450        8
# challenging          NaN         NaN   0.406224  0.380440        7
# ...                  ...         ...        ...       ...      ...
# unpredictable        NaN         NaN   0.414377  0.414377        8
# grest                NaN         NaN   0.417058  0.417058        8
# inexspensive         NaN         NaN   0.395711  0.395711        8
# classy               NaN         NaN   0.422217  0.422217        8
# girard               NaN         NaN   0.403619  0.403619        8
#
# [635 rows x 11 columns]

# %%
# Drop the rows with high Num_NaN
df_pos_dropped = df_pos.copy()

# Get names of indexes to drop
indexNames = df_pos_dropped[df_pos_dropped['Num_NaN'] >= 6].index
 
# Delete these row indexes from dataFrame
df_pos_dropped.drop(indexNames , inplace=True)
df_pos_dropped = df_pos_dropped.sort_values(by =['Row_Mean'], ascending=False)
df_pos_dropped = df_pos_dropped.head(100)
extended_creativity_dict = list(set(list(df_pos_dropped.index)+creativity_dict))
df_pos_dropped
# Out:
#                  creative       new     novel  interesting    genius  \
# inventive        0.523200       NaN  0.348066          NaN  0.380742
# imaginative      0.411242       NaN  0.395319          NaN  0.394292
# clever           0.491569       NaN  0.411869     0.360856  0.571555
# ingenious        0.360706       NaN  0.412710          NaN  0.472336
# innovative       0.425377       NaN  0.345816          NaN  0.385818
# creativity       0.545321       NaN       NaN          NaN       NaN
# intricate             NaN       NaN       NaN          NaN  0.370379
# ingenuity             NaN       NaN       NaN          NaN  0.455595
# quirky                NaN       NaN  0.321381          NaN       NaN
# inspiring             NaN       NaN       NaN          NaN  0.406429
# brilliant             NaN       NaN  0.313528          NaN  0.613874
# intriguing            NaN       NaN  0.423304     0.571207  0.389464
# unorthodox       0.377786       NaN       NaN          NaN  0.385113
# uncomplicated         NaN       NaN       NaN          NaN       NaN
# creatively       0.381174       NaN       NaN          NaN       NaN
# crafty                NaN       NaN       NaN          NaN  0.416337
# unconventional        NaN       NaN  0.302997          NaN       NaN
# intuitive             NaN       NaN       NaN          NaN       NaN
# sophisticated         NaN       NaN       NaN     0.391143       NaN
# resourceful           NaN       NaN       NaN          NaN       NaN
# untraditional    0.370584       NaN       NaN          NaN       NaN
# neat             0.402275       NaN  0.307337     0.471488  0.440187
# experimentation  0.512402       NaN       NaN          NaN       NaN
# amusing               NaN       NaN  0.335860          NaN       NaN
# hilarious             NaN       NaN  0.349292          NaN       NaN
# bizarre               NaN       NaN  0.357764     0.451146  0.415309
# invent                NaN       NaN  0.365596          NaN  0.394626
# fascinating           NaN       NaN  0.404614     0.391700       NaN
# originality           NaN       NaN  0.366657          NaN       NaN
# teriffic              NaN       NaN       NaN          NaN  0.384774
# simplistic            NaN       NaN  0.309893          NaN       NaN
# intrigued             NaN       NaN  0.346948     0.436027  0.381026
# invented              NaN       NaN  0.304150          NaN  0.423586
# creative              NaN  0.213937       NaN          NaN       NaN
# invention             NaN       NaN  0.343586          NaN  0.367103
#
#                  imaginative  ingenious  innovative  inventive  Row_Mean  \
# inventive           0.741210   0.606477    0.649409        NaN  0.541517
# imaginative              NaN   0.582219    0.591492   0.741210  0.519296
# clever              0.513869   0.644944    0.501276   0.599966  0.511988
# ingenious           0.582219        NaN    0.528395   0.606477  0.493807
# innovative          0.591492   0.528395         NaN   0.649409  0.487718
# creativity          0.451726        NaN    0.417130   0.428902  0.460770
# intricate           0.513993   0.475568         NaN   0.478061  0.459500
# ingenuity           0.449900   0.488250    0.435454   0.440036  0.453847
# quirky              0.541590   0.419968         NaN   0.515763  0.449676
# inspiring           0.474658        NaN    0.438969   0.472810  0.448217
# brilliant           0.416284   0.514126    0.408017   0.416113  0.446990
# intriguing          0.454065   0.442271    0.385769   0.455537  0.445945
# unorthodox          0.482987   0.462172    0.433036   0.522849  0.443990
# uncomplicated       0.413480   0.400114    0.468020   0.489562  0.442794
# creatively          0.499967   0.344887    0.464035   0.520470  0.442106
# crafty              0.422443   0.460005         NaN   0.452750  0.437884
# unconventional      0.489322   0.399576    0.470506   0.511537  0.434788
# intuitive           0.427289   0.423579    0.467411   0.418429  0.434177
# sophisticated       0.486674   0.368599    0.434571   0.470707  0.430339
# resourceful         0.474374   0.386336    0.366691   0.491289  0.429673
# untraditional       0.457179   0.393118    0.432288   0.475380  0.425710
# neat                     NaN   0.504657         NaN        NaN  0.425189
# experimentation     0.423524   0.348630    0.403001        NaN  0.421889
# amusing             0.459259   0.424874         NaN   0.446883  0.416719
# hilarious           0.478616   0.389021         NaN   0.435767  0.413174
# bizarre                  NaN   0.421036         NaN        NaN  0.411314
# invent                   NaN   0.461008    0.385689   0.419255  0.405235
# fascinating         0.440412   0.380094         NaN        NaN  0.404205
# originality         0.457219   0.359836         NaN   0.431270  0.403745
# teriffic            0.402366        NaN    0.372808   0.404280  0.391057
# simplistic          0.421373   0.417124         NaN   0.409148  0.389385
# intrigued                NaN        NaN    0.389026        NaN  0.388257
# invented                 NaN   0.444540    0.377417        NaN  0.387423
# creative            0.411242   0.360706    0.425377   0.523200  0.386892
# invention                NaN   0.448710    0.382694        NaN  0.385523
#
#                  Num_NaN
# inventive              3
# imaginative            3
# clever                 1
# ingenious              3
# innovative             3
# creativity             5
# intricate              5
# ingenuity              4
# quirky                 5
# inspiring              5
# brilliant              3
# intriguing             2
# unorthodox             3
# uncomplicated          5
# creatively             4
# crafty                 5
# unconventional         4
# intuitive              5
# sophisticated          4
# resourceful            5
# untraditional          4
# neat                   4
# experimentation        5
# amusing                5
# hilarious              5
# bizarre                5
# invent                 4
# fascinating            5
# originality            5
# teriffic               5
# simplistic             5
# intrigued              5
# invented               5
# creative               4
# invention              5

# %%
uncreativity_dict = ['old', 'bore', 'worn', 'uninteresting', 'uninteresting','uninspired','boring','bland']

df_neg = pd.DataFrame()
for base_word in uncreativity_dict:
    top_similar_list = list(set(model.wv.most_similar(positive=[base_word], topn=100)))
    for pair in top_similar_list:
        df_neg.at[pair[0], base_word] = pair[1]

df_neg.loc[:,'Row_Mean'] = df_neg.mean(numeric_only=True, axis=1)
df_neg.loc[:,'Num_NaN'] = df_neg.isnull().sum(axis=1)
df_neg

# Drop the rows with high Num_NaN
df_neg_dropped = df_neg.copy()

# Get names of indexes to drop
indexNames_neg = df_neg_dropped[df_neg_dropped['Num_NaN'] >= 5].index
 
# Delete these row indexes from dataFrame
df_neg_dropped.drop(indexNames_neg, inplace=True)
df_neg_dropped = df_neg_dropped.sort_values(by =['Row_Mean'], ascending=False)
df_neg_dropped = df_neg_dropped.head(100)
extended_uncreativity_dict = list(set(list(df_neg_dropped.index)+uncreativity_dict))
df_neg_dropped
# Out:
#                  old      bore  worn  uninteresting  uninspired    boring  \
# uninspiring      NaN       NaN   NaN       0.635065    0.805005  0.429899
# unexciting       NaN       NaN   NaN       0.686163    0.654778  0.457475
# blah             NaN       NaN   NaN            NaN    0.418020  0.681188
# dull             NaN       NaN   NaN       0.560801    0.527137  0.660049
# unremarkable     NaN       NaN   NaN       0.635921    0.587140  0.420924
# unimpressive     NaN       NaN   NaN       0.602480    0.678542  0.348398
# unmemorable      NaN       NaN   NaN       0.620137    0.646331  0.346731
# disappointingly  NaN       NaN   NaN       0.641699    0.628573  0.338065
# forgettable      NaN       NaN   NaN       0.582091    0.639951  0.356318
# flavorless       NaN       NaN   NaN       0.491648    0.487514  0.539359
# lifeless         NaN       NaN   NaN       0.548430    0.569170  0.397065
# tasteless        NaN       NaN   NaN       0.517505    0.493752  0.536390
# flavourless      NaN       NaN   NaN       0.555308    0.524320  0.412685
# disappointing    NaN       NaN   NaN       0.513658    0.520042  0.504377
# tastless         NaN       NaN   NaN       0.526422    0.471202  0.472468
# meh              NaN       NaN   NaN       0.520380    0.479594  0.517690
# underwhelming    NaN       NaN   NaN       0.549180    0.645742  0.397601
# drab             NaN       NaN   NaN       0.514229    0.497033  0.418532
# boring           NaN       NaN   NaN       0.463543    0.420033       NaN
# unimpressed      NaN       NaN   NaN       0.478438    0.509197  0.404007
# monotonous       NaN       NaN   NaN       0.532504    0.477429  0.361334
# pointless        NaN       NaN   NaN       0.503191    0.411531  0.447602
# muddled          NaN       NaN   NaN       0.502208    0.474854  0.333327
# mediocre         NaN       NaN   NaN       0.465059    0.486525  0.346811
# exciting         NaN       NaN   NaN       0.440617         NaN  0.544656
# pathetic         NaN       NaN   NaN       0.477943    0.473974  0.337516
# lackluster       NaN       NaN   NaN       0.450839    0.598463  0.368142
# lame             NaN       NaN   NaN       0.457213    0.471439  0.342438
# enjoyable        NaN       NaN   NaN       0.466002    0.438149  0.355929
# devoid           NaN  0.289185   NaN       0.508307    0.461051       NaN
# memorable        NaN       NaN   NaN       0.455337    0.450589  0.345666
# unattractive     NaN       NaN   NaN       0.488090    0.426382  0.334665
# humdrum          NaN       NaN   NaN       0.472312    0.431264  0.344991
# stodgy           NaN       NaN   NaN       0.426574    0.408213  0.380669
# unappealing      NaN       NaN   NaN       0.437545    0.421111  0.355259
#
#                     bland  Row_Mean  Num_NaN
# uninspiring           NaN  0.623323        4
# unexciting            NaN  0.599472        4
# blah             0.660554  0.586587        4
# dull             0.503844  0.562958        3
# unremarkable          NaN  0.547995        4
# unimpressive          NaN  0.543140        4
# unmemorable           NaN  0.537733        4
# disappointingly       NaN  0.536112        4
# forgettable           NaN  0.526120        4
# flavorless       0.527805  0.511582        3
# lifeless              NaN  0.504888        4
# tasteless        0.463765  0.502853        3
# flavourless           NaN  0.497438        4
# disappointing    0.427997  0.491518        3
# tastless              NaN  0.490031        4
# meh              0.407761  0.481356        3
# underwhelming    0.323097  0.478905        3
# drab                  NaN  0.476598        4
# boring           0.516778  0.466784        4
# unimpressed           NaN  0.463881        4
# monotonous            NaN  0.457089        4
# pointless             NaN  0.454108        4
# muddled               NaN  0.436796        4
# mediocre              NaN  0.432798        4
# exciting         0.311349  0.432207        4
# pathetic              NaN  0.429811        4
# lackluster       0.298437  0.428971        3
# lame                  NaN  0.423697        4
# enjoyable             NaN  0.420027        4
# devoid                NaN  0.419515        4
# memorable             NaN  0.417197        4
# unattractive          NaN  0.416379        4
# humdrum               NaN  0.416189        4
# stodgy                NaN  0.405152        4
# unappealing           NaN  0.404638        4

# %%
print("Dict for creativity:")
print("\n(containing", len(extended_creativity_dict), "words)")
print("\n",extended_creativity_dict)

print("\nDict for uncreativity:")
print("(containing", len(extended_uncreativity_dict), "words)")
print("\n",extended_uncreativity_dict)
# Out:
# Dict for creativity:
#
# (containing 39 words)
#
#  ['amusing', 'simplistic', 'innovative', 'hilarious', 'invented', 'untraditional', 'intuitive', 'bizarre', 'sophisticated', 'unorthodox', 'neat', 'brilliant', 'quirky', 'fascinating', 'invent', 'novel', 'originality', 'inventive', 'intricate', 'clever', 'experimentation', 'resourceful', 'imaginative', 'invention', 'creative', 'teriffic', 'genius', 'new', 'uncomplicated', 'intrigued', 'creativity', 'ingenious', 'interesting', 'intriguing', 'ingenuity', 'crafty', 'inspiring', 'unconventional', 'creatively']
#
# Dict for uncreativity:
# (containing 41 words)
#
#  ['unattractive', 'muddled', 'disappointing', 'monotonous', 'boring', 'devoid', 'enjoyable', 'blah', 'lifeless', 'exciting', 'humdrum', 'uninspiring', 'unappealing', 'uninspired', 'disappointingly', 'bore', 'old', 'unmemorable', 'tastless', 'tasteless', 'worn', 'mediocre', 'unimpressed', 'meh', 'bland', 'drab', 'pointless', 'dull', 'lackluster', 'flavorless', 'pathetic', 'stodgy', 'unexciting', 'uninteresting', 'lame', 'memorable', 'underwhelming', 'forgettable', 'unremarkable', 'flavourless', 'unimpressive']

# %% [markdown]
# # PMI

# %% [markdown]
# PMI(A,B) = (P(A,B))/ (P(A)*P(B))
#
# P(A,B) = (number of doc where A B both occur)/ total number of doc
#
# P(A) = (number of doc where A occurs)/ total number of doc
#
# P(B) = (number of doc where B occurs)/ total number of doc

# %%
### Subset a sample 

df_sample = df_full.head(10000)

review_list_sample = []
for review in df_sample['review_text']:
    # tokenize review, lower case, remove accented, remove stopwords
    tokens = [lemmatizer.lemmatize(w) 
              for w in gensim.utils.simple_preprocess(remove_stopwords(review), deacc=True, min_len=3)]
    review_list_sample.append(tokens)
print(len(review_list_sample))

model_sample = gensim.models.Word2Vec(min_count=5, size=300, window = 5)

model_sample.build_vocab(review_list_sample)
model_sample.intersect_word2vec_format("/Users/nessyliu/Desktop/RA/GoogleNews-vectors-negative300.bin", 
                                  binary=True, lockf=1.0)
model_sample.train(review_list_sample, total_examples=len(review_list_sample), epochs=model_sample.epochs)

print(len(list(model_sample.wv.vocab)))
# Out:
# 10000
# 2631

# %%
# Create a dictionary for each vocabulary (key) in the word2vec model with its probability (value)

N = len(review_list_sample)
vocab_prob = {}
for vocab in model_sample.wv.vocab:
    vocab_prob[vocab] = sum([vocab in review for review in review_list_sample])/ N

# %%
# Create a PMI df, each column is a dict word (A), each row is a vocab in review data (B), values are P(A,B)

sample_dict = [word for word in extended_creativity_dict if word in model_sample.wv.vocab]
print(sample_dict)

df_PMI = pd.DataFrame()
i = 1
for A in sample_dict:
    print(i,'/',len(sample_dict))
    i+=1
    for B in model_sample.wv.vocab:
        P_A = vocab_prob[A]
        P_B = vocab_prob[B]
        P_AB = sum([(A in review and B in review) for review in review_list_sample]) / N
        df_PMI.at[B, A] = P_AB / (P_A * P_B)
# Out:
# ['creative', 'genius', 'new', 'interesting']
# 1 / 4
# 2 / 4
# 3 / 4
# 4 / 4

# %%
df_PMI.head(20)
# Out:
#           creative     genius       new  interesting
# loved     1.882530   0.941265  1.044641     0.684556
# thanks    3.229974   3.229974  1.717674     1.761804
# sharing   0.000000   5.319149  1.475833     1.934236
# recipe    1.508205   1.508205  1.422769     1.096876
# too       0.000000   4.045307  0.935331     2.942042
# die       0.000000  78.125000  3.612717     0.000000
# for       0.000000   5.230126  1.692989     0.000000
# very      1.698370   0.000000  0.628299     0.000000
# basic    32.051282   0.000000  2.964280     0.000000
# need      0.000000   3.396739  1.727821     2.470356
# time      0.668449   2.005348  1.081883     1.215362
# slow      3.633721   0.000000  2.184433     1.321353
# cooking   0.000000   4.980080  1.995870     1.207292
# process   0.000000   0.000000  1.651528    12.987013
# make      0.000000   2.306273  0.853188     2.515934
# meat      0.000000   2.607789  1.567688     0.948287
# tender    1.482800   1.482800  1.371375     0.539200
# yummy     0.000000   0.000000  0.554027     1.452222
# suggest   0.000000  26.041667  1.204239     0.000000
# cutting   0.000000   0.000000  1.229861     0.000000

# %% [markdown]
# # Closest Sentences

# %%
# Sent tokenize the reviews
sentence_list = []
raw_list = []
for review in df_sample['review_text']:
    sentences_in_review = sent_tokenize(review)
    for sent in sentences_in_review:
        tokens = [lemmatizer.lemmatize(w) 
                  for w in gensim.utils.simple_preprocess(remove_stopwords(review), deacc=True, min_len=3)]
        sentence_list.append(tokens)
        raw_list.append(sent)
print(len(sentence_list))
# Out:
# 38960

# %%
# mean vector of the extended creative dict
creative_vec = np.mean([model_sample.wv[word] for word in sample_dict], axis=0)

# df storing each sentence with its vector value (mean of the vectors of all its words)
sent_vector_list = []
cosine_distance_list = []
for sent in sentence_list:
#     try:
#         sent_vector = np.mean([model_sample.wv[token] for token in sent])
#         sent_vector_list.append(sent_vector)
#         cosine_distance_list.append(scipy.spatial.distance.cosine(sent_vector, creative_vec))
#     except: # if the word not in vocab
#         sent_vector = 'None'
#         sent_vector_list.append(sent_vector)
#         cosine_distance_list.append('None')
    token_vec_list = []
    for token in sent:
        try:
            token_vec = model_sample.wv[token]
        except:
            # continue
            token_vec = np.zeros(300)
        token_vec_list.append(token_vec)
    
    sent_vector = np.mean(token_vec_list, axis=0)
    sent_vector_list.append(sent_vector)
    cosine_distance_list.append(abs(scipy.spatial.distance.cosine(sent_vector, creative_vec)))
    
df_sent = pd.DataFrame({
    'raw': raw_list,
    #'sentence' : sentence_list,
    'vector' : sent_vector_list,
    'cos_dist': cosine_distance_list
})
df_sent = df_sent.drop_duplicates(subset='cos_dist', keep="first")

# %%
df_sent = df_sent.sort_values(by =['cos_dist'], ascending=True)

df_sent.head(20)
# Out:
#                                                      raw  \
# 13630  I really love this recipe -- it's got a sweet ...
# 28619               In my son's new top 10 of favorites.
# 15272  i made this as presented and it was very good ...
# 18675                                A new favorite!!!!!
# 33332                          So different and SO GOOD!
# 18208                 This is my familiy's new favorite!
# 32837  I truly love Chef Johns recipes and this one i...
# 23363                             Wow, that was awesome.
# 2296     this is so great, simple and tastes delicious!!
# 2928   Strange name that brings strange comments but ...
# 22798               Another great recipe from Chef John.
# 5258   This is my favorite recipe website, have been ...
# 5512                                  Such a cute idea!!
# 10160                      Amazing - new family favorite
# 9732          I've grilled tri-tips for years and years.
# 32864                                   I LOVE pastrami.
# 26139  Follow the reviews and make the changes they s...
# 5497   My grandson loved this so much that he had to ...
# 32853      What a wonderful recipe and totally worth it!
# 32924  I made this pastrami for my husband for Father...
#
#                                                   vector  cos_dist
# 13630  [0.123237014, -0.018454539, 0.036114357, 0.304...  0.261980
# 28619  [0.018842475, 0.1026762, -0.00029796362, 0.475...  0.281492
# 15272  [0.17010970103243986, 0.14826197984317938, 0.0...  0.294592
# 18675  [0.06800623, 0.1639131, 0.31489766, 0.3450297,...  0.298927
# 33332  [-0.010801996, 0.013818285, 0.009665249, 0.361...  0.300156
# 18208  [0.09201975688338279, 0.11644953414797783, 0.1...  0.307868
# 32837  [-0.027955972822383046, -0.046079766008188014,...  0.308222
# 23363  [-0.070553094, -0.038026787, 0.029123444, 0.40...  0.309530
# 2296   [0.014271491, 0.019467827, 0.01845777, 0.35075...  0.316049
# 2928   [0.05712676, 0.042948022, -0.0030723654, 0.150...  0.316661
# 22798  [-0.1696444, -0.0443784, 0.11698871, 0.3595582...  0.320134
# 5258   [0.035003121248743635, 0.09293185770907934, 0....  0.321169
# 5512   [0.078812696, 0.11671119, -0.039690994, 0.3713...  0.323906
# 10160  [0.007347456, -0.101743914, 0.04408148, 0.2687...  0.328415
# 9732   [-0.08645581510408144, 0.14719049529613634, 0....  0.330279
# 32864  [-0.04228162432887724, 0.12342105942246105, 0....  0.330971
# 26139  [-0.18353955, -0.07526836, 0.2148532, 0.366107...  0.332561
# 5497   [0.025733927885691326, 0.09607521345218023, -0...  0.339272
# 32853  [0.01836542845038431, -0.02264385104977659, 0....  0.339444
# 32924  [-0.12443087189173212, 0.011427888456656009, 0...  0.340078
