# %%
import re
import pandas as pd
import nltk
import unicodedata
import csv
import itertools
from tqdm import trange, tqdm
from nltk import word_tokenize, pos_tag, corpus
from nltk.stem import WordNetLemmatizer
from collections import defaultdict, Counter

# %%
# Read in the datasets
df_directions = pd.read_excel('/Users/nessyliu/Desktop/RA/AllRecipes_Directions_2019-11-26.xlsx')
df = pd.read_csv('/Users/nessyliu/Desktop/RA/AllReviews_26thNov2019.csv')
df_ingredients_raw = pd.read_csv('/Users/nessyliu/Desktop/RA/part_2/Ingredients.csv')
df_cluster = pd.read_excel('/Users/nessyliu/Desktop/RA/part_2/Cluster_names.xlsx')

# %%
full_directions_list = []
recipe_id_list = list(set(df_directions.recipe_id.tolist()))
for recipe_id in recipe_id_list:
    full_dir_this_recipe = ' '.join(df_directions.loc[df_directions['recipe_id']==recipe_id, 'directions_step_text'])
    full_directions_list.append(full_dir_this_recipe)
dict_recipe_direction = dict(zip(recipe_id_list, full_directions_list))

# %%
# list of cluster names with spaces (e.g. apple juice) sorted by number of words in each name, 
# e.g. "apple juice" should appear before "juice"
cluster_name_orig_list = df_cluster.cluster_name.tolist()
cluster_name_orig_list.sort(key=lambda x: len(x.split()), reverse=True)

# create dict to map recipe_id to ingredient_ids
df_ingredients = df_ingredients_raw.groupby('recipe_id')['ingredient_id'].apply(list).reset_index(name ='ingredients')
dict_recipe_ingredients = dict(zip(df_ingredients.recipe_id, df_ingredients.ingredients))

# create dict to map ingredient_id to cluster_name
df_cluster = df_cluster.replace(' ', '_', regex=True)
dict_ingredient_clustername = dict(zip(df_cluster.ingredient_id, df_cluster.cluster_name))

# %%
# lemmatization dict
lemma_list = pd.read_csv('/Users/nessyliu/Desktop/RA/lemma_list.csv')
lemma_dict = lemma_list.set_index('word_list').to_dict()['lemma_list']

def lemmatization(text):
    # use the custom lemma dict first
    text = " ".join(str(lemma_dict.get(word, word)) for word in text.split())
    
    # then use the WordNetLemmatizer from nltk
    wnl = WordNetLemmatizer()
    # lemmatize each word based on its pos tagging
    text_after = " ".join([wnl.lemmatize(i,j[0].lower()) if j[0].lower() in ['a','n','v'] else wnl.lemmatize(i) for i,j in pos_tag(word_tokenize(text))])    
    return text_after

# %%
unigram_exclude_list = ['purpose','extra', 'whole', 'frying', 'cut',
                        'sun', 'baby', 'five', 'star',
                        'white', 'green', 'black', 'red', 'pink', 'yellow', 'brown', 'golden', 'blue', 
                        'color', 'colored',
                        'ground', 'sea', 'part', 'baked', 'raw', 'new', 'active',
                        'italian', 'dark', 'light', 'fresh', 'sweet', 'candied',
                        'dried', 'dry', 'heavy', 'condensed', 'firm', 'free', 'mixed', 'flavored', 'evaporated',
                        'hot', 'self', 'rising', 'split', 'cooking', 'stewed',
                        'de', 'dr']
unigram_exclude_list += corpus.stopwords.words('english')

ngram_exclude_list = ['all_purpose', 'purpose_flour', 'free_all']

ngram_not_start_end = ['for', 'of', 'and', 'with', 'in']

# %%
perfect_match_list = []
partial_match_list = []
no_match_list = []
recipe_list = []
direction_list = []
lemmatized_direction_list = []

num_ingredient_list = []
num_perfect_match_list = []
num_partial_match_list = []
num_no_match_list = []

for recipe_id in tqdm(recipe_id_list):
    # list of ingre that appeared exactly the same in the direction
    perfect_match_this_recipe = []
    # list of ingre that matched shorter form in the direction
    partial_match_this_recipe = []
    # list fo ingre that are not matched
    no_match_this_recipe = []
    
    # count number of ingredients
    num_perfect_match_this_recipe = 0
    num_partial_match_this_recipe = 0
    num_no_match_this_recipe = 0

    # get the ingredients of this recipe id
    try:
        recipe = [dict_ingredient_clustername[ingre_id] for ingre_id in dict_recipe_ingredients[recipe_id]]
        recipe.sort(key=lambda x: len(x.split('_')), reverse=True)
    except:
        recipe = [] # if the recipe id is not in the recipe_ingredient map list
        
    recipe.sort(key=lambda x: len(x.split('_')), reverse=True)
    # get the direction of this recipe id
    direction = dict_recipe_direction[recipe_id]
    lemmatized_direction = lemmatization(dict_recipe_direction[recipe_id])
    # map each ingredient to the words in the direction
    for ingre in recipe:
        ingre_tokens = ingre.split('_')
        ingre_original = ' '.join(ingre_tokens)
        if ingre_original in direction or ingre_original in lemmatized_direction:
            perfect_match_this_recipe.append(ingre)
            num_perfect_match_this_recipe += 1
        else:
            partial_match_this_ingre = []
            if len(ingre_tokens) > 1:
                n = len(ingre_tokens)-1
                while n > 0: # length of the short form
                    for i in range(0,len(ingre_tokens)-n+1): # start index in the full cluster name
                        short_form = ' '.join(ingre_tokens[i:i+n])
                        if short_form in direction or short_form in lemmatized_direction:
                            # the short form is a map to the ingre
                            # don't break the loop if matched, cuz 'oil for frying' may end up matched 'for frying' and break
                            # but ignore subsequence part, e.g. if 'firm tofu' is matched, ignore 'firm' & 'tofu'
                            if not any(short_form in existing_short_form for existing_short_form in partial_match_this_ingre):
                                if n > 1: # if the short form >=2 words
                                    if short_form.replace(' ','_') not in ngram_exclude_list\
                                        and ingre_tokens[i] not in ngram_not_start_end \
                                        and ingre_tokens[i+n-1] not in ngram_not_start_end:
                                            # if the short form not in ngram_exclude_list
                                            # and the short form does not start or end with words in ngram_not_start_end list
                                            partial_match_this_ingre.append(short_form.replace(' ','_'))
                                else: # if the short form is unigram
                                    if short_form not in unigram_exclude_list:
                                        partial_match_this_ingre.append(short_form)
                            
                    n -= 1
            if len(partial_match_this_ingre) == 0:
                no_match_this_recipe.append(ingre)
                num_no_match_this_recipe += 1
            else:
                partial_match_this_recipe.append([ingre, partial_match_this_ingre])
                num_partial_match_this_recipe += 1
    
    recipe_list.append(recipe)
    direction_list.append(direction)
    lemmatized_direction_list.append(lemmatized_direction)
    perfect_match_list.append(perfect_match_this_recipe)
    partial_match_list.append(partial_match_this_recipe)
    no_match_list.append(no_match_this_recipe)
    num_perfect_match_list.append(num_perfect_match_this_recipe)
    num_partial_match_list.append(num_partial_match_this_recipe)
    num_no_match_list.append(num_no_match_this_recipe)
    num_ingredient_list.append(len(recipe))

matched_df = pd.DataFrame({
    'recipe_id': recipe_id_list, 
    'recipe': recipe_list,
    'direction': direction_list,
    'lemma_direction': lemmatized_direction_list,
    'perfect_match': perfect_match_list,
    'partial_match': partial_match_list,
    'no_match': no_match_list,
    'num_ingredient': num_ingredient_list,
    'num_perfect_match': num_perfect_match_list,
    'num_partial_match': num_partial_match_list,
    'num_no_match': num_no_match_list
})
# Out:
# 100%|██████████| 69121/69121 [06:12<00:00, 185.44it/s]

# %%
# test the 1-gram to (n-1)-gram shorter forms
ingre_tokens = ['fresh','white','chocolate','chips']

n = len(ingre_tokens)-1
while n > 0:
    for i in range(0,len(ingre_tokens)-n+1):
        short_form = ' '.join(ingre_tokens[i:i+n])
        print(short_form)
    n = n-1
# Out:
# fresh white chocolate
# white chocolate chips
# fresh white
# white chocolate
# chocolate chips
# fresh
# white
# chocolate
# chips

# %%
# n = 10 # check a random recipe
# print('recipe:',matched_df.loc[n,'recipe'])
# print('perfect:',matched_df.loc[n,'perfect_match'])
# print('partial:',matched_df.loc[n,'partial_match'])
# print('no:',matched_df.loc[n,'no_match'])
# print('\ndirection:',matched_df.loc[n,'direction'])

# %%
matched_df.to_csv('/Users/nessyliu/Desktop/RA/part_2/result/matched_directions.csv')

# %%
# matched_df.head()

# %%
# Create a dict using ingredient (cluster name) as key, 
# all appeared short forms (across all directions) as values, excluding meaningless terms (e.g. 'all','purpose','for')
all_short_forms = []
dict_ingre_shortforms = defaultdict(list)
for partial_match_this_recipe in partial_match_list:
    for partial_match_this_ingre in partial_match_this_recipe:
        ingre = partial_match_this_ingre[0]
        short_forms = partial_match_this_ingre[1]
        for short_form in short_forms:
            if short_form not in dict_ingre_shortforms[ingre]:
                all_short_forms.append(short_form)
                dict_ingre_shortforms[ingre].append(short_form)

# %%
count_short_forms = Counter(all_short_forms)
# count_short_forms.most_common()

# %%
# manually add some more mappings
dict_ingre_shortforms['beef_sirloin'].append('steak')
dict_ingre_shortforms['crabmeat'].append('crab')
dict_ingre_shortforms['espresso'].append('coffee_bean')

# %%
for key in dict_ingre_shortforms:
    print('\n',key)
    print(dict_ingre_shortforms[key])
# Out:
#  all_purpose_flour
# ['flour']
#
#  other_milk
# ['milk']
#
#  olive_oil
# ['oil', 'olive']
#
#  ground_coriander
# ['coriander']
#
#  ground_turmeric
# ['turmeric']
#
#  cumin_seed
# ['cumin', 'seed']
#
#  extra_virgin_olive_oil
# ['olive_oil', 'oil', 'virgin_olive_oil', 'virgin_olive', 'olive']
#
#  ground_black_pepper
# ['pepper', 'black_pepper']
#
#  split_pea
# ['pea']
#
#  whole_milk
# ['milk']
#
#  parmesan_cheese
# ['cheese', 'parmesan']
#
#  red_bell_pepper
# ['bell_pepper', 'pepper', 'bell', 'red_bell']
#
#  ground_cumin
# ['cumin']
#
#  flavored_gelatin
# ['gelatin']
#
#  granny_smith_apple
# ['apple', 'smith_apple']
#
#  beef_stew_meat
# ['beef', 'meat', 'stew', 'stew_meat', 'beef_stew']
#
#  vegetable_oil
# ['oil', 'vegetable']
#
#  white_sugar
# ['sugar']
#
#  whole_clove
# ['clove']
#
#  oil_for_frying
# ['oil']
#
#  ricotta_cheese
# ['cheese', 'ricotta']
#
#  whole_kernel_corn
# ['corn', 'kernel', 'kernel_corn']
#
#  white_rice
# ['rice']
#
#  cheddar_cheese
# ['cheese', 'cheddar']
#
#  ground_nutmeg
# ['nutmeg']
#
#  white_vinegar
# ['vinegar']
#
#  red_onion
# ['onion']
#
#  green_chile_pepper
# ['chile', 'green_chile', 'pepper', 'chile_pepper']
#
#  ground_turkey
# ['turkey']
#
#  black_olive
# ['olive']
#
#  worcestershire_sauce
# ['sauce']
#
#  sea_salt
# ['salt']
#
#  dried_fig
# ['fig']
#
#  agave_nectar
# ['agave']
#
#  rib_eye_steak
# ['steak', 'rib_eye', 'rib', 'eye']
#
#  whole_black_peppercorn
# ['peppercorn', 'black_peppercorn']
#
#  heavy_cream
# ['cream']
#
#  skinless_boneless_chicken_breast
# ['chicken_breast', 'chicken', 'breast', 'boneless_chicken_breast', 'boneless_chicken', 'skinless']
#
#  chicken_thigh
# ['chicken', 'thigh']
#
#  red_wine
# ['wine']
#
#  silken_tofu
# ['tofu']
#
#  dashi_stock
# ['dashi', 'stock']
#
#  jalapeno_pepper
# ['jalapeno', 'pepper']
#
#  gorgonzola_cheese
# ['cheese', 'gorgonzola']
#
#  ground_ginger
# ['ginger']
#
#  semisweet_chocolate_chip
# ['chocolate_chip', 'chocolate', 'semisweet_chocolate', 'chip', 'semisweet']
#
#  rice_cereal
# ['cereal', 'rice']
#
#  condensed_tomato_soup
# ['tomato_soup', 'soup', 'tomato']
#
#  white_wine_vinegar
# ['vinegar', 'wine', 'wine_vinegar', 'white_wine']
#
#  corn_tortilla
# ['tortilla', 'corn']
#
#  whole_wheat_tortilla
# ['tortilla']
#
#  mexican_cheese_blend
# ['cheese_blend', 'cheese', 'blend']
#
#  cajun_seasoning
# ['seasoning']
#
#  vegetable_broth
# ['broth', 'vegetable']
#
#  italian_bread
# ['bread']
#
#  dried_parsley
# ['parsley']
#
#  dried_oregano
# ['oregano']
#
#  sweet_onion
# ['onion']
#
#  hot_sauce
# ['sauce']
#
#  superfine_sugar
# ['sugar']
#
#  ground_cardamom
# ['cardamom']
#
#  gouda_cheese
# ['cheese', 'gouda']
#
#  dry_active_yeast
# ['yeast', 'active_yeast']
#
#  unsalted_butter
# ['butter']
#
#  arborio_rice
# ['rice']
#
#  morel_mushroom
# ['morel', 'mushroom']
#
#  green_onion
# ['onion']
#
#  plain_kefir
# ['kefir']
#
#  dried_mint
# ['mint']
#
#  penne_pasta
# ['penne', 'pasta']
#
#  baby_back_rib
# ['rib', 'baby_back', 'back']
#
#  beef_broth
# ['broth', 'beef']
#
#  kosher_salt
# ['salt', 'kosher']
#
#  herbes_de_provence
# ['herbes_de']
#
#  baby_carrot
# ['carrot']
#
#  bay_leaf
# ['bay', 'leaf']
#
#  chicken_stock
# ['chicken', 'stock']
#
#  rice_vinegar
# ['rice', 'vinegar']
#
#  avocado_oil
# ['oil', 'avocado']
#
#  ground_cinnamon
# ['cinnamon']
#
#  self_rising_flour
# ['flour', 'rising_flour']
#
#  greek_yogurt
# ['yogurt']
#
#  feta_cheese
# ['feta', 'cheese']
#
#  smoked_sausage
# ['sausage', 'smoked']
#
#  dried_thyme
# ['thyme']
#
#  milk_powder
# ['milk', 'powder']
#
#  plain_yogurt
# ['yogurt', 'plain']
#
#  french_salad_dressing
# ['salad_dressing', 'dressing', 'salad']
#
#  brussels_sprout
# ['sprout']
#
#  dry_mustard
# ['mustard']
#
#  agar_agar_powder
# ['agar_agar', 'powder', 'agar_powder', 'agar']
#
#  flax_seed
# ['flax', 'seed']
#
#  unflavored_gelatin
# ['gelatin']
#
#  italian_sausage
# ['sausage']
#
#  romano_cheese
# ['cheese', 'romano']
#
#  ground_allspice
# ['allspice']
#
#  sparkling_water
# ['water']
#
#  white_wine
# ['wine']
#
#  cranberry_juice
# ['cranberry', 'juice']
#
#  condensed_cream_of_chicken_soup
# ['cream_of_chicken_soup', 'cream_of_chicken', 'chicken_soup', 'chicken', 'soup', 'cream', 'condensed_cream']
#
#  green_bell_pepper
# ['bell_pepper', 'pepper', 'bell']
#
#  flour_tortilla
# ['tortilla', 'flour']
#
#  butternut_squash
# ['squash', 'butternut']
#
#  canola_oil
# ['oil', 'canola']
#
#  ground_beef
# ['beef']
#
#  cooking_spray
# ['spray']
#
#  chili_sauce
# ['sauce', 'chili']
#
#  rom_tomato
# ['rom', 'tomato']
#
#  linguine_pasta
# ['linguine', 'pasta']
#
#  chorizo_sausage
# ['chorizo', 'sausage']
#
#  vegan_cheese
# ['vegan', 'cheese']
#
#  taco_shell
# ['taco', 'shell']
#
#  mixed_berry
# ['berry']
#
#  chile_de_arbol_pepper
# ['chile', 'pepper', 'arbol_pepper', 'de_arbol', 'chile_de_arbol', 'chile_de', 'arbol']
#
#  whole_wheat_flour
# ['flour', 'wheat_flour', 'wheat', 'whole_wheat']
#
#  pasilla_chile_pepper
# ['pasilla_chile', 'pepper', 'pasilla', 'chile_pepper', 'chile']
#
#  adobo_sauce
# ['sauce', 'adobo']
#
#  romaine_lettuce
# ['lettuce', 'romaine']
#
#  ear_corn
# ['corn', 'ear']
#
#  poblano_pepper
# ['poblano', 'pepper']
#
#  guajillo_chile_pepper
# ['guajillo_chile', 'chile', 'pepper']
#
#  white_onion
# ['onion']
#
#  chicken_bouillon
# ['bouillon', 'chicken']
#
#  cotija_cheese
# ['cheese', 'cotija']
#
#  black_bean
# ['bean']
#
#  chicken_breast
# ['chicken']
#
#  chayote_squash
# ['chayote', 'squash']
#
#  basmati_rice
# ['rice']
#
#  ground_pork
# ['pork']
#
#  balsamic_vinegar
# ['vinegar', 'balsamic']
#
#  green_olive
# ['olive']
#
#  cider_vinegar
# ['vinegar', 'cider']
#
#  chicken_broth
# ['broth', 'chicken']
#
#  dried_dill_weed
# ['dill', 'dill_weed', 'dried_dill']
#
#  monterey_jack_cheese
# ['cheese', 'jack_cheese', 'jack']
#
#  green_pea
# ['pea']
#
#  dry_vermouth
# ['vermouth']
#
#  shortbread_cooky
# ['cooky', 'shortbread']
#
#  caramel_topping
# ['caramel', 'topping']
#
#  pork_sausage
# ['sausage', 'pork']
#
#  swiss_chard
# ['chard']
#
#  italian_seasoning
# ['seasoning']
#
#  ancho_chile_pepper
# ['ancho', 'pepper', 'chile', 'ancho_chile', 'chile_pepper']
#
#  shiitake_mushroom
# ['mushroom', 'shiitake']
#
#  beef_part
# ['beef']
#
#  beef_bone
# ['beef', 'bone']
#
#  seafood_stock
# ['stock', 'seafood']
#
#  baked_bean
# ['bean']
#
#  bacon_dripping
# ['bacon', 'dripping']
#
#  dried_basil
# ['basil']
#
#  firm_tofu
# ['tofu']
#
#  red_wine_vinegar
# ['vinegar', 'wine_vinegar', 'wine', 'red_wine']
#
#  white_fish
# ['fish']
#
#  chili_oil
# ['oil']
#
#  seedless_grape
# ['grape', 'seedless']
#
#  canning_jar_with_lid_and_ring
# ['jar', 'lid', 'ring', 'canning', 'canning_jar', 'lid_and_ring', 'jar_with_lid', 'jar_with_lid_and_ring']
#
#  cherry_tomato
# ['tomato', 'cherry']
#
#  hamburger_bun
# ['bun', 'hamburger']
#
#  garlic_and_herb_seasoning
# ['garlic', 'seasoning', 'herb_seasoning']
#
#  chow_mein_noodle
# ['noodle', 'chow']
#
#  sriracha_sauce
# ['sauce', 'sriracha']
#
#  cayenne_pepper
# ['cayenne', 'pepper']
#
#  whole_wheat_bread
# ['bread', 'wheat_bread', 'whole_wheat', 'wheat']
#
#  dried_rosemary
# ['rosemary']
#
#  dried_marjoram
# ['marjoram']
#
#  dijon_mustard
# ['mustard']
#
#  ground_white_pepper
# ['pepper', 'white_pepper']
#
#  condensed_cream_of_mushroom_soup
# ['cream_of_mushroom_soup', 'cream_of_mushroom', 'mushroom_soup', 'cream', 'mushroom', 'soup']
#
#  muenster_cheese
# ['cheese']
#
#  grape_tomato
# ['tomato']
#
#  skim_milk
# ['milk']
#
#  green_bean
# ['bean']
#
#  skinless_boneless_chicken_thigh
# ['chicken_thigh', 'chicken', 'thigh']
#
#  brie_cheese
# ['cheese', 'brie']
#
#  gluten_free_all_purpose_flour
# ['flour', 'gluten']
#
#  port_wine
# ['port', 'wine']
#
#  ground_clove
# ['clove']
#
#  rolled_oat
# ['oat', 'rolled']
#
#  thai_basil
# ['basil']
#
#  confectioners'_sugar
# ['sugar', "confectioners'"]
#
#  tomato_soup
# ['tomato', 'soup']
#
#  sourdough_bread
# ['bread', 'sourdough']
#
#  wheat_gluten
# ['wheat', 'gluten']
#
#  bone_in_chicken_breast
# ['chicken_breast', 'bone', 'chicken', 'breast']
#
#  beef_chuck
# ['beef', 'chuck']
#
#  pepper_jack_cheese
# ['pepper', 'cheese', 'jack_cheese', 'jack', 'pepper_jack']
#
#  cake_flour
# ['flour', 'cake']
#
#  vanilla_extract
# ['vanilla', 'extract']
#
#  half_and_half
# ['half']
#
#  sour_cream
# ['cream']
#
#  french_bread
# ['bread', 'french']
#
#  baby_spinach
# ['spinach']
#
#  cottage_cheese
# ['cheese', 'cottage']
#
#  chile_pepper
# ['pepper', 'chile']
#
#  wonton_wrapper
# ['wrapper', 'wonton']
#
#  pizza_dough
# ['dough', 'pizza']
#
#  mozzarella_cheese
# ['mozzarella', 'cheese']
#
#  lemon_grass
# ['lemon', 'grass']
#
#  pig's_part
# ["pig's"]
#
#  pork_shoulder
# ['pork', 'shoulder']
#
#  smoked_paprika
# ['paprika']
#
#  chocolate_hazelnut_spread
# ['hazelnut_spread', 'chocolate', 'chocolate_hazelnut', 'spread']
#
#  navy_bean
# ['bean']
#
#  vanilla_powder
# ['vanilla', 'powder']
#
#  sun_dried_tomato
# ['dried_tomato', 'tomato']
#
#  miso_paste
# ['miso', 'paste']
#
#  liquid_amino
# ['amino', 'liquid']
#
#  vegetable_bouillon
# ['bouillon', 'vegetable']
#
#  garbanzo_bean
# ['bean', 'garbanzo']
#
#  sazon_seasoning
# ['sazon', 'seasoning']
#
#  yukon_gold_potato
# ['potato', 'gold', 'gold_potato']
#
#  cane_sugar
# ['sugar']
#
#  red_pepper_flake
# ['flake', 'red_pepper', 'pepper_flake', 'pepper']
#
#  mixed_vegetable
# ['vegetable']
#
#  dried_onion
# ['onion']
#
#  biscuit_dough
# ['dough', 'biscuit']
#
#  chicken_chunk
# ['chicken', 'chunk']
#
#  chinese_five_spice_powder
# ['spice_powder', 'spice', 'five_spice_powder', 'five_spice']
#
#  rice_wrapper
# ['rice', 'wrapper']
#
#  soy_sauce
# ['sauce', 'soy']
#
#  raspberry_jam
# ['raspberry', 'jam']
#
#  semisweet_chocolate
# ['chocolate', 'semisweet']
#
#  key_lime_juice
# ['lime_juice', 'lime', 'juice']
#
#  rose_water
# ['rose', 'water']
#
#  chipotle_pepper
# ['chipotle', 'pepper']
#
#  bread_crumb
# ['bread', 'crumb']
#
#  dried_cilantro
# ['cilantro']
#
#  peppermint_candy
# ['peppermint', 'candy']
#
#  seashell_pasta
# ['pasta']
#
#  orzo_pasta
# ['orzo', 'pasta']
#
#  chicken_liver
# ['liver', 'chicken']
#
#  butter_bean
# ['bean', 'butter']
#
#  other_meat
# ['meat']
#
#  coconut_flavored_yogurt
# ['coconut', 'yogurt']
#
#  bread_flour
# ['flour', 'bread']
#
#  chocolate_candy
# ['chocolate', 'candy']
#
#  caraway_seed
# ['caraway', 'seed']
#
#  candy_coated_chocolate
# ['chocolate', 'candy', 'coated_chocolate', 'coated']
#
#  serrano_pepper
# ['serrano', 'pepper']
#
#  cola_soda
# ['cola', 'soda']
#
#  tostada_shell
# ['tostada']
#
#  dried_currant
# ['currant']
#
#  american_cheese
# ['cheese']
#
#  dried_sage
# ['sage']
#
#  black_sesame_seed
# ['sesame_seed']
#
#  ground_chicken
# ['chicken']
#
#  ground_chile_pepper
# ['chile_pepper', 'chile', 'pepper', 'ground_chile']
#
#  beef_brisket
# ['brisket', 'beef']
#
#  pinto_bean
# ['bean', 'pinto']
#
#  fresh_yeast
# ['yeast']
#
#  lamb_shoulder
# ['lamb']
#
#  brown_sugar
# ['sugar']
#
#  himalayan_salt
# ['salt']
#
#  curry_powder
# ['curry', 'powder']
#
#  light_cream
# ['cream']
#
#  turkey_sausage
# ['sausage', 'turkey']
#
#  swiss_cheese
# ['cheese']
#
#  colby_cheese
# ['cheese', 'colby']
#
#  french_baguette
# ['baguette']
#
#  creole_seasoning
# ['seasoning', 'creole']
#
#  dried_tarragon
# ['tarragon']
#
#  sherry_vinegar
# ['vinegar', 'sherry']
#
#  vanilla_flavored_yogurt
# ['vanilla', 'yogurt']
#
#  coconut_sugar
# ['sugar', 'coconut']
#
#  baking_soda
# ['baking', 'soda']
#
#  emmentaler_cheese
# ['cheese']
#
#  roasted_red_pepper
# ['pepper', 'roasted_red', 'red_pepper', 'roasted']
#
#  bread_roll
# ['roll', 'bread']
#
#  naan_bread
# ['naan', 'bread']
#
#  provolone_cheese
# ['cheese', 'provolone']
#
#  apple_butter
# ['apple', 'butter']
#
#  gruyere_cheese
# ['cheese']
#
#  kielbasa_sausage
# ['kielbasa', 'sausage']
#
#  yellow_bell_pepper
# ['bell_pepper', 'pepper', 'bell']
#
#  allspice_berry
# ['allspice', 'berry']
#
#  cream_cheese
# ['cheese', 'cream']
#
#  pie_crust
# ['pie', 'crust']
#
#  turkey_gravy
# ['turkey', 'gravy']
#
#  bay_scallop
# ['scallop', 'bay']
#
#  buttery_cracker
# ['cracker', 'buttery']
#
#  sea_scallop
# ['scallop']
#
#  dried_cranberry
# ['cranberry']
#
#  beef_bouillon
# ['beef', 'bouillon']
#
#  strip_steak
# ['steak']
#
#  egg_noodle
# ['noodle', 'egg']
#
#  condensed_golden_mushroom_soup
# ['mushroom', 'soup', 'golden_mushroom_soup', 'golden_mushroom', 'mushroom_soup']
#
#  pork_chop
# ['pork', 'chop']
#
#  beef_stock
# ['stock', 'beef']
#
#  dill_pickle_juice
# ['pickle_juice', 'dill', 'pickle', 'juice', 'dill_pickle']
#
#  new_potato
# ['potato']
#
#  empanada_pastry
# ['empanada', 'pastry']
#
#  rotini_pasta
# ['rotini', 'pasta']
#
#  evaporated_milk
# ['milk']
#
#  ditalini_pasta
# ['pasta', 'ditalini']
#
#  portobello_mushroom
# ['mushroom', 'portobello']
#
#  lasagna_noodle
# ['lasagna', 'noodle']
#
#  prime_rib_roast
# ['roast', 'prime_rib', 'rib', 'rib_roast']
#
#  lamb_stew_meat
# ['lamb', 'meat', 'stew', 'lamb_stew', 'stew_meat']
#
#  peach_nectar
# ['peach']
#
#  potato_gnocchi
# ['gnocchi']
#
#  breakfast_sausage
# ['sausage', 'breakfast']
#
#  instant_yeast
# ['yeast', 'instant']
#
#  dark_chocolate
# ['chocolate']
#
#  red_potato
# ['potato']
#
#  coconut_flavored_rum
# ['flavored_rum', 'coconut', 'rum']
#
#  french_fried_onion
# ['fried', 'fried_onion', 'onion', 'french']
#
#  kalamata_olive
# ['olive']
#
#  chickpea_flour
# ['flour', 'chickpea']
#
#  white_corn
# ['corn']
#
#  chocolate_cake_mix
# ['cake_mix', 'chocolate', 'cake', 'mix', 'chocolate_cake']
#
#  chocolate_pudding_mix
# ['pudding_mix', 'chocolate', 'pudding', 'mix', 'chocolate_pudding']
#
#  orange_zest
# ['zest', 'orange']
#
#  lemon_zest
# ['lemon', 'zest']
#
#  flat_iron_steak
# ['steak', 'flat']
#
#  tortilla_chip
# ['chip', 'tortilla']
#
#  whole_grain_bread
# ['bread', 'grain_bread']
#
#  caesar_dressing
# ['dressing']
#
#  smoked_salt
# ['salt']
#
#  rice_noodle
# ['noodle', 'rice']
#
#  sunflower_seed_oil
# ['oil', 'seed', 'sunflower', 'sunflower_seed']
#
#  soy_yogurt
# ['yogurt', 'soy']
#
#  grenadine_syrup
# ['grenadine', 'syrup']
#
#  maraschino_cherry
# ['cherry', 'maraschino']
#
#  egg_substitute
# ['egg', 'substitute']
#
#  seafood_seasoning
# ['seasoning', 'seafood']
#
#  red_chile_pepper
# ['chile_pepper', 'pepper', 'red_chile', 'chile']
#
#  teriyaki_sauce
# ['teriyaki', 'sauce']
#
#  garlic_pepper_seasoning
# ['pepper_seasoning', 'garlic', 'pepper', 'seasoning', 'garlic_pepper']
#
#  hoisin_sauce
# ['hoisin', 'sauce']
#
#  italian_salad_dressing
# ['dressing', 'salad_dressing', 'salad']
#
#  pepper_jam
# ['pepper', 'jam']
#
#  dried_savory
# ['savory']
#
#  vegetable_stock
# ['stock', 'vegetable']
#
#  pink_peppercorn
# ['peppercorn']
#
#  pumpkin_seed
# ['seed', 'pumpkin']
#
#  unsweetened_chocolate
# ['chocolate', 'unsweetened']
#
#  pumpkin_pie_spice
# ['pumpkin', 'spice', 'pie', 'pie_spice', 'pumpkin_pie']
#
#  pumpkin_puree
# ['pumpkin', 'puree']
#
#  processed_cheese
# ['cheese', 'processed']
#
#  chicken_carcass
# ['chicken']
#
#  crystallized_ginger
# ['ginger']
#
#  mexican_crema
# ['crema']
#
#  fettuccine_pasta
# ['pasta', 'fettuccine']
#
#  chardonnay_wine
# ['wine', 'chardonnay']
#
#  blackening_seasoning
# ['seasoning']
#
#  peanut_oil
# ['oil', 'peanut']
#
#  jasmine_rice
# ['rice']
#
#  ground_lamb
# ['lamb']
#
#  rye_bread
# ['bread', 'rye']
#
#  beef_tenderloin
# ['tenderloin', 'beef']
#
#  sweetened_condensed_milk
# ['condensed_milk', 'milk', 'sweetened']
#
#  spread_dip
# ['dip', 'spread']
#
#  taco_seasoning
# ['seasoning', 'taco']
#
#  macintosh_apple
# ['apple']
#
#  sweet_corn
# ['corn']
#
#  bittersweet_chocolate
# ['chocolate', 'bittersweet']
#
#  steel_cut_oat
# ['oat', 'cut_oat', 'steel']
#
#  egg_roll_wrapper
# ['wrapper', 'roll_wrapper', 'egg', 'egg_roll', 'roll']
#
#  golden_raisin
# ['raisin']
#
#  chocolate_flavored_syrup
# ['chocolate', 'flavored_syrup', 'syrup']
#
#  fusilli_pasta
# ['fusilli', 'pasta']
#
#  smoked_ham
# ['ham']
#
#  chicken_wing
# ['chicken', 'wing']
#
#  colored_sugar
# ['sugar']
#
#  other_fish
# ['fish']
#
#  dried_chive
# ['chive']
#
#  cannellini_bean
# ['bean', 'cannellini']
#
#  black_eyed_pea
# ['eyed_pea', 'pea']
#
#  clam_juice
# ['clam', 'juice']
#
#  almond_milk
# ['milk', 'almond']
#
#  spelt_flour
# ['flour', 'spelt']
#
#  cinnamon_stick
# ['cinnamon', 'stick']
#
#  hemp_seed
# ['hemp', 'seed']
#
#  blueberry_jam
# ['jam', 'blueberry']
#
#  chocolate_chip
# ['chocolate', 'chip']
#
#  dried_apricot
# ['apricot']
#
#  refried_bean
# ['bean']
#
#  raw_sugar
# ['sugar']
#
#  sucralose_sweetener
# ['sweetener', 'sucralose']
#
#  millet_flour
# ['flour']
#
#  lemon_lime_soda
# ['lemon', 'soda', 'lime_soda', 'lime']
#
#  butterscotch_pudding_mix
# ['pudding_mix', 'butterscotch_pudding', 'mix', 'pudding', 'butterscotch']
#
#  dinner_roll
# ['roll']
#
#  dark_chocolate_chip
# ['chocolate_chip', 'dark_chocolate', 'chocolate', 'chip']
#
#  fire_roasted_tomato
# ['tomato', 'roasted', 'roasted_tomato', 'fire', 'fire_roasted']
#
#  mushroom_oyster
# ['mushroom', 'oyster']
#
#  tomato_sauce
# ['sauce', 'tomato']
#
#  coconut_cream
# ['coconut', 'cream']
#
#  cheese_tortellini
# ['cheese', 'tortellini']
#
#  dried_cherry
# ['cherry']
#
#  coconut_extract
# ['coconut', 'extract']
#
#  white_chocolate_chip
# ['chocolate_chip', 'chocolate', 'white_chocolate', 'chip']
#
#  butter_extract
# ['butter', 'extract']
#
#  golden_delicious_apple
# ['apple', 'delicious_apple']
#
#  chile_paste
# ['chile', 'paste']
#
#  hawaiian_bread_roll
# ['bread', 'roll', 'bread_roll']
#
#  skirt_steak
# ['steak']
#
#  thai_chile_pepper
# ['chile_pepper', 'chile', 'pepper']
#
#  turmeric_root
# ['turmeric', 'root']
#
#  lime_zest
# ['lime', 'zest']
#
#  fish_stock
# ['fish', 'stock']
#
#  rice_vermicelli
# ['rice', 'vermicelli']
#
#  ramen_noodle
# ['ramen', 'noodle']
#
#  pepperoncini_pepper
# ['pepperoncini', 'pepper']
#
#  soba_noodle
# ['soba', 'noodle']
#
#  mascarpone_cheese
# ['mascarpone', 'cheese']
#
#  angel_hair_pasta
# ['pasta', 'angel_hair']
#
#  egg_yolk
# ['egg', 'yolk']
#
#  maple_syrup
# ['syrup', 'maple']
#
#  chicken_tender
# ['chicken', 'tender']
#
#  bone_in_chicken
# ['bone', 'chicken']
#
#  club_soda
# ['soda']
#
#  seasoned_salt
# ['salt', 'seasoned']
#
#  ground_veal
# ['veal']
#
#  vanilla_ice_cream
# ['ice_cream', 'vanilla', 'vanilla_ice', 'cream', 'ice']
#
#  yellow_cake_mix
# ['cake_mix', 'cake', 'mix', 'yellow_cake']
#
#  creamy_salad_dressing
# ['salad_dressing', 'creamy', 'dressing', 'salad']
#
#  farfalle_pasta
# ['pasta', 'farfalle']
#
#  ranch_dressing
# ['ranch', 'dressing']
#
#  dill_pickle
# ['pickle', 'dill']
#
#  cherry_pie_filling
# ['pie_filling', 'cherry', 'filling', 'pie', 'cherry_pie']
#
#  vanilla_pudding_mix
# ['pudding_mix', 'vanilla', 'pudding', 'mix', 'vanilla_pudding']
#
#  beef_sirloin
# ['beef', 'sirloin', 'steak']
#
#  lamb_chop
# ['lamb', 'chop']
#
#  wheat_cereal
# ['wheat', 'cereal']
#
#  mixed_nut
# ['nut']
#
#  cocoa_powder
# ['cocoa', 'powder']
#
#  kidney_bean
# ['bean', 'kidney']
#
#  sesame_oil
# ['oil', 'sesame']
#
#  pork_roast
# ['roast', 'pork']
#
#  brown_rice
# ['rice']
#
#  alfalfa_sprout
# ['alfalfa', 'sprout']
#
#  dandelion_green
# ['dandelion']
#
#  cheesecake_pudding_mix
# ['pudding_mix', 'cheesecake']
#
#  strawberry_ice_cream
# ['ice_cream', 'strawberry', 'ice']
#
#  chocolate_cooky
# ['cooky', 'chocolate']
#
#  white_bean
# ['bean']
#
#  egg_white
# ['egg']
#
#  sugar_based_curing_mixture
# ['sugar', 'curing', 'mixture', 'curing_mixture']
#
#  wood_chip
# ['wood', 'chip']
#
#  vanilla_bean
# ['vanilla', 'bean']
#
#  oat_cereal
# ['cereal', 'oat']
#
#  orange_juice
# ['orange', 'juice']
#
#  merlot_wine
# ['wine', 'merlot']
#
#  orange_liqueur
# ['orange', 'liqueur']
#
#  lemon_pudding_mix
# ['pudding_mix', 'lemon', 'pudding', 'mix', 'lemon_pudding']
#
#  apple_jam
# ['apple']
#
#  yellow_squash
# ['squash']
#
#  zucchini_blossom
# ['blossom', 'zucchini']
#
#  aluminum_foil
# ['foil', 'aluminum']
#
#  great_northern_bean
# ['bean', 'great', 'northern_bean']
#
#  leg_of_lamb
# ['leg', 'lamb']
#
#  ginger_paste
# ['ginger', 'paste']
#
#  kaffir_lime_leaf
# ['lime_leaf', 'kaffir', 'lime', 'leaf', 'kaffir_lime']
#
#  mixed_spice
# ['spice']
#
#  lime_juice
# ['lime', 'juice']
#
#  chili_seasoning
# ['seasoning', 'chili']
#
#  ancho_chile_powder
# ['ancho_chile', 'chile_powder', 'ancho', 'powder']
#
#  buckwheat_flour
# ['buckwheat', 'flour']
#
#  flavored_rum
# ['rum']
#
#  flavored_vodka
# ['vodka']
#
#  citric_acid_powder
# ['citric_acid', 'powder', 'acid']
#
#  green_tomato
# ['tomato']
#
#  almond_flour
# ['almond', 'flour']
#
#  saltine_cracker
# ['cracker', 'saltine']
#
#  nutritional_yeast
# ['yeast']
#
#  mustard_seed
# ['mustard', 'seed']
#
#  garlic_powder
# ['garlic', 'powder']
#
#  havarti_cheese
# ['cheese', 'havarti']
#
#  champagne_vinegar
# ['vinegar']
#
#  semolina_flour
# ['semolina', 'flour']
#
#  candied_mixed_fruit_peel
# ['mixed_fruit', 'peel', 'fruit', 'mixed_fruit_peel', 'fruit_peel']
#
#  candied_cherry
# ['cherry']
#
#  salt_free_seasoning
# ['salt', 'seasoning', 'free_seasoning']
#
#  pita_bread
# ['bread', 'pita']
#
#  lemon_juice
# ['lemon', 'juice']
#
#  cashew_milk
# ['milk']
#
#  grape_jam
# ['grape']
#
#  flank_steak
# ['steak']
#
#  sour_cherry
# ['cherry', 'sour']
#
#  fava_bean
# ['bean', 'fava']
#
#  almond_meal
# ['almond', 'meal']
#
#  strawberry_topping
# ['strawberry', 'topping']
#
#  pimento_pepper
# ['pepper', 'pimento']
#
#  rigatoni_pasta
# ['rigatoni', 'pasta']
#
#  curry_leaf
# ['curry']
#
#  round_steak
# ['round', 'steak']
#
#  asafoetida_powder
# ['asafoetida', 'powder']
#
#  balsamic_vinaigrette_dressing
# ['vinaigrette', 'balsamic_vinaigrette', 'dressing', 'balsamic']
#
#  hot_dog_bun
# ['hot_dog', 'bun']
#
#  frozen_whipped_topping
# ['whipped_topping', 'frozen', 'topping', 'whipped', 'frozen_whipped']
#
#  enoki_mushroom
# ['mushroom']
#
#  dried_mixed_fruit
# ['fruit', 'mixed_fruit']
#
#  peppermint_extract
# ['extract', 'peppermint']
#
#  mixed_salad_green
# ['salad', 'salad_green']
#
#  thousand_island_dressing
# ['dressing', 'thousand_island']
#
#  sweet_pickle_relish
# ['pickle', 'relish', 'pickle_relish', 'sweet_pickle']
#
#  russet_potato
# ['potato']
#
#  chipotle_chile_pepper
# ['chipotle', 'pepper', 'chile', 'chipotle_chile', 'chile_pepper']
#
#  manchego_cheese
# ['cheese']
#
#  anaheim_chile_pepper
# ['chile_pepper', 'chile', 'pepper', 'anaheim']
#
#  milk_chocolate
# ['chocolate', 'milk']
#
#  milk_chocolate_chip
# ['chocolate_chip', 'milk', 'chocolate', 'chip', 'milk_chocolate']
#
#  fennel_seed
# ['fennel', 'seed']
#
#  andouille_sausage
# ['sausage', 'andouille']
#
#  acorn_squash
# ['squash', 'acorn']
#
#  asiago_cheese
# ['cheese']
#
#  italian_cheese_blend
# ['cheese', 'cheese_blend', 'blend']
#
#  vegetarian_crumbles
# ['vegetarian', 'crumbles']
#
#  spanish_onion
# ['onion']
#
#  mango_nectar
# ['mango']
#
#  pomegranate_juice
# ['pomegranate', 'juice']
#
#  english_muffin
# ['muffin']
#
#  halloumi_cheese
# ['cheese', 'halloumi']
#
#  snow_pea
# ['pea']
#
#  pickled_ginger
# ['ginger']
#
#  chia_seed
# ['seed', 'chia']
#
#  beef_tri_tip
# ['beef', 'tri_tip', 'tip', 'tri']
#
#  gravy_mix
# ['gravy', 'mix']
#
#  queso_fresco
# ['queso']
#
#  dried_blueberry
# ['blueberry']
#
#  apricot_jam
# ['apricot', 'jam']
#
#  mixed_fruit
# ['fruit']
#
#  chocolate_ice_cream
# ['ice_cream', 'chocolate', 'ice']
#
#  orange_bell_pepper
# ['bell_pepper', 'pepper', 'orange']
#
#  stewed_tomato
# ['tomato']
#
#  rice_wine
# ['rice', 'wine']
#
#  delicata_squash
# ['squash']
#
#  gummy_candy
# ['gummy', 'candy']
#
#  pork_loin
# ['pork', 'loin']
#
#  greek_seasoning
# ['seasoning']
#
#  dried_mango
# ['mango']
#
#  ciabatta_roll
# ['ciabatta']
#
#  pizza_sauce
# ['sauce', 'pizza']
#
#  condensed_cream_of_celery_soup
# ['celery_soup', 'cream', 'cream_of_celery_soup', 'cream_of_celery', 'celery', 'soup']
#
#  pecorino_cheese
# ['cheese']
#
#  graham_cracker
# ['cracker', 'graham']
#
#  low_fat_milk
# ['milk', 'low', 'fat_milk']
#
#  hatch_chile_pepper
# ['chile', 'pepper', 'chile_pepper']
#
#  chanterelle_mushroom
# ['mushroom', 'chanterelle']
#
#  goat_cheese
# ['cheese', 'goat']
#
#  pearl_onion
# ['onion']
#
#  alfredo_sauce
# ['sauce']
#
#  amaretto_liqueur
# ['amaretto', 'liqueur']
#
#  irish_cream_liqueur
# ['cream', 'cream_liqueur', 'liqueur']
#
#  strawberry_flavored_yogurt
# ['strawberry', 'yogurt', 'strawberry_flavored']
#
#  chicken_sausage
# ['sausage', 'chicken']
#
#  pork_tenderloin
# ['pork', 'tenderloin']
#
#  creme_de_cacao_liqueur
# ['creme_de_cacao', 'creme_de', 'de_cacao', 'liqueur', 'cacao']
#
#  banana_pepper
# ['banana', 'pepper']
#
#  beef_short_rib
# ['short_rib', 'rib', 'beef']
#
#  apple_cider
# ['cider', 'apple']
#
#  cream_corn
# ['cream', 'corn']
#
#  dried_celery
# ['celery']
#
#  brown_rice_syrup
# ['rice_syrup', 'syrup']
#
#  flavored_yogurt
# ['yogurt']
#
#  cranberry_bean
# ['bean']
#
#  chili_powder
# ['chili', 'powder']
#
#  ham_steak
# ['ham']
#
#  crescent_roll
# ['crescent', 'roll']
#
#  focaccia_bread
# ['focaccia', 'bread']
#
#  turkey_bacon
# ['bacon']
#
#  nut_butter
# ['nut', 'butter']
#
#  fruit_juice
# ['juice', 'fruit']
#
#  vanilla_cake_mix
# ['cake_mix', 'vanilla']
#
#  spaghetti_squash
# ['squash', 'spaghetti']
#
#  flavored_syrup
# ['syrup']
#
#  buffalo_wing_sauce
# ['wing_sauce', 'sauce', 'wing', 'buffalo']
#
#  fontina_cheese
# ['fontina', 'cheese']
#
#  greek_salad_dressing
# ['dressing', 'salad_dressing', 'salad']
#
#  apple_juice
# ['juice', 'apple']
#
#  sweet_pickle
# ['pickle']
#
#  barbeque_sauce
# ['sauce', 'barbeque']
#
#  hot_chocolate_mix
# ['chocolate', 'mix', 'hot_chocolate', 'chocolate_mix']
#
#  marsala_wine
# ['wine', 'marsala']
#
#  xanthan_gum
# ['gum']
#
#  malt_vinegar
# ['vinegar']
#
#  puff_pastry
# ['pastry', 'puff']
#
#  raspberry_flavored_syrup
# ['raspberry', 'syrup']
#
#  vegetable_protein
# ['protein', 'vegetable']
#
#  vermicelli_pasta
# ['vermicelli', 'pasta']
#
#  fenugreek_seed
# ['fenugreek', 'seed']
#
#  roasted_garlic
# ['garlic']
#
#  grapeseed_oil
# ['oil']
#
#  muffin_mix
# ['mix']
#
#  white_cake_mix
# ['cake_mix', 'cake', 'mix', 'white_cake']
#
#  slider_bun
# ['bun', 'slider']
#
#  adobo_seasoning
# ['adobo', 'seasoning']
#
#  turkey_giblet
# ['turkey', 'giblet']
#
#  turkey_dripping
# ['dripping', 'turkey']
#
#  ziti_pasta
# ['ziti', 'pasta']
#
#  green_tea
# ['tea']
#
#  dried_orange_peel
# ['orange_peel', 'orange', 'dried_orange']
#
#  strawberry_jam
# ['strawberry', 'jam']
#
#  blue_cheese_dressing
# ['dressing', 'cheese', 'blue_cheese', 'cheese_dressing']
#
#  coleslaw_dressing
# ['dressing', 'coleslaw']
#
#  chicken_drumstick
# ['chicken', 'drumstick']
#
#  orecchiette_pasta
# ['orecchiette', 'pasta']
#
#  string_cheese
# ['string', 'cheese']
#
#  candied_mixed_fruit
# ['fruit']
#
#  neufchatel_cheese
# ['cheese']
#
#  white_chocolate
# ['chocolate']
#
#  poultry_seasoning
# ['seasoning', 'poultry']
#
#  salad_dressing
# ['dressing', 'salad']
#
#  garam_masala
# ['masala']
#
#  cornbread_mix
# ['mix', 'cornbread']
#
#  turkey_breast
# ['turkey', 'breast']
#
#  sweet_pepper
# ['pepper']
#
#  wild_rice
# ['rice']
#
#  raspberry_vinaigrette
# ['raspberry', 'vinaigrette']
#
#  blackberry_jam
# ['jam', 'blackberry']
#
#  cookie_dough
# ['cookie', 'dough']
#
#  smoked_turkey
# ['turkey']
#
#  protein_powder
# ['protein', 'powder']
#
#  orange_drink_mix
# ['orange_drink', 'drink_mix', 'orange', 'mix']
#
#  pineapple_juice
# ['pineapple', 'juice']
#
#  chicken_base
# ['chicken', 'base']
#
#  pickling_salt
# ['salt', 'pickling']
#
#  dr_pepper_soda
# ['soda', 'pepper', 'pepper_soda']
#
#  mandarin_orange
# ['orange', 'mandarin']
#
#  cornish_game_hen
# ['hen', 'game_hen']
#
#  sweet_potato
# ['potato']
#
#  apricot_nectar
# ['apricot']
#
#  butterscotch_chip
# ['butterscotch', 'chip']
#
#  bran_cereal
# ['cereal', 'bran']
#
#  rice_flour
# ['flour', 'rice']
#
#  amaranth_flour
# ['flour']
#
#  lemon_cake_mix
# ['cake_mix', 'lemon', 'mix', 'cake']
#
#  baking_mix
# ['mix', 'baking']
#
#  vanilla_sugar
# ['vanilla', 'sugar']
#
#  sourdough_starter
# ['starter']
#
#  coconut_pudding_mix
# ['pudding_mix', 'coconut', 'pudding', 'mix']
#
#  almond_extract
# ['extract', 'almond']
#
#  rye_flour
# ['rye', 'flour']
#
#  chuck_roast
# ['roast']
#
#  ground_mace
# ['mace']
#
#  coconut_milk
# ['coconut', 'milk']
#
#  walnut_oil
# ['walnut', 'oil']
#
#  soup_mix
# ['soup', 'mix']
#
#  hoagie_roll
# ['roll', 'hoagie']
#
#  mincemeat_pie_filling
# ['mincemeat', 'filling', 'pie_filling', 'pie']
#
#  orange_jam
# ['orange', 'jam']
#
#  candied_citron
# ['citron']
#
#  lemon_flavored_yogurt
# ['lemon', 'yogurt']
#
#  tomato_paste
# ['tomato', 'paste']
#
#  pistachio_pudding_mix
# ['pudding_mix', 'pistachio_pudding', 'mix', 'pudding', 'pistachio']
#
#  sesame_seed
# ['seed', 'sesame']
#
#  poppy_seed
# ['seed', 'poppy']
#
#  pork_sparerib
# ['sparerib', 'pork']
#
#  turkey_kielbasa_sausage
# ['kielbasa', 'turkey_kielbasa', 'sausage', 'turkey']
#
#  soy_flour
# ['flour', 'soy']
#
#  rum_extract
# ['rum', 'extract']
#
#  apple_pie_filling
# ['pie_filling', 'apple', 'filling', 'pie', 'apple_pie']
#
#  devil's_food_cake_mix
# ['cake_mix', 'cake', 'mix', 'food', "devil's_food"]
#
#  lemon_extract
# ['lemon', 'extract']
#
#  baking_powder
# ['powder', 'baking']
#
#  candied_citrus_peel
# ['citrus_peel', 'citrus', 'peel']
#
#  vanilla_cooky
# ['cooky', 'vanilla']
#
#  pina_colada_mix_liqueur
# ['mix', 'pina_colada_mix', 'pina_colada', 'colada_mix', 'liqueur']
#
#  strawberry_cake_mix
# ['cake_mix', 'strawberry', 'cake', 'strawberry_cake']
#
#  candied_pineapple
# ['pineapple']
#
#  gingersnap_cooky
# ['gingersnap', 'cooky']
#
#  butter_cake_mix
# ['cake_mix', 'butter', 'cake', 'mix']
#
#  angel_food_cake_mix
# ['angel_food_cake', 'angel_food', 'food_cake', 'mix', 'cake_mix', 'cake', 'food']
#
#  coffee_liqueur
# ['liqueur', 'coffee']
#
#  corn_syrup
# ['syrup', 'corn']
#
#  maple_extract
# ['maple', 'extract']
#
#  mint_chocolate_chip
# ['mint', 'chocolate', 'chocolate_chip']
#
#  food_coloring
# ['coloring', 'food']
#
#  sweet_chocolate
# ['chocolate']
#
#  brazil_nut
# ['nut']
#
#  angel_food_cake
# ['cake', 'angel_food', 'food']
#
#  cake_mix
# ['cake', 'mix']
#
#  orange_extract
# ['extract', 'orange']
#
#  pie_filling
# ['filling', 'pie']
#
#  garlic_salt
# ['salt', 'garlic']
#
#  banana_pudding_mix
# ['pudding_mix', 'banana', 'pudding', 'mix']
#
#  potato_chip
# ['chip', 'potato']
#
#  candied_orange_peel
# ['orange_peel', 'orange', 'peel']
#
#  red_currant_jam
# ['currant', 'red_currant']
#
#  cherry_liqueur
# ['cherry', 'liqueur']
#
#  soy_milk
# ['milk', 'soy']
#
#  hazelnut_liqueur
# ['hazelnut', 'liqueur']
#
#  condensed_cheddar_cheese_soup
# ['cheese', 'soup', 'cheese_soup', 'cheddar_cheese_soup', 'cheddar_cheese']
#
#  pastry_flour
# ['flour', 'pastry']
#
#  linguica_sausage
# ['sausage', 'linguica']
#
#  cream_of_tartar
# ['cream', 'tartar']
#
#  decorating_gel
# ['gel', 'decorating']
#
#  brownie_mix
# ['brownie', 'mix']
#
#  citrus_soda
# ['soda', 'citrus']
#
#  beef_liver
# ['liver', 'beef']
#
#  spice_cake_mix
# ['cake_mix', 'spice', 'spice_cake', 'mix']
#
#  honeydew_melon
# ['honeydew', 'melon']
#
#  dried_beef
# ['beef']
#
#  onion_powder
# ['onion', 'powder']
#
#  russian_salad_dressing
# ['dressing', 'salad_dressing']
#
#  chicken_leg
# ['chicken', 'leg']
#
#  skinless_boneless_chicken
# ['chicken']
#
#  cornflakes_cereal
# ['cornflakes', 'cereal']
#
#  vegetable_soup
# ['soup', 'vegetable']
#
#  polish_sausage
# ['sausage']
#
#  irish_whiskey
# ['whiskey']
#
#  sugar_snap_pea
# ['pea', 'snap_pea', 'sugar']
#
#  cream_of_chicken_soup
# ['chicken', 'soup', 'chicken_soup', 'cream_of_chicken', 'cream']
#
#  carob_powder
# ['carob', 'powder']
#
#  cream_of_broccoli_soup
# ['broccoli', 'soup', 'cream', 'broccoli_soup']
#
#  catalina_salad_dressing
# ['dressing', 'salad_dressing', 'salad']
#
#  cinnamon_sugar
# ['cinnamon', 'sugar']
#
#  orange_soda
# ['orange', 'soda']
#
#  cheese_sauce
# ['cheese', 'sauce']
#
#  raspberry_vinegar
# ['vinegar', 'raspberry']
#
#  beef_dripping
# ['beef', 'dripping']
#
#  macadamia_nut
# ['nut', 'macadamia']
#
#  pine_nut
# ['nut', 'pine']
#
#  cream_of_potato_soup
# ['potato_soup', 'cream', 'potato', 'soup']
#
#  confectioners'_coating
# ['coating', "confectioners'"]
#
#  candy_cane
# ['candy']
#
#  pound_cake
# ['cake']
#
#  beau_monde_seasoning
# ['seasoning']
#
#  cinnamon_candy
# ['candy', 'cinnamon']
#
#  raspberry_liqueur
# ['liqueur', 'raspberry']
#
#  peanut_butter
# ['peanut', 'butter']
#
#  oat_flour
# ['oat', 'flour']
#
#  anise_seed
# ['anise', 'seed']
#
#  sorghum_flour
# ['sorghum', 'flour']
#
#  raisin_bread
# ['bread', 'raisin']
#
#  phyllo_dough
# ['phyllo', 'dough']
#
#  barley_cereal
# ['cereal', 'barley']
#
#  cookie_mix
# ['cookie', 'mix']
#
#  swai_fish
# ['swai', 'fish']
#
#  maraschino_cherry_juice
# ['cherry_juice', 'maraschino_cherry']
#
#  mexican_style_corn
# ['corn', 'style_corn', 'style']
#
#  apple_pie_spice
# ['apple', 'pie', 'spice', 'apple_pie']
#
#  wheat_bran
# ['bran', 'wheat']
#
#  black_walnut
# ['walnut']
#
#  lemon_pepper
# ['lemon', 'pepper']
#
#  chocolate_drink_mix
# ['chocolate_drink', 'mix', 'chocolate', 'drink_mix']
#
#  cranberry_sauce
# ['cranberry', 'sauce']
#
#  steak_seasoning
# ['seasoning', 'steak']
#
#  vanilla_chip
# ['vanilla']
#
#  corn_cereal
# ['cereal', 'corn']
#
#  creme_de_menthe_liqueur
# ['creme_de_menthe', 'creme_de', 'de_menthe', 'liqueur']
#
#  beef_base
# ['beef', 'base']
#
#  pancake_mix
# ['mix', 'pancake']
#
#  yellow_corn
# ['corn']
#
#  animal_fat
# ['fat']
#
#  udon_noodle
# ['noodle', 'udon']
#
#  tomato_juice
# ['tomato', 'juice']
#
#  tri_color_pasta
# ['pasta', 'tri', 'color_pasta']
#
#  pasta_shell
# ['pasta', 'shell']
#
#  blueberry_pie_filling
# ['blueberry', 'pie', 'pie_filling', 'filling']
#
#  pumpernickel_bread
# ['bread', 'pumpernickel']
#
#  ice_cream
# ['ice', 'cream']
#
#  jarlsberg_cheese
# ['cheese']
#
#  potato_nugget
# ['potato']
#
#  grapefruit_juice
# ['grapefruit', 'juice']
#
#  banana_liqueur
# ['banana', 'liqueur']
#
#  condensed_cream_of_shrimp_soup
# ['cream_of_shrimp_soup', 'cream_of_shrimp', 'shrimp_soup', 'shrimp', 'soup', 'cream']
#
#  red_snapper
# ['snapper']
#
#  anise_liqueur
# ['anise', 'liqueur']
#
#  file_powder
# ['file', 'powder']
#
#  habanero_pepper
# ['pepper', 'habanero']
#
#  onion_salt
# ['onion', 'salt']
#
#  lima_bean
# ['bean', 'lima']
#
#  ground_bison
# ['bison']
#
#  vegetable_juice
# ['vegetable', 'juice']
#
#  barbeque_seasoning
# ['barbeque', 'seasoning']
#
#  corned_beef
# ['beef']
#
#  lamb_shank
# ['lamb', 'shank']
#
#  pizza_crust
# ['pizza', 'crust']
#
#  pork_neck_bone
# ['bone', 'pork', 'neck_bone', 'pork_neck']
#
#  red_apple
# ['apple']
#
#  sloppy_joe_sauce
# ['sloppy_joe', 'sauce', 'sloppy']
#
#  tomato_puree
# ['tomato', 'puree']
#
#  onion_soup
# ['onion', 'soup']
#
#  ranch_style_bean
# ['style_bean', 'bean', 'ranch', 'style']
#
#  pumpkin_pie_filling
# ['pumpkin_pie', 'filling', 'pumpkin', 'pie', 'pie_filling']
#
#  blue_cheese
# ['cheese']
#
#  spaghetti_sauce
# ['sauce', 'spaghetti']
#
#  turkey_carcass
# ['turkey', 'carcass']
#
#  bone_in_ham
# ['ham', 'bone']
#
#  tarragon_vinegar
# ['vinegar', 'tarragon']
#
#  turkey_stock
# ['turkey']
#
#  marinara_sauce
# ['sauce']
#
#  hash_brown
# ['hash']
#
#  water_chestnut
# ['water', 'chestnut']
#
#  cream_of_mushroom_soup
# ['mushroom_soup', 'mushroom', 'soup', 'cream']
#
#  sunflower_seed
# ['seed', 'sunflower']
#
#  safflower_oil
# ['oil']
#
#  wax_bean
# ['bean']
#
#  beef_consomme
# ['consomme', 'beef']
#
#  salad_seasoning
# ['salad', 'seasoning']
#
#  bean_sprout
# ['sprout', 'bean']
#
#  poppy_seed_dressing
# ['dressing', 'poppy', 'seed']
#
#  acinus_di_pepe_pasta
# ['di', 'pasta', 'acinus', 'pepe', 'pepe_pasta', 'acinus_di_pepe', 'acinus_di', 'di_pepe']
#
#  luncheon_meat
# ['meat']
#
#  coconut_oil
# ['coconut', 'oil']
#
#  bottom_round_roast
# ['roast', 'bottom', 'round']
#
#  whipped_cream
# ['whipped', 'cream']
#
#  porcini_mushroom
# ['mushroom', 'porcini']
#
#  peach_jam
# ['peach']
#
#  collard_green
# ['collard']
#
#  browning_sauce
# ['sauce', 'browning']
#
#  sweet_vermouth
# ['vermouth']
#
#  sweet_pea
# ['pea']
#
#  beef_shank
# ['beef']
#
#  scotch_whiskey
# ['whiskey', 'scotch']
#
#  corn_chip
# ['chip', 'corn']
#
#  vanilla_flavored_syrup
# ['vanilla', 'syrup']
#
#  pudding_mix
# ['mix', 'pudding']
#
#  salt_pork
# ['salt', 'pork']
#
#  raspberry_juice
# ['raspberry', 'juice']
#
#  beef_gravy
# ['beef', 'gravy']
#
#  candied_pecan
# ['pecan']
#
#  rib_roast
# ['roast', 'rib']
#
#  drink_mix
# ['drink', 'mix']
#
#  pork_rib
# ['pork', 'rib']
#
#  taco_sauce
# ['sauce', 'taco']
#
#  red_bean
# ['bean']
#
#  rack_of_lamb
# ['lamb', 'rack']
#
#  limoncello_liqueur
# ['limoncello', 'liqueur']
#
#  mung_bean
# ['bean']
#
#  ham_hock
# ['ham', 'hock']
#
#  southern_comfort_liqueur
# ['liqueur']
#
#  pigeon_pea
# ['pea']
#
#  sweet_and_sour_mix
# ['sour_mix', 'sweet_and_sour', 'mix', 'sour']
#
#  baby_corn
# ['corn']
#
#  fruit_roll
# ['fruit', 'roll']
#
#  dried_apple
# ['apple']
#
#  white_chocolate_pudding_mix
# ['pudding_mix', 'chocolate', 'pudding', 'mix', 'white_chocolate_pudding', 'white_chocolate', 'chocolate_pudding']
#
#  cube_steak
# ['steak']
#
#  picante_sauce
# ['sauce']
#
#  steak_sauce
# ['sauce', 'steak']
#
#  blood_orange
# ['orange']
#
#  coconut_water
# ['coconut', 'water']
#
#  scotch_bonnet_chile_pepper
# ['pepper', 'scotch_bonnet', 'chile_pepper', 'bonnet_chile_pepper', 'bonnet_chile', 'scotch_bonnet_chile', 'bonnet']
#
#  roast_beef
# ['beef', 'roast']
#
#  grape_juice
# ['juice', 'grape']
#
#  jagermeister_liqueur
# ['liqueur', 'jagermeister']
#
#  rump_roast
# ['roast']
#
#  corn_flour
# ['corn', 'flour']
#
#  bamboo_shoot
# ['bamboo']
#
#  roquefort_cheese
# ['cheese']
#
#  star_anise
# ['anise']
#
#  bread_dough
# ['dough', 'bread']
#
#  anise_extract
# ['anise']
#
#  grape_leaf
# ['grape', 'leaf']
#
#  mesquite_seasoning
# ['mesquite', 'seasoning']
#
#  maple_sugar
# ['sugar', 'maple']
#
#  fiddlehead_fern
# ['fiddlehead']
#
#  mixed_baby_green
# ['baby_green']
#
#  meat_tenderizer
# ['meat', 'tenderizer']
#
#  liquid_smoke
# ['smoke', 'liquid']
#
#  celery_seed
# ['seed']
#
#  kaiser_roll
# ['roll', 'kaiser']
#
#  cherry_juice
# ['cherry', 'juice']
#
#  hot_dog
# ['dog']
#
#  lumpia_wrapper
# ['lumpia', 'wrapper']
#
#  cinnamon_chip
# ['chip', 'cinnamon']
#
#  ice_cream_cone
# ['cone', 'cream']
#
#  turkey_leg
# ['turkey']
#
#  masa_harina
# ['masa']
#
#  potato_starch
# ['potato', 'starch']
#
#  hollandaise_sauce
# ['sauce', 'hollandaise']
#
#  fat_free_milk
# ['milk', 'fat']
#
#  pulled_pork
# ['pork']
#
#  absinthe_liqueur
# ['liqueur', 'absinthe']
#
#  wheat_berry
# ['berry', 'wheat']
#
#  fajita_seasoning
# ['seasoning', 'fajita']
#
#  cassava_flour
# ['flour']
#
#  parchment_paper
# ['paper', 'parchment']
#
#  mustard_green
# ['mustard']
#
#  jerk_seasoning
# ['seasoning']
#
#  cinnamon_roll
# ['roll', 'cinnamon']
#
#  garlic_paste
# ['garlic', 'paste']
#
#  jelly_bean
# ['jelly', 'bean']
#
#  sea_bass
# ['bass']
#
#  peppermint_oil
# ['oil']
#
#  tangerine_juice
# ['juice', 'tangerine']
#
#  ham_bone
# ['bone']
#
#  mozzarella_ball
# ['mozzarella', 'ball']
#
#  cedar_plank
# ['plank']
#
#  fish_sauce
# ['sauce']
#
#  burrata_cheese
# ['cheese', 'burrata']
#
#  cheese_curd
# ['cheese']
#
#  turkey_broth
# ['turkey', 'broth']
#
#  melon_liqueur
# ['melon', 'liqueur']
#
#  celery_root
# ['celery', 'root']
#
#  oyster_sauce
# ['sauce']
#
#  garlic_scape
# ['scape', 'garlic']
#
#  seasoned_pepper
# ['seasoned', 'pepper']
#
#  coconut_flour
# ['coconut', 'flour']
#
#  strawberry_extract
# ['extract']
#
#  wheat_germ
# ['wheat']
#
#  duck_fat
# ['duck', 'fat']
#
#  kitchen_twine
# ['twine']
#
#  celery_salt
# ['celery', 'salt']
#
#  sparkling_wine
# ['wine']
#
#  dill_seed
# ['dill']
#
#  teff_flour
# ['teff', 'flour']
#
#  truffle_oil
# ['truffle', 'oil']
#
#  almond_butter
# ['butter']
#
#  cocktail_sauce
# ['cocktail', 'sauce']
#
#  quinoa_flour
# ['quinoa', 'flour']
#
#  pork_belly
# ['pork']
#
#  shrimp_paste
# ['paste', 'shrimp']
#
#  bok_choy
# ['choy']
#
#  tamarind_paste
# ['tamarind', 'paste']
#
#  rice_milk
# ['milk']
#
#  coconut_butter
# ['butter']
#
#  raspberry_extract
# ['raspberry']
#
#  whipped_topping
# ['topping']
#
#  creme_fraiche
# ['fraiche']
#
#  crabmeat
# ['crab']
#
#  espresso
# ['coffee_bean']

# %%
import csv

with open('/Users/nessyliu/Desktop/RA/part_2/result/dict_ingre_shortforms.csv', 'w') as f:
    for key in dict_ingre_shortforms.keys():
        f.write("%s,%s\n"%(key,dict_ingre_shortforms[key]))

# %%
# test on a subset of data
df = df.head(1000)

# %%
# Combine each review with its direction
recipe_id_list = df.recipe_id.tolist()
review_id_list = df.review_id.tolist()
review_list = df.review_text.tolist()

comb_dir_review_list = []
for recipe_id, review  in zip(recipe_id_list, review_list):
    direction = dict_recipe_direction[recipe_id]
    combined_text = direction + ' ' + review
    comb_dir_review_list.append(combined_text)

# %%
import spacy
import neuralcoref

text = comb_dir_review_list[300]
print(text)

nlp = spacy.load('en')
neuralcoref.add_to_pipe(nlp, greedyness=0.4, max_dist = 100, 
                        conv_dict={'paprika': ['ingredient']})
doc = nlp(text)
for cluster in doc._.coref_clusters:
    print('')
    print(cluster)
    
    
test_sentence = 'My sister has a dog. She loves him.'
test_doc = nlp(test_sentence)
print(test_doc._.coref_clusters)
# Out:
# In a shallow bowl, mix 1 1/2 cup of flour, paprika, and garlic powder. In a second shallow bowl, whisk together the eggs and milk until thoroughly blended. In a third bowl, combine the crushed cracker crumbs, potato flakes, and 1/2 cup of flour. With a fork, prick the pork chops thoroughly to tenderize the meat. Season the chops with salt and pepper. Gently press the pork chops into the flour to coat, and shake off the excess flour. Dip into the beaten egg mixture, then press each chop into the cracker crumb mixture. Gently toss between your hands so any crumbs that haven't stuck can fall away Heat the oil in a large, deep skillet over medium heat, and gently place the pork chops into the hot oil. Fry the chops until the meat is no longer pink in the center and the crust is crisp and golden brown, about 5 minutes per side. Remove the chops from the pan, and drain the excess oil on paper towels. Easy and delicious. Great with country gravy and mashed potatoes.
#
# the pork: [the pork, the pork]
#
# the pork chops: [the pork chops, the chops]
# [My sister: [My sister, She], a dog: [a dog, him]]
