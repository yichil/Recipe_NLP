# %%
import re
import pandas as pd
import nltk
import unicodedata
import csv
import itertools
from tqdm import trange

# %%
# lemmatization dict
lemma_list = pd.read_csv('/Users/nessyliu/Desktop/RA/lemma_list.csv')
lemma_dict = lemma_list.set_index('word_list').to_dict()['lemma_list']

# Read in the datasets
df = pd.read_csv('/Users/nessyliu/Desktop/RA/AllReviews_26thNov2019.csv')
df_ingredients_raw = pd.read_csv('/Users/nessyliu/Desktop/RA/part_2/Ingredients.csv')
df_cluster = pd.read_excel('/Users/nessyliu/Desktop/RA/part_2/Cluster_names.xlsx')

# %%
df = df.head(30000)

# %%
cluster_name_orig_list = df_cluster.cluster_name.tolist() # list of cluster names with spaces, e.g. apple juice

# create dict to map recipe_id to ingredient_ids
df_ingredients = df_ingredients_raw.groupby('recipe_id')['ingredient_id'].apply(list).reset_index(name ='ingredients')
dict_recipe_ingredients = dict(zip(df_ingredients.recipe_id, df_ingredients.ingredients))

# create dict to map ingredient_id to cluster_name
df_cluster = df_cluster.replace(' ', '_', regex=True)
dict_ingredient_clustername = dict(zip(df_cluster.ingredient_id, df_cluster.cluster_name))

# list of cluster names with underscore, e.g. apple_juice, so that when check 'apple', won't confuse with 'apple juice'
cluster_name_list = df_cluster.cluster_name.tolist() 

recipe_id_list = df.recipe_id.tolist()
review_list = df.review_text.tolist()

# %%
# Map for expanding contractions in case of negations
CONTRACTION_MAP = {
    "ain't": "is not",
    "aren't": "are not",
    "can't": "can not",
    "cannot": "can not",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hasn't": "has not",
    "haven't": "have not",
    "isn't": "is not",
    "mayn't": "may not",
    "mightn't": "might not",
    "mustn't": "must not",
    "needn't": "need not",
    "shan't": "shall not",
    "sha'n't": "shall not",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "wasn't": "was not",
    "weren't": "were not",
    "won't": "will not",
    "wouldn't": "would not",
}

contain_ingre_flag_list = []
addition_flag_list = []
deletion_flag_list = []
replacement_flag_list = []

ingre_in_recipe_list = []
ingre_not_recipe_list = []
ngram_in_list = []
ngram_not_list = []
recipe_list = []

addition_list = []
deletion_list = []
replacement_list = []

clean_text_list = []

# %%
def deal_with_ingredient(text, recipe):
    # tokenize the review text
    sentences = nltk.sent_tokenize(text)
    tokens_sentences = [nltk.word_tokenize(sent) for sent in sentences]
    tokens = list(itertools.chain.from_iterable(tokens_sentences))
    flag = False
    
    # detect ingredients and get ngrams
    ingre_in_recipe = []
    ingre_not_recipe = []
    ngram_in = []
    ngram_not = []
    ngrams = list(nltk.everygrams(tokens, 4, 4))
    ngrams = [list(ngram) for ngram in ngrams] 
    detected_ingredients = [token for token in tokens if token in cluster_name_list] 
    if len(detected_ingredients) > 0:
        flag = True
    for ingre in detected_ingredients:
        if ingre in recipe:
            ingre_in_recipe.append(ingre)
            ngram_in.append([ngram for ngram in ngrams if ingre in ngram])
        else:
            ingre_not_recipe.append(ingre)
            ngram_not.append([ngram for ngram in ngrams if ingre in ngram])
    
    return flag, ingre_in_recipe, ingre_not_recipe, ngram_in, ngram_not

# %%
def text_processing(df):
    """
    text processing
    """
    for i in trange(0,len(df)):
    #for i in range(0,len(df)):
        
        recipe_id = df.iloc[i]['recipe_id']
        try:
            recipe = [dict_ingredient_clustername[ingre_id] for ingre_id in dict_recipe_ingredients[recipe_id]]
        except:
            recipe = [] # if the recipe id is not in the recipe_ingredient map list
        
        text = df.iloc[i]['review_text']
        
        # Convert to lower case
        text = text.lower()

        # Normalize the accented characters
        text = normalize_accented_characters(text)

        # Expand contractions, e.g. didn't --> did not
        text = expand_contractions(text, CONTRACTION_MAP)
        
        # Lemmatize the text, e.g. removed --> remove
        text = lemmatization(text)

        # Concatenate ingredient phrases in the reviews (which appear in the cluster name list)
        text = concat_phrase(text)
        
        clean_text_list.append(text)

        
        # check whether review contain ingredient words in cluster name list, 
        # get the ingredients in the recipe and the ingredients not in the recipe
        # also get the ngrams containing the detected ingredient words
        flag, ingre_in_recipe, ingre_not_recipe, ngram_in, ngram_not = deal_with_ingredient(text, recipe)
        contain_ingre_flag_list.append(flag)
        ingre_in_recipe_list.append(ingre_in_recipe)
        ingre_not_recipe_list.append(ingre_not_recipe)
        ngram_in_list.append(ngram_in)
        ngram_not_list.append(ngram_not)
        
        recipe_list.append(recipe)
        
        
        # Extract terms indicating altering
        addition_terms = addition_extraction(text)
        deletion_terms = deletion_extraction(text)
        replacement_terms = replacement_extraction(text)
        
        if len(addition_terms) > 0:
            addition_flag_list.append(True)
        else:
            addition_flag_list.append(False)

        if len(deletion_terms) > 0:
            deletion_flag_list.append(True)
        else:
            deletion_flag_list.append(False)
            
        if len(replacement_terms) > 0:
            replacement_flag_list.append(True)
        else:
            replacement_flag_list.append(False)
        
        replacement_list.append(replacement_terms)
        addition_list.append(addition_terms)
        deletion_list.append(deletion_terms)



def concat_phrase(text):
    # concatenate the ingredient phrases in the cluster name list
    for cluster in cluster_name_orig_list:
        text = re.sub(r'\b' + cluster + r'\b', cluster.replace(' ', '_'), text)
    
    # concatenate some important phrases for the ease of detection
    text = re.sub(r'\binstead of\b', 'instead_of', text)
    text = re.sub(r'\bleave out\b', 'leave_out', text)
    text = re.sub(r'\bleave off\b', 'leave_off', text)
    text = re.sub(r'\bbother with\b', 'bother_with', text)
    return text


def normalize_accented_characters(text):
    """
    In case of Unicode characters
    """
    # text = unicodedata.normalize('NFKD', text)
    text = unicodedata.normalize('NFC', text)
    text = text.replace("“", '"').replace("”", '"').replace("’", "'").replace("‘", "'").replace('–', '-')
    text = re.sub('ı', 'I', text)
    return text


def expand_contractions(text, contraction_mapping):
    """
    Expand contractions in case of negations, e.g. isn’t -> is not
    """
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
                                      flags=re.IGNORECASE | re.DOTALL)

    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match) \
            if contraction_mapping.get(match) \
            else contraction_mapping.get(match.lower())
        expanded_contraction = first_char + expanded_contraction[1:]
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text


def lemmatization(text_before):
    """
    Lemmatize the text
    """
    text_before = text_before.lower()
    text_after = " ".join(str(lemma_dict.get(word, word)) for word in text_before.split())
    return text_after


def replacement_extraction(text):
    """
    extract Replacement terms
    """
    sentences = nltk.sent_tokenize(text)
    tokens_sentences = [nltk.word_tokenize(sent) for sent in sentences]
    tagged_sentences = [tagger.tag(sent) for sent in tokens_sentences]
    DESC_list = []
    for sent_tagged in tagged_sentences:  # each sentence
        sent_tree = key_phrases_cp.parse(sent_tagged)  # chunk each sentence based on grammar structure
        DESC_in_this_sent = []
        for subtree in sent_tree.subtrees():
            if subtree.label() == "REPLACEMENT_TERM":
                string = str(subtree)
                string = re.sub('\n', '', string)
                string = re.sub('\s+', ' ', string)
                string = re.sub('REPLACEMENT_TERM ', '', string)
                string = re.sub('\/[A-Z]+\$*', '', string)
                string = re.sub('\(', '', string)
                string = re.sub('\)', '', string)

                DESC_in_this_sent.append(string)
        if DESC_in_this_sent != []:
            DESC_list.extend(DESC_in_this_sent)
    DESC_list = list(set(DESC_list))
    return DESC_list


def addition_extraction(text):
    """
    extract Addition terms
    """
    sentences = nltk.sent_tokenize(text)
    tokens_sentences = [nltk.word_tokenize(sent) for sent in sentences]
    tagged_sentences = [tagger.tag(sent) for sent in tokens_sentences]
    DESC_list = []
    for sent_tagged in tagged_sentences:  # each sentence
        sent_tree = key_phrases_cp.parse(sent_tagged)  # chunk each sentence based on grammar structure
        DESC_in_this_sent = []
        for subtree in sent_tree.subtrees():
            if subtree.label() == "ADDITION_TERM":
                string = str(subtree)
                string = re.sub('\n', '', string)
                string = re.sub('\s+', ' ', string)
                string = re.sub('ADDITION_TERM ', '', string)
                string = re.sub('\/[A-Z]+\$*', '', string)
                string = re.sub('\(', '', string)
                string = re.sub('\)', '', string)

                DESC_in_this_sent.append(string)
        if DESC_in_this_sent != []:
            DESC_list.extend(DESC_in_this_sent)
    DESC_list = list(set(DESC_list))
    return DESC_list


def deletion_extraction(text):
    """
    extract Deletion terms
    """
    sentences = nltk.sent_tokenize(text)
    tokens_sentences = [nltk.word_tokenize(sent) for sent in sentences]
    tagged_sentences = [tagger.tag(sent) for sent in tokens_sentences]
    DESC_list = []
    for sent_tagged in tagged_sentences:  # each sentence
        sent_tree = key_phrases_cp.parse(sent_tagged)  # chunk each sentence based on grammar structure
        DESC_in_this_sent = []
        for subtree in sent_tree.subtrees():
            if subtree.label() == "DELETION_TERM":
                string = str(subtree)
                string = re.sub('\n', '', string)
                string = re.sub('\s+', ' ', string)
                string = re.sub('DELETION_TERM ', '', string)
                string = re.sub('\/[A-Z]+\$*', '', string)
                string = re.sub('\(', '', string)
                string = re.sub('\)', '', string)

                DESC_in_this_sent.append(string)
        if DESC_in_this_sent != []:
            DESC_list.extend(DESC_in_this_sent)
    DESC_list = list(set(DESC_list))
    return DESC_list



# Custom our own tagger for POS tagging, and use python's default tagger as backup
custom_tagger = {
    'replace': 'REPLACEMENT', 'substitute': 'REPLACEMENT', 'instead_of': 'REPLACEMENT',
    'delete': 'DELETION', 'remove': 'DELETION', 'omit': 'DELETION', 'subtract': 'DELETION',
    'leave_out': 'DELETION', 'leave_off': 'DELETION',
    'add': 'ADDITION',
    'bother_with': 'BOTHERWITH',
    'no': 'NO',
    'not': 'NOT',
    'that': 'DT',
    'with': 'IN',
    'even': 'EVEN'}

ingredient_tagger = {}
for ingre in cluster_name_list:
    ingredient_tagger[ingre] = 'INGREDIENT'
    
custom_tagger_combined = {**custom_tagger, **ingredient_tagger}

default_tagger = nltk.data.load("/Users/nessyliu/nltk_data/taggers/maxent_treebank_pos_tagger/english.pickle")
tagger = nltk.tag.UnigramTagger(model=custom_tagger_combined, backoff=default_tagger)

# Define grammar structures for extracting negation phrases and then creativity words
key_phrases_grammar = r"""
    DELETION_TERM:
        # Extract "not have + ingredient"
        # e.g. "I didn't have any Beef"
        {<NOT><HAVE><DT>?<RB>?<INGREDIENT>}
        
        # Extract "have no + ingredient"
        # e.g. "I had no Beef"
        {<HAVE><NO><INGREDIENT>}
        
        # Extract "deletion + ingredient"
        # e.g. "I removed Apple", "I deleted the Beef", "I left off the Beef"
        {<DELETION><[A-Z]*>*<INGREDIENT>}
        
        # Extract negation terms with "bother with"
        # e.g. "I didn't bother with the Beef"
        {<NOT><BOTHERWITH><[A-Z]*>*<INGREDIENT>}
        
    REPLACEMENT_TERM:
        # e.g. replace the Apple with some Banana
        {<REPLACEMENT><[A-Z]*>*<INGREDIENT><IN><DT>?<[A-Z]*>*<INGREDIENT>}
        
        # e.g. didn't use Apple, replace with Banana
        {<INGREDIENT><[A-Z]*>*<REPLACEMENT><IN><[A-Z]*>*<INGREDIENT>}
    
    ADDITION_TERM:
        # e.g. I added some Milk
        {<ADDITION><[A-Z]*>*<INGREDIENT>}
"""
key_phrases_cp = nltk.RegexpParser(key_phrases_grammar)

# %%
text = "I didn't have the celery so replace with a shredded carrot which broke down."
replacement_extraction(text)
# Out:
# ['celery so replace with a shredded carrot']

# %%
text_processing(df)
# Out:
# 100%|██████████| 30000/30000 [59:33<00:00,  8.40it/s]

# %%
result_df = pd.DataFrame({
    'recipe_id': recipe_id_list,
    'review_text': review_list,
    'clean_text': clean_text_list,
    'recipe': recipe_list,
    'flag': contain_ingre_flag_list,
    'ingre_in_recipe': ingre_in_recipe_list,
    'ingre_not_recipe': ingre_not_recipe_list,
    'ngram_in': ngram_in_list,
    'ngram_not': ngram_not_list,
    'addition_flag': addition_flag_list,
    'deletion_flag': deletion_flag_list,
    'replacement_flag': replacement_flag_list,
    'addition_terms': addition_list,
    'deletion_terms': deletion_list,
    'replacement_terms': replacement_list
})


result_df.to_csv('/Users/nessyliu/Desktop/RA/part_2/result_df.csv')

review_with_ingre_df = result_df.loc[result_df['flag'] == True]
review_with_ingre_df.to_csv('/Users/nessyliu/Desktop/RA/part_2/review_with_ingre_df.csv')

# %%
print(len(review_with_ingre_df))
print(len(result_df))
# Out:
# 18262
# 30000

# %%
list(itertools.chain.from_iterable(replacement_list))
# Out:
# ['substitute lime for lemon_juice',
#  'replace brandy for gin',
#  'substitute vodka for the gin',
#  'instead_of seasoning with salt and pepper i seasoned with italian_bread',
#  'substitute the water with a nice dark belgian beer',
#  'substitute chicken_liver for beef_liver',
#  'substitute balsamic_vinegar for the red_wine because i is out i also used regular cream_of_mushroom_soup',
#  'instead_of spinach as well as parmigiana cheese',
#  'instead_of the brown_sugar in the egg',
#  'replace the fish seasoning with kosher_salt',
#  'replace the sour_cream with nonfat plain greek_yogurt',
#  'substitute chipotle_pepper for the ancho_chile_pepper',
#  'substitute beef_broth for the water',
#  'substitute red_wine vinegar for the white_vinegar but that is simply a matter of curiosity and not a complaint against the white_vinegar',
#  'substitute chicken for the beef and add a little more seasoning',
#  'substitute some pumpkin_puree for some of the mashed banana',
#  'substitute the rosemary with thyme',
#  'replace paprika with chili_powder',
#  'instead_of fish_stock as i do not have the fish_stock',
#  'sugar substitute for the brown_sugar',
#  'substitute soy_milk for the milk and canadian maple_syrup for the brown_sugar',
#  'substitute half the honey for some smooth almond_butter to reduce the sugar',
#  'substitute worsheschire sauce for the soy_sauce',
#  'substitute a cup of beer for the water',
#  'instead_of bbq sauce added a jar of beef_gravy with about 1/2 can of water',
#  'replace the water with beer',
#  'replace water with beer',
#  'substitute garlic_powder for onion_powder',
#  'substitute ground_turkey for the beef & added a packet of onion_soup',
#  'substitute ground_turkey for the beef',
#  'substitute beer for the water',
#  'substitute some sesame_oil for part of the butter',
#  'replace butter with olive_oil',
#  'substitute the water with either beef or chicken_broth depending on what we are serving it with and it the best rice',
#  'substitute venison for beef',
#  'substitute substitute 1t grey poupon mustard for the mustard_seed',
#  'instead_of salt and dijon_mustard because i do not have mustard',
#  'instead_of flour for thickener- it do not clump and give the sauce',
#  'instead_of shortening as i rarely have shortening',
#  'ginger so substitute out of necessity orientali blend spices with ginger and broccoli',
#  'substitute beef_stew_meat for oxtail and added celery',
#  'substitute the butter for olive_oil',
#  'replace ground_beef with lean ground_turkey',
#  'instead_of beef because i do not have beef_broth',
#  'replace the ground_beef with steak',
#  'replace the flour with 2 tbs of corn starch and eliminated the extra water',
#  'instead_of beef round_steak because i have a lot of veal',
#  'substitute beef_broth for the wine',
#  'substitute it with fresh mushroom & cut the sour_cream in half & added cream_cheese',
#  'replace the water with beef_broth',
#  'substitute fresh mushrooms for canned and dried_parsley for fresh as it is new year day and i do not have any fresh parsley',
#  'substitute more wine for water',
#  'instead_of an onion i just put in a sprinkle of onion',
#  'substitute 1/2 c. red_wine for the 1/4 c. water',
#  'substitute the white_wine with apple_cider vinegar',
#  'substitute johnsonville sausage in for the beef',
#  'substitute half cream/half water for the wine',
#  'instead_of a boullion cube i used a little beef_stock with no salt',
#  'substitute white grape_juice for the wine',
#  'substitute water for the wine and added fresh sliced white mushrooms with the sour_cream',
#  'replace flour with corn',
#  'substitute sour_cream for cream_cheese',
#  'instead_of water w/cream soup and red_wine with flour',
#  'substitute red_wine vinegar for the marinade',
#  'substitute white_wine for the called-for red in the marinade',
#  'substitute chicken_stock for beef_stock and white_wine vinegar for red_wine',
#  'substitute dijon_mustard for the prepared mustard',
#  'substitute beef_broth & use half the amount of salt in the marinade',
#  'substitute ghee for the butter',
#  'instead_of red_wine i used cognac however i do not try marinating the beef in it i just added to the sauce',
#  'replace the wine with diluted au joir sauce and add 3 tbsp cream_cheese with the sour_cream',
#  'substitute mexican_crema for the sour_cream',
#  'substitute beef_broth with mushroom',
#  'sour_cream and a bit extra to substitute for the deletion of the cream_cheese',
#  'substitute neufschatel cheese for cream_cheese',
#  'substitute sliced celery for shallots as wife can not have onion',
#  'substitute greek_yogurt for sour_cream',
#  'substitute cooking sherry for the white_wine',
#  'instead_of chuck and i added some worcestershire_sauce as well as the salt and pepper',
#  'heavy_cream plus vinegar to substitute for the creme_fraiche',
#  'substitute sour_cream for the creme_fraiche',
#  'substitute stew meat for the chuck_roast and sour_cream for the creme_fraiche',
#  'instead_of white_wine as i is out of white_wine',
#  'replace the wine with brandy',
#  'substitute chicken_stock for the beef_stock',
#  'substitute a little wine for the water',
#  'substitute sour_cream for cream_cheese',
#  'substitute light sour_cream for cream_cheese',
#  'substitute cream of mushroom for the golden mushroom',
#  'substitute sour_cream for cream_cheese',
#  'substitute beef_broth for the water',
#  'substitute 1/4 cup of water with 1/4 cup of beef_stock and added about 4 tbs of sour_cream',
#  'replace the cream_cheese with sour_cream',
#  'substitute one can of beef_broth for the water',
#  'replace the cream_cheese with sour_cream',
#  'instead_of the water and a little plain fat free greek_yogurt for the sour_cream',
#  'substitute golden mushroom with a cream of mushroom',
#  'instead_of water and chopped onion i use a cup of french onion_soup for every 2 cans of golden mushroom',
#  'replace the 1/4 cup of water with french onion_soup',
#  'substitute cubed beef for the ground_beef',
#  'substitute the 1.5 cups water for milk with the flour',
#  'substitute heavy_cream for sour_cream',
#  'instead_of macaroni for some fiber and 3  i used ground_turkey instead_of beef',
#  'replace ground_beef with cubed beef',
#  'instead_of water along with 8 oz of creem cheese',
#  'instead_of water and added mushrooms and i also stirred in some sour_cream at the end when adding the cream_cheese',
#  'substitute the water with the low sodium beef_broth',
#  'replace the water with beef_broth',
#  'substitute the water with a bottle of dark beer',
#  'instead_of water with the leave overs make a cabbage',
#  'replace some  or all  of the water with beer',
#  'replace some of the water with a bottle of guiness and a cup of beef_broth',
#  'substitute butter for margarine',
#  'substitute low-sodium beef_broth for the water and dry sherry',
#  'substitute beef_broth for the water',
#  'replace hot milk with buttermilk',
#  'substitute beef_broth for the beer',
#  'substitute low-sodium beef_broth for the water',
#  'substitute beef_broth for the beer',
#  'replace the 4c water with beef_broth',
#  'substitute beef_broth for the water',
#  'substitute chicken_stock for one of the 4 cups of water',
#  'substitute 1 container of chicken_broth for the 4 cups of water and added the can beer',
#  'substitute a can of beef_broth for the water',
#  'substitute beef_broth for water',
#  'replace squash with mushrooms and celery',
#  'replace water with beef_broth',
#  'replace some of the water with red_wine',
#  'instead_of water after browning the flour',
#  'substitute 2 cup of red_wine and 1 cup of water for the 3 cups of water',
#  'substitute beef_bouillon and red_wine for the water',
#  'instead_of water with the cornstarch',
#  'substitute wine for beer as im not a beer',
#  'replace the water with red_wine',
#  'gravy_mix so i substitute with 1 cup of beef',
#  'celery so i substitute with a dash of celery_salt',
#  'replace the condensed cream of mushroom with condensed cream of celery',
#  'substitute jars of savory beef_gravy for the gravy_mix',
#  'substitute apple_juice for the vermouth and used the whole package of onion_soup',
#  'substitute dry ranch_dressing mix and a real onion for the soup_mix',
#  'replace water for the wine',
#  'substitute with beef_broth and some extra onion in mushroom',
#  'substitute cream_of_chicken_soup for the mushroom and added carrots and celery',
#  'substitute marsala_wine for the vermouth and used cream of celery instead_of cream of mushroom',
#  'replace condensced cream_of_mushroom_soup with gluten free cream_of_mushroom_soup',
#  'replace white_wine with 1/4 cp red cooking wine',
#  'substitute beef_broth for the vermouth and i skipped the butter and just do a once around with the olive_oil',
#  'water i replace with a can of college inn beef_broth and a little water',
#  'substitute wine for the water',
#  'substitute red_wine for the water and added 1/4 beef',
#  'substitute the cream_of_mushroom_soup for cream_of_broccoli_soup',
#  'substitute french onion_soup for the water',
#  'substitute red_wine for the water',
#  'substitute wine for the water',
#  'substitute half beef_broth and half red_wine for the water',
#  'replace water with red_wine and beef_broth',
#  'substitute broth and red_wine for the water',
#  'substitute 1 can beer for the water and added garlic_powder',
#  'substitute red_wine for the water',
#  'substitute red_wine for the water',
#  'substitute the water with beef_broth',
#  'substitute low sodium beef_broth for the water',
#  'substitute beef_broth for the water',
#  'substitute low sodium beef_stock for the water',
#  'substitute beef_broth for the water',
#  'substitute beef_broth for the water',
#  'garlic cloves to substitute for the garlic_salt',
#  'replace the water with trader joes 40-clove garlic sauce',
#  'replace the spinach with fresh kale',
#  'substitute beef_stock and red_wine for the water',
#  'substitute one can of cream_of_mushroom_soup with one can of golden mushroom soup and beef_broth for the water',
#  'substitute beef_broth for the water',
#  'substitute beef_broth for the water',
#  'substitute thyme for oregano',
#  'substitute salt and pepper with monterey seasoning',
#  'red_wine can be replace by pure organic apple_juice',
#  'substitute mccormick just a pinch season all as im not a big fan of rosemary on it own.. will make again but will also cut back on the butter',
#  'dried_rosemary so i substitute with 1/2 dry thyme',
#  'butter and it work wonderfully as a healthy substitute for butter',
#  'substitute french onion_soup for the dry onion_soup',
#  'substitute worcestershire_sauce for the water',
#  'replace the onion with a package of dry onion_soup',
#  'substitute the celery with cabbage and i put more than a 1/2 cup water',
#  'substitute dried_celery for the celery',
#  'substitute equal parts olive_oil and worcestershire_sauce for the water',
#  'instead_of beef_broth i used red_wine with beef and onion_soup',
#  'instead_of 1/4 cup of butter i used 1 stick of butter',
#  'substitute dried_oregano and basil for the spaghetti_sauce',
#  'replace onion with red_onion',
#  'replace the garlic_salt with garlic_powder and added regular salt',
#  'substitute italian herbs and tomato_paste for the packaged dry spaghetti_sauce seasoning',
#  'replace water for beef_broth',
#  'replace the water with beef_broth',
#  'substitute beef_broth for the water',
#  'substitute beef_broth for water',
#  'substitute beef_broth for the water',
#  'replace the red_wine with a rue of grape_jam and red_wine vinegar',
#  'substitute 1/2 cup no sodium beef_stock for the water',
#  'substitute beef_stock for the water',
#  'substitute marjoram with fresh rosemary and rubbed the roast with the basil',
#  'substitute thyme for the marjoram',
#  'substitute beef_broth for the water',
#  'substitute beef_broth for water',
#  'substitute cajan seasoning for paprika',
#  'substitute red_wine for the water',
#  'replace the water with beer and added a little beef',
#  'replace water with double the amount of chicken_broth',
#  'substitute beef_broth for the water',
#  'substitute beef with mushroom dry soup_mix for the onion_soup',
#  'substitute the water with a can of beef_broth',
#  'substitute 3/4 cup of water with red_wine',
#  'substitute the water with beef_broth',
#  'substitute just one pound of stew beef for the chuck_roast',
#  'substitute 1 cup beef_broth for the water',
#  'replace the water with beef_broth',
#  'replace the water with beef_broth',
#  'instead_of water and take another user advice to rub the pork with montreal steak spice and freshly crushed garlic',
#  'replace the water with beef_broth or beer',
#  'replace the water with beef_broth',
#  'substitute 3 tablespoons of cornstarch with 1 tablespoon of beef_base',
#  'substitute another dry gravy_mix since i do not have brown gravy_mix',
#  'substitute red_wine and beef_broth in place of chicken_broth',
#  'substitute 1/4 c of red_wine for that amount of water',
#  'instead_of water for the gravy_mix',
#  'instead_of flour for the sauce and instead_of water used beef_broth',
#  'instead_of chicken since i have it and added a cup of red_wine',
#  'instead_of chicken_broth in the recipe i used vegetable_broth',
#  'instead_of chicken_broth i used a can of french onion_soup with some beef_broth and since i didnt have tomato_paste',
#  'substitute beer for the chicken_broth',
#  'substitute beef_broth for the chicken_stock',
#  'substitute monterey seasoning for pepper',
#  'substitute one cup of red_wine and 3/4 cup each beef and chicken_broth for the 2 1/2 cups of chicken_broth',
#  'substitute ketchup for the tomato_paste',
#  'instead_of bay_leaf and marjoram and i can not recall ever make a sauce with tomato_paste',
#  'substitute ghee for butter',
#  'substitute venison for the beef',
#  'substitute ground_turkey for the ground_beef',
#  'cornstarch so i substitute with flour',
#  'instead_of 3. i also sauteed the 1/4 cup of chopped onion with 3 cloves of garlic',
#  'substitute beef_bouillon for the broth by adding 1 tablespoon or 1 cube and a cup of water',
#  'substitute 1/2 the beef_stock for this mushroom',
#  'instead_of corn starch and half the amount of onion in the sauce',
#  'substitute chicken_broth because it is what i have on hand and added garlic_powder',
#  'replace 1 cup of beef_broth with a can of condensed french onion_soup and only used 1/2 of a large onion',
#  'instead_of water with the soup i filled the can 1/2 with heavy whipping cream and 1/2 with beef_broth',
#  'substitute chicken_broth for the rest of the milk',
#  'replace the ground_beef with ground_turkey and the crackers with matzo',
#  'substitute one tbs of brown gravy_mix for 1 tbs of flour',
#  'substitute beef_broth in place of the milk',
#  'instead_of make a sauce with the butter',
#  'substitute a can of beefy mushroom for one cup of milk',
#  'replace the 2 t onion with the same amount of dried minced onion',
#  'substitute one cup of water with chicken_broth',
#  'substitute beef_stock for half the milk',
#  'substitute beef_broth for milk',
#  'instead_of have it as milk with a taste of beef',
#  'substitute one jar of beef_gravy for the ketchup',
#  'substitute ground_turkey in place of beef',
#  'replace the recommend sauce with brown gravy and topped it all with mushrooms sauteed in garlic',
#  'substitute cream_of_mushroom_soup for the french onion_soup',
#  'replace the water with a dry red_wine',
#  'substitute pancake_mix for the 1tbsp flour',
#  'substitute some milk for the egg',
#  'substitute cooking sherry for water',
#  'substitute 1 tablespoon cooking sherry with 1 teaspoon vanilla_extract',
#  'instead_of the sherry and i use olive_oil with a pat of butter instead_of vegetable_oil',
#  'substitute a1 bold steak_sauce for the worchestershire sauce',
#  'substitute red_wine for the sherry',
#  'substitute white_wine for the sherry because i do not have it and for 1 tblsp i thought i can either add water',
#  'instead_of sherry in the gravy and that is only because i do not have any sherry',
#  'substitute the sherry for water',
#  'substitute soy_sauce for the worcestershire_sauce',
#  'substitute french onion_soup for the beef_broth',
#  'substitute cream of mushroom for french onion_soup',
#  'mushroom so i substitute with a can of condensed french onion_soup',
#  'substitute one of the cans of condensed_cream_of_chicken_soup with condensed_cream_of_mushroom_soup',
#  'instead_of au jus and substitute low sodium beef_broth for the water',
#  'substitute cream_of_mushroom_soup for the cream of chicken',
#  'substitute cream_of_mushroom_soup for the cream of chicken',
#  'replace one can of cream of chicken with cream of mushroom',
#  'substitute the italian_bread crumbs with ritz crackers and cream of chicken with cream of mushroom',
#  'substitute the water for beef_broth',
#  'substitute the cream of mushroom with cream of mushroom and chicken',
#  'substitute cream of mushroom for the chicken',
#  'substitute cream of mushroom for cream of chicken',
#  'substitute the cream of chicken for cream of mushroom',
#  'substitute red_wine for the water',
#  'substitute 1 egg for the milk',
#  'substitute a can of cream of chicken for one of the mushroom',
#  'tomato_sauce to substitute for tomato_juice & ketchup',
#  'substitute red_wine vinegar for the actual red_wine',
#  'replace the rice with quinoa',
#  'salsa in with the chicken and peppers instead_of as a topping',
#  'blue_cheese on top of the burger instead_of in the ground_beef',
#  'substitute the chicken for turkey',
#  'substitute 93 % lean turkey for the 83 % lean chicken',
#  'replace the ground_beef with ground_pork',
#  'substitute w/ 1tblsp sour_cream & 2 tblsp milk per 2 pound beef',
#  'substitute whole_milk for the evaporated_milk',
#  'substitute regular milk for evaporated and is concerned that i have only lean ground_beef',
#  'substitute 1/4 of the total amount of ground_beef with 1/2 lb ground italian_sausage and added 1/8 tsp oregano',
#  'substitute milk for evaporated_milk',
#  'substitute heavy_cream for evaporated_milk',
#  'substitute regular milk for the evaporated_milk',
#  'replace the cajun_seasoning with steak_sauce',
#  'substitute johnsonville sausage for the beef',
#  'substitute ground_turkey for ground_beef and used a half packet of ranch_dressing mix instead_of onion',
#  'substitute the onion_soup for ranch seasoning',
#  'substitute the oats with italian_bread crumbs and cut the ketchup in 1/2 and added worcestershire_sauce',
#  'substitute seasoned_salt for the regular salt',
#  'replace the minced garlic with garlic_powder',
#  'onion_soup might make a good addition or a substitute for the basil',
#  'instead_of salt since i love garlic and also added a bit of montreal steak_seasoning',
#  'replace the salt and pepper with montreal steak_sauce',
#  'substitute pepperjack cheese for the american and add bacon',
#  'instead_of saltine crackers and i also only used 1lb of ground_beef with the entire ranch_dressing',
#  'substitute the ground_beef for ground_turkey',
#  'substitute the fresh chopped onion for 1 t dried minced onion since i do not like too much onion',
#  'instead_of powder and used shredded mexi cheese for the cheese',
#  'replace the soy_sauce and worcestershire_sauce with bbq sauce',
#  'substitute onion_powder for the garlic_powder',
#  'substitute parsley for the cilantro']

# %%
list(itertools.chain.from_iterable(deletion_list))
# Out:
# ['leave_out the bbq sauce',
#  'leave_out the rice',
#  'remove course shell of salt',
#  'leave_out the salt',
#  'leave_out the chili powders and increased the black pepper',
#  'leave_out the hot_sauce',
#  'leave_out the tomato_juice',
#  'leave_out the cilantro',
#  'leave_out the cilantro',
#  'remove the bitter',
#  'omit the process of soaking the liver and milk',
#  'leave_out the milk',
#  'leave_out garlic_powder',
#  'leave_out the mustard',
#  'leave_out the mustard',
#  'leave_out the ketchup and bell pepper',
#  'leave_out the corn_syrup',
#  'leave_out the maple_syrup',
#  'leave_out the parsley',
#  'omit the dill',
#  'leave_out the ancho chili pepper',
#  'leave_out the soy_sauce',
#  'omit the final step with the flour',
#  'omit the all-purpose flour and water',
#  'remove the bay_leaf',
#  'remove roast and deglazed pot with 1 c red_wine',
#  'leave_out the green_onion',
#  'leave_out the garlic_salt and salt',
#  'omit the honey',
#  'remove the honey and vanilla_extract',
#  'remove from the grill and hit all sides with a little freshly ground_black_pepper',
#  'omit the salt',
#  'omit the butter and sugar',
#  'leave_out the dried cranberries as i have none.. this felt a little lacking so i added 2 tsp of actual brown_sugar.. i do not bother use another bowl for the milk',
#  'not bother_with the water',
#  'leave_out the water as i do not soak the rice',
#  'leave_out the mustard and used chopped green_onion',
#  'leave_out the chili_powder',
#  'leave_out the chili_powder',
#  'leave_out the parsley and replace it with kale',
#  'delete the white_sugar',
#  'leave_out the water and ketchup',
#  'leave_out the red pepper and added a bit more chili_powder',
#  'omit the salt',
#  'omit the garlic_salt and double the garlic_powder',
#  'leave_out garlic_salt',
#  'leave_out tomato_sauce',
#  'leave_out the butter but added just a tad more water',
#  'remove and the rice',
#  'omit the salt and add a teaspoon of better than bullion chicken',
#  'leave_out the dry_mustard',
#  'leave_out the mustard',
#  'leave_out the mustard powder and most of the salt',
#  'leave_out the brown_sugar and make sure the paprika',
#  'omit the brown_sugar and add more garlic and hungarian paprika',
#  'remove some soy_sauce and added more honey',
#  'omit the extra water',
#  'leave_out the sauce',
#  'leave_out the egg',
#  'leave_out the wine',
#  'leave_out the flour',
#  'remove from the pan and set aside and the ground_beef',
#  'leave_out wine & added more worchestershire & pepper',
#  'leave_out the chives and the wine',
#  'leave_out the sour_cream',
#  'remove it from the pan and then saute the thin strips of beef',
#  'leave_out sour_cream to cut fat  i also added a couple dashes of tabasco and 1/4 cup quick cooking tapioca',
#  'omit the water',
#  'leave_out the water',
#  'leave_out the canned mushrooms and subbed cream_cheese instead_of sour_cream',
#  'omit the water',
#  'leave_out the fresh parsley',
#  'leave_out the white_wine and just used water',
#  'remove ½ cup of broth & mix with 2 tablespoons of cornstarch',
#  'omit water',
#  'leave_off the bouillon and water',
#  'leave_out the salt',
#  'leave_out the flour',
#  'leave_out the chives and parsley',
#  'omit the flour',
#  'omit the wine',
#  'leave_out the chives and only used half the sour_cream',
#  'omit that but still use the cream_of_mushroom_soup',
#  'omit the white_wine',
#  'omit the red pepper',
#  'leave_out the red pepper flakes and added the wine with the sauce',
#  'leave_out the red pepper',
#  'leave_out the red pepper',
#  'omit red flakes and wine',
#  'leave_out the addition of any salt',
#  'leave_out the wine and red pepper',
#  'leave_out the cream_cheese',
#  'omit the mustard',
#  'leave_out the red pepper',
#  'leave_out the red pepper',
#  'omit the cream_cheese and sour_cream because the sauce',
#  'leave_out the wine',
#  'omit pepper',
#  'leave_out the pepper',
#  'leave_out the red pepper',
#  'leave_out the red pepper',
#  'omit the crushed pepper',
#  'omit the red pepper',
#  'omit the red pepper and cream_cheese',
#  'remove this and melted the butter and added the flour',
#  'delete red_wine and used 2/3 c olive_oil',
#  'delete all the other beef',
#  'delete the garlic and add a few dashes of worcestershire_sauce',
#  'leave_out the white_wine',
#  'leave_out the worcestershire_sauce',
#  'omit either the beef boullion or soup_mix',
#  'omit the onion',
#  'leave_out the onion',
#  'leave_out ketchup and hot_sauce',
#  'leave_out some salt',
#  'remove from heat and added low fat sour_cream',
#  'leave_out the sour_cream',
#  'leave_out the extra boullion and salt',
#  'leave_out all the water and used mushroom soup instead_of mushrooms and used tomato_sauce',
#  'leave_out the butter as i used minced onions and drained the grease so i do not use the flour',
#  'leave_out the butter',
#  'leave_out the flour and added milk',
#  'leave_out the onion',
#  'leave_out the salt',
#  'omit flour',
#  'leave_out the flour',
#  'remove from heat and stir in sour_cream',
#  'omit the wine and used chicken_bouillon instead_of the beef',
#  'omit the pepper',
#  'remove the beef and put it in another dish and spread with mix of brown_sugar and mustard',
#  'remove the veggies and make a gravy out of the leftover stock use a slurry of stock and corn',
#  'omit the potatoes b/c they absorb a lot of the salt',
#  'remove beef',
#  'remove it from the pot or crock pot and top it with a glaze of mustard and brown_sugar',
#  'remove it from the pot and finished it in the oven with a sauce',
#  'remove the corned_beef',
#  'remove from water and wrap in aluminum_foil',
#  'remove the beef only added veggies to pot of stock then put the corned_beef in the oven at 350 in baking pan and covered it with a bottle of dark lager and aluminum_foil while the veggies cooked in the water',
#  'remove the corned_beef when i added the cabbage',
#  'remove from heat and add a dollop of sour_cream and horseradish',
#  'remove corned_beef',
#  'remove it from the pot and glazed it with a tart orange',
#  'remove beef',
#  'remove corn beef and put in oven with a glaze of mustard and brown_sugar for 30 more minute at 350. in liquid added celery',
#  'remove the corned_beef',
#  'leave_off the bread topping',
#  'leave_out the vinegar',
#  'remove the corned_beef',
#  'remove some salt',
#  'remove the corned_beef',
#  'not bother_with the seasoning',
#  'remove the beef from the broth i dump in potatoes and carrots to cook and when theyre close to done i add a quartered cabbage',
#  'leave_out the cabbage',
#  'leave_out the beer',
#  'not bother_with the beer',
#  'remove the cabbage',
#  'not bother_with beer',
#  'remove the beef and potatoes and added the cabbage',
#  'remove them & put them in a casserole dish with a few pats of butter',
#  'omit the veges except the onion to ensure the beef',
#  'omit is the onion',
#  'remove the corned_beef to make room for almost a whole head of cabbage',
#  'remove the cabbage',
#  'leave_out the beer',
#  'remove the corned_beef',
#  'remove brisket and veggies at the end and cooked the cabbage',
#  'leave_out the beer and added some beef flavor better than boullion to the water',
#  'leave_out the beer',
#  'leave_out the beer',
#  'leave_out the beer',
#  'remove some of the salt',
#  'omit the sugar',
#  'leave_out the sugar',
#  'leave_out the zucchini',
#  'remove the roast from the cooker after searing and deglazed the bottom with a little water',
#  'omit potatoes and add more veggies and mushrooms and make mashed taters cause of all the gravy i is able to make from the drippings the 3 cups of water netted 2 cups of stock i do a 4 tbls butter/flour mix in ci skillet added stock with salt pepper',
#  'leave_out celery',
#  'leave_out tomato_paste',
#  'leave_out the tomato_paste',
#  'remove the meat and vegetables and cooked down the liquid into a lovely sauce',
#  'remove the roast and vegetables and thicken the sauce',
#  'leave_out the brown gravy_mix',
#  'omit the gravy_mix',
#  'leave_out celery as a personal preference and rubbed more garlic',
#  'omit the minced garlic',
#  'leave_out the celery',
#  'remove the bone from the chuck_roast',
#  'leave_out the gravy_mix and put in beef_broth',
#  'leave_out the brown gravy_mix but added some fat free beef_broth',
#  'leave_out the gravy_mix',
#  'remove the grease from the gravy and added cornstarch',
#  'leave_out the celery',
#  'omit the gravy_mix',
#  'leave_out the celery and added some chunks of potato and onion',
#  'omit the onion_soup',
#  'leave_out the onion_soup',
#  'omit the onion_soup as i personally do not like the burnt onion',
#  'remove from heat and added a can of cream of celery and the dry soup_mix',
#  'leave_out mushroom',
#  'remove the roast and added potatoes and carrots to the gravy_mix',
#  'remove the roast and make a thickening for the gravy and added a little salt and coarse black pepper',
#  'remove the roast from the crock pot and use easy blending flour',
#  'leave_out onion',
#  'remove all seeds and pre slice the bell pepper',
#  'leave_out the water and mixed in 1/2 cup of white_wine and 1 tablespoon of worcestershire with the soup and soup_mix',
#  'leave_out the cup of water and still have a whole lot of sauce',
#  'leave_out the water',
#  'omit the water',
#  'leave_out the worcestershire and added a can of cream_of_mushroom_soup',
#  'leave_off the bay_leaf',
#  'remove garlic and such  with 1/8th cup of cornstarch',
#  'remove it from the pan and added a cup of beef_broth to the drippings and thickened with a bit of corn',
#  'remove meat & vegies then thickened liquid with a little cornstarch',
#  'remove cooked beef and added 1 can condensed french onion_soup',
#  'remove the browned roast tossed into the hot pan the sliced onions and garlic',
#  'remove the fat and most of the onion',
#  'remove the roast and cook the onion',
#  'leave_out the rosemary',
#  'remove the carrots and much of the onion and celery',
#  'leave_out the celery',
#  'leave_out the butter and used thyme instead_of rosemary',
#  'leave_out the celery',
#  'omit the water',
#  'leave_out the onions as they overpowered the garlic',
#  'leave_out the celery',
#  'leave_out the celery because i do not have any and i used chicken_broth instead_of water',
#  'leave_out the celery',
#  'remove with a little red cooking wine',
#  'leave_out the onion and celery',
#  'leave_out the celery',
#  'omit the celery and add an extra onion',
#  'omit thev3 cubes beef_bouillon',
#  'remove the veggies and roast when cooked and use cornstarch',
#  'omit the salt',
#  'leave_out all of the sugar',
#  'leave_out all sugar',
#  'leave_out the italian_seasoning',
#  'remove the vegetables i used corn',
#  'leave_out the butter but do add 1/2 water',
#  'leave_out the butter',
#  'remove the roast from the crock pot and stir cooked egg noodles or rice',
#  'omit the brown gravy_mix since it and the ranch_dressing have so much salt',
#  'leave_out the celery',
#  'leave_out the extra salt',
#  'delete the celery and added minced garlic',
#  'remove half of it and strained it and added flour',
#  'omit the plain salt',
#  'leave_out the celery and added a tablespoon of minced garlic',
#  'omit the celery',
#  'remove when they start to brown this replaces the garlic_salt',
#  'leave_out celery',
#  'remove and deglazed the pan with 1/4 cup red_wine',
#  'leave_out the celery',
#  'leave_out the zucchini',
#  'leave_out the bay_leaf',
#  'omit the water and substitute beer or red_wine',
#  'remove the roast from the skillet and placed it in the crock pot i added one can of campbells cream of mushroom and a can of cream_of_mushroom_soup mix and a pkg of lipton dry onion_soup',
#  'leave_out the salt',
#  'omit the added salt',
#  'leave_out the salt',
#  'leave_out the additional salt',
#  'remove the grease from the rendered fat and then cut the broth with water',
#  'leave_out the additional salt',
#  'omit the pepperoncini juice & salt',
#  'remove roast and vegetables to rest and added gravy to skillet whisking in a half cup of water with 2 tbls flour',
#  'leave_out the celery',
#  'leave_out the water',
#  'leave_out the celery',
#  'omit the water',
#  'leave_out the celery as i hate it and take the advice of others and added garlic and some worcester sauce',
#  'remove the beef',
#  'leave_out the celery',
#  'leave_out the onion_soup',
#  'omit the celery',
#  'leave_out the onion_soup mix and added onion_powder',
#  'omit celery',
#  'remove it to a warm plate and add chopped onions and garlic',
#  'remove the roast and veggies and then whisked cornstarch',
#  'leave_out the salt',
#  'leave_off the pepper',
#  'remove meat and veggies and thickened the gravy with a little corn',
#  'delete the salt',
#  'leave_out the added salt',
#  'leave_out the flour',
#  'leave_out the step with the flour',
#  'leave_out the salt',
#  'omit the flour',
#  'leave_off the flour and salt',
#  'leave_out the salt',
#  'omit the salt',
#  'omit the water',
#  'not bother_with putting the flour',
#  'remove the meat and am enjoying this savory carrot',
#  'omit salting the roast prior to coating it with flour',
#  'omit the salt',
#  'omit vinegar',
#  'leave_out the tomato_paste and used beef_broth',
#  'leave_out the rosemary and thyme',
#  'remove all the veggies and liquid and put in a pot with about ¼ cup heavy_cream and 2 tbls flour',
#  'remove the beef',
#  'leave_out the 1/4 tsp salt',
#  'leave_out the gravy_mix and add a can of cream_of_mushroom_soup',
#  'leave_out tomato_paste',
#  'delete the mushroom',
#  'leave_out mushrooms and added rutabaga',
#  'leave_out the oil and butter',
#  'omit the flour',
#  'leave_out the celery and cloves and used a single bay_leaf',
#  'remove the beef',
#  'remove patties from pan and sauteed the onions and mushrooms slightly before adding other sauce',
#  'omit the salt since i knew that the beef_broth',
#  'remove the patties and added the cornstarch',
#  'omit breadcrumbs and thicken the sauce',
#  'remove the patties before adding in the beef_stock',
#  'omit the mushrooms because we are not a mushroom',
#  'omit the egg due to allergies and used angus ground_beef',
#  'remove them and browned the steak',
#  'leave_out sauce next time..added 1/2 green pepper',
#  'remove the bread',
#  'leave_out the poultry_seasoning',
#  'delete the salt',
#  'leave_out the 1/2 teaspoon of salt',
#  'omit some of the shroom juice and obviously add less salt',
#  'omit the beef',
#  'leave_out the salt',
#  'leave_out the beef_bouillon next time and subsitute beef_broth',
#  'leave_out the onion',
#  'omit the poultry_seasoning and added just season salt and a bit of worcestershire_sauce',
#  'leave_out the extra cup of milk and tbsp of flour',
#  'leave_out the milk and flour',
#  'remove i added 2tbs of flour and i have to add a bit more butter',
#  'leave_out the poultry_seasoning',
#  'leave_out the salt in the meat to help reduce the over salt',
#  'leave_out the poultry_seasoning',
#  'leave_out and montreal steak_seasoning',
#  'leave_out the pepper and reduce salt',
#  'leave_out the onion_soup mix and make a traditional salisbury steak',
#  'omit salt and maybe use half an onion',
#  'leave_out the mustard and salt and used a packet of lipton onion_soup',
#  'remove the sauce',
#  'leave_out the ketchup',
#  'leave_out the ketchup',
#  'omit the ketchup',
#  'omit the ketchup',
#  'leave_out the ketchup completely and used beef_broth',
#  'leave_out the ketchup',
#  'delete the salt',
#  'leave_out the ketchup',
#  'leave_out the ketchup',
#  'leave_out ketchup',
#  'leave_out the mustard and ketchup and added the worchester sauce',
#  'omit this and just use the lipton onion',
#  'omit the egg',
#  'omit ketchup and use addl onion_soup',
#  'leave_out the mustard',
#  'leave_out the sherry',
#  'leave_out the sherry',
#  'leave_out the sherry',
#  'leave_out the sherry',
#  'leave_out the sherry',
#  'leave_out the sherry',
#  'leave_out the seasoned_salt',
#  'leave_out sherry',
#  'leave_out the sherry',
#  'leave_out the onion_powder',
#  'leave_out adding the seasoned_salt',
#  'leave_out the sherry',
#  'leave_off the sherry',
#  'leave_out the seasoned_salt',
#  'leave_out the cooking sherry',
#  'leave_out the sherry',
#  'leave_out is the sherry',
#  'omit sherry',
#  'leave_out the sherry',
#  'leave_out the cooking sherry',
#  'omit the seasoned_salt in the gravy next time because it is a bit too salty for me and there is plenty of salt in the beef_broth',
#  'leave_out the egg',
#  'remove dry_mustard',
#  'omit that but i do chop fresh garlic',
#  'leave_out the water',
#  'leave_out the salt',
#  'omit the water',
#  'remove without cleaning and adding olive_oil',
#  'remove them from the butter so i can cook the flour',
#  'leave_out the milk',
#  'omit the flour and milk',
#  'leave_out the onion_soup mix and added 1 cup finely chopped onion and a clove of minced garlic',
#  'omit or reduce salt',
#  'leave_out the sour_cream',
#  'remove some broth and blended well with 1 tables cornstarch',
#  'remove the steaks and added the onion and some mushroom',
#  'omit the itialian seasoning',
#  'leave_out the milk and used an egg',
#  'omit green pepper',
#  'omit the ketchup',
#  'leave_out the chopped onion since the soup_mix already have onion',
#  'leave_out the celery and onion',
#  'leave_out the carrot and added green pepper',
#  'leave_out the flour and the brown_sugar',
#  'leave_out the carrots and celery and put in green peppers and maybe garlic',
#  'omit the sugar',
#  'leave_out the celery',
#  'leave_out the celery',
#  'leave_out the oil but kept the flour',
#  'remove the meat from the pan and whir up about 80 % of the sauce',
#  'leave_out the onion_powder',
#  'omit the cheese',
#  'remove the chicken from the pan and cooked the veggies in the chicken_broth',
#  'omit the salt',
#  'leave_out the salt',
#  'leave_out the black pepper',
#  'leave_out the blue_cheese',
#  'leave_out the rosemary',
#  'remove the burgers and added a half cup of a semi-fermented prune juice that i keep in the frig and a tablespoon of tomato_paste',
#  'leave_out the caraway_seed',
#  'leave_out the lime_juice',
#  'leave_out the ground_ginger',
#  'leave_out ginger as we have an allergy and added a little corse salt and fresh diced onion',
#  'leave_out the soy_sauce',
#  'leave_out the optional lime_juice and ranch_dressing',
#  'leave_out half of the zucchini it is still difficult to form the burgers.. i leave_out the red pepper',
#  'remove half and added some taco_seasoning',
#  'leave_out the tomato',
#  'leave_out the tomato',
#  'leave_out the egg and bread',
#  'leave_out the carrot',
#  'leave_out the celery_salt & chopped celery',
#  'leave_out the celery_salt',
#  'leave_out the cayenne_pepper',
#  'leave_out the diced celery and added tomato and some red_onion',
#  'leave_off the blue_cheese',
#  'omit the celery and celery_salt i topped mine with the lettuce',
#  'leave_off the bacon',
#  'leave_out the potatoes and used cheddar_cheese',
#  'leave_out the mushroom and used cheddar_cheese',
#  'leave_out the green onions and sprinkled the burgers with onion_powder',
#  'leave_out the bread',
#  'leave_out the bread',
#  'leave_out the mustard',
#  'omit the breadcrumbs to make them juicier and go light on the garlic',
#  'leave_out cayenne_pepper',
#  'omit the bread',
#  'leave_out the cayenne_pepper and just sprinkled black pepper',
#  'leave_out the egg_white',
#  'leave_out the milk',
#  'leave_out the cayenne_pepper',
#  'omit the cayenne_pepper',
#  'leave_out the cayenne and use regular milk',
#  'delete the bread',
#  'leave_out the cayenne_pepper',
#  'leave_out the brown_sugar',
#  'leave_out onion and cajun season because of taste choice and bread',
#  'leave_out the parmesan_cheese',
#  'leave_out the parm cheese',
#  'leave_out the mayo and subbed with a little sour_cream',
#  'omit the mayo and onion_soup',
#  'omit the mayo and substitute shredded american for the cheddar_cheese',
#  'leave_out 1/3 of the cheese',
#  'leave_out the soup_mix',
#  'leave_out a bit of mayo and add a little ketchup and mustard',
#  'omit the salt and sometimes use thyme and/or steak',
#  'leave_out the oatmeal',
#  'omit the onion',
#  'leave_out the egg',
#  'leave_out the olive_oil',
#  'leave_out the basil',
#  'leave_out the basil',
#  'leave_out the salt',
#  'leave_out the onion',
#  'leave_out the egg',
#  'leave_out the egg',
#  'leave_out the crackers and egg and just add onion_soup',
#  'leave_out the onions and substitute crackers for plain bread',
#  'leave_out the onion and replace the crackers with some italian_bread',
#  'leave_out the egg',
#  'leave_out the crackers and egg',
#  'omit the onion',
#  'leave_out the egg',
#  'leave_out the crackers & egg',
#  'leave_out the egg',
#  'leave_out the egg',
#  'leave_out the bread',
#  'delete the egg',
#  'leave_out the bread and egg',
#  'leave_out the eggs and crackers as well as used one package of ranch_dressing',
#  'leave_out the garlic_powder',
#  'leave_out the onion_soup',
#  'leave_out the rosemary',
#  'leave_out the chopped onion',
#  'leave_out the fresh garlic and added an extra tsp of worcestershire_sauce',
#  'leave_out one of the onion',
#  'leave_out the cheese and worcestershire_sauce',
#  'leave_out the salt and the rosemary',
#  'omit the soy_sauce',
#  'leave_out the onion_soup mix and added a 1 tbs of italian_bread',
#  'leave_out the cheese',
#  'leave_out the additional onion and garlic',
#  'leave_out the 1/2 onion and the clove of garlic',
#  'leave_out the cheese',
#  'leave_out the cheese',
#  'leave_out the rosemary and garlic',
#  'leave_out the oregano and rosemary',
#  'omit the soy_sauce or cheese',
#  'leave_out the onion_soup mix and the rosemary',
#  'leave_out rosemary',
#  'leave_out the soy_sauce and onion_soup mix and you will cut the salt',
#  'leave_out the rosemary',
#  'leave_out the garlic_powder and used another garlic',
#  'leave_out the rosemary',
#  'leave_out the dried_onion soup_mix',
#  'leave_out the french onion mix and halved the garlic_powder with 1/2 garlic_salt 1/2 garlic_powder',
#  'omit onion_soup',
#  'leave_out rosemary',
#  'leave_out the onion_soup mix and put in minced onion',
#  'delete the rosemary and added a tsp of red pepper',
#  'leave_out the garlic_powder',
#  'omit the cayenne and hot_sauce',
#  'omit the egg',
#  'leave_out the chopped onion and used onion_powder in the sauce']

# %%
list(itertools.chain.from_iterable(addition_list))
# Out:
# ['add the bbq sauce',
#  'add 1/2 jar of bbq sauce',
#  'add much water b/c the 2 cans of beer',
#  'add bbq sauce',
#  'add an onion',
#  'add something green like bell pepper',
#  'add one chopped onion',
#  'add to it by saute onion',
#  'add some water',
#  'add some crushed red pepper',
#  'add it as it seem to take forever to cook the rice',
#  'add 1/2 cup milk',
#  'add minced garlic',
#  'add about a cup to a cup and a half of water to get the rice',
#  'add sugar',
#  'add some peppers and onions to browned ground_beef',
#  'add some mustard',
#  'add some garlic',
#  'add 1/2 cup of fresh lemon_juice',
#  'add some salt',
#  'add fat but i will not go there and just rate this as make with beef',
#  'add curing salt',
#  'add more seasoning to the flour',
#  'add a knob of butter to olive oil_for_frying',
#  'add tablespoon of the keg steak',
#  'add a fair amount of salt and pepper to the potato flake/crushed cracker',
#  'add pepper',
#  'add the cheese to the mixture after you add the ground_beef',
#  'add lot of garlic_powder and approx a cup of beef_broth',
#  'add some herbs like rosemary',
#  'add a few tablespoons of water',
#  'add worchestire sauce',
#  'add some salt',
#  'add a little worcestershire_sauce',
#  'add more salt',
#  'add any pepper',
#  'add more mustard',
#  'add the sauce',
#  'add a little olive_oil and a teaspoon of minced garlic',
#  'add about a tablespoon of cream_of_mushroom_soup with garlic',
#  'add powdered ranch_dressing mix or onion_soup',
#  'add butter with the veggies and a piece of american sliced cheese',
#  'add at least 2 tb of butter',
#  'add worcestershire_sauce',
#  'add a pat of butter',
#  'add celery',
#  'add is to microwave the whole potato until able to stick',
#  'add about an extra 1/4 cup of flour to thicken it and i also dipped the hotdogs in flour',
#  'add a little red_wine',
#  'add meat_tenderizer',
#  'add some seasonings to the flour and also salt and pepper',
#  'add extra seasonings to the flour',
#  'add more salt',
#  'add plenty of salt and pepper',
#  'add a couple of beef_bouillon cubes in addition to the full amount of coffee',
#  'add a tsp of instant coffee',
#  'add more coffee',
#  'add some red_wine',
#  'add some garlic',
#  'add garlic',
#  'add the bacon',
#  'add minced onion and/or green pepper',
#  'add more water and i put more crushed pineapple in it due to the water',
#  'add a bit more water',
#  'add butter',
#  'add another 1/2 a cup of water',
#  'add less green_onion',
#  'add cilantro',
#  'add the lime_juice',
#  'add bacon to the onions and cook the liver in the grease from the bacon',
#  'add some soy_sauce',
#  'add 2 c of beef_broth',
#  'add a bit of sour_cream',
#  'add a bell pepper',
#  'add bacon',
#  'add some cold water into the leftover flour',
#  'add a little garlic',
#  'add green pepper strips to the onions and a dash of paprika to the flour',
#  'add as much milk',
#  'add a little olive_oil with the butter',
#  'add garlic be careful not to add to soon as garlic',
#  'add bacon',
#  'add bacon to the pan while cooking liver but because of the bacon fat i used less butter',
#  'add more flour',
#  'add back the onions and a little gravy powder and enough water',
#  'add some lawrys season salt and lawrys garlic_salt to the flour',
#  'add a little more seasoning but we like thing well seasoned with pepper',
#  'add a decent amount of lime_juice to make sure it have that lime',
#  'add a quarter cup of high end tequila',
#  'add some tequila',
#  'add lime_juice',
#  'add any sugar added extra garlic',
#  'add extra garlic',
#  'add the extra sugar',
#  'add a touch of brown_sugar',
#  'add cornstarch',
#  'add bbq sauce',
#  'add the additional three cloves of garlic',
#  'add butter',
#  'add a little ketchup and mustard',
#  'add jalapenos and cheese',
#  'add some smoked habanero and maybe some cheese',
#  'add crushed red pepper',
#  'add better taste to pork',
#  'add a packet of dry onion_soup',
#  'add a couple sprigs of fresh thyme',
#  'add any salt',
#  'add straight broth  no water',
#  'add a little syrup',
#  'add the 10x sugar',
#  'add the milk',
#  'add the right amount of maple_syrup',
#  'add the wine',
#  'add the pistashios or parsley',
#  'add some green peppers or other vegetables and i might add a little more of the chile_pepper',
#  'add even more ginger and maybe a touch of hot_sauce',
#  'add a bit of water',
#  'add to it about 1.5 tablespoons brown_sugar',
#  'add the extra salt',
#  'add 3 cloves of minced garlic',
#  'add fresh mushrooms and used apple cidar vinegar mixed with water',
#  'add some sprigs of fresh rosemary',
#  'add a bay_leaf',
#  'add a small amount of beer broth along with the vinegar',
#  'add a few tablespoons of water',
#  'add some red_wine',
#  'add some carrots and garlic',
#  'add wine',
#  'add that to the gravy and put over egg',
#  'add the water or flour',
#  'add another cup of water',
#  'add water',
#  'add some water',
#  'add the honey so i added two garlic cloves..half an onion lot of pepper',
#  'add much flavor and that will be the last time i use the stovetop to cook the rice',
#  'add some garlic',
#  'add onion_salt',
#  'add the tomato_sauce',
#  'add butter and parsley',
#  'add little bits of butter',
#  'add beefy onion_soup mix to the ground_beef',
#  'add cabbage',
#  'add a few more seasonings like garlic_powder and soy_sauce',
#  'add a generous amount of lemon_pepper seasoning and cabbage',
#  'add italian_salad_dressing',
#  'add a can of tomato_sauce',
#  'add some oregano',
#  'add a few spoonfuls of cream_of_mushroom_soup',
#  'add butter',
#  'add approximately a 1/2 a can of cream_of_mushroom_soup',
#  'add a little bit of soy_sauce just to add a bit of flavor and use the extra lean ground_beef',
#  'add a little worcestershire_sauce and garlic',
#  'add water',
#  'add golden mushroom',
#  'add a good bit of worcestershire_sauce',
#  'add a package of onion_soup',
#  'add heaps of pepper',
#  'add a piece of bacon',
#  'add ketchup',
#  'add 1 clove minced garlic and do not form the ground_beef',
#  'add an egg',
#  'add the onion_soup',
#  'add butter',
#  'add squash or tomato',
#  'add a 1/4 of a green or red pepper',
#  'add a little butter',
#  'add cabbage',
#  'add some diced sweet potatoes which is delicious and a little more seasoning',
#  'add the soup_mix',
#  'add a lil cream_of_mushroom_soup',
#  'add fresh minced garlic',
#  'add garlic_powder',
#  'add cut celery',
#  'add more seasonings/ salt..maybe some chicken_broth',
#  'add green beans and a1 sauce',
#  'add onion_soup mix to the beef',
#  'add more pumpkin_seed',
#  'add some garlic',
#  'add a little minced garlic',
#  'add cayenne_pepper',
#  'add 1/4 more cayenne_pepper',
#  'add rice',
#  'add more salt',
#  'add more coconut_milk',
#  'add an extra tbsp of brown_sugar',
#  'add more cinnamon to the base and use a vanilla flavoured greek_yogurt',
#  'add a little franks red hot_sauce in with the barbecue and water',
#  'add some liquid_smoke and be careful not to use a sauce with too high of a sugar content or itll burn and taste bitter',
#  'add the water',
#  'add more bbq sauce',
#  'add the sauce and water',
#  'add more seasoning.. maybe even garlic_salt',
#  'add liquid_smoke',
#  'add extra salt',
#  'add extra water',
#  'add cilantro and a can of seasoned tomato',
#  'add more carrot',
#  'add more water to the wild_rice',
#  'add pepper',
#  'add 2 cups milk',
#  'add salt',
#  'add an egg to the patties and forgot to coat the outside with the leftover cracker',
#  'add 2 extra teaspoons of salt',
#  'add minced garlic',
#  'add a few tablespoons bread',
#  'add about 3-4 tablespoons of flour',
#  'add the chili_powder',
#  'add any into the ground_beef',
#  'add salt',
#  'add some onion_soup',
#  'add salt',
#  'add some cayenne_pepper',
#  'add a little garlic_powder',
#  'add a tablespoon of mustard and one whole diced onion',
#  'add a few dashes of hot_sauce and one dash of vinegar to cut the tomato_sauce',
#  'add 1 can tomato_paste and 1 tsp of salt in the last 30 minute to give it a slightly more tomato',
#  'add some minced onion and garlic',
#  'add additional stock or water',
#  'add garlic_powder and onion_powder and use beer instead_of water',
#  'add more tomato_sauce and added beef_broth',
#  'add the parm and used panko instead_of dry bread crumbs that i flavoured with two teaspoons of italian_seasoning',
#  'add vinegar',
#  'add 3 3/4 cups water',
#  'add chicken',
#  'add butter',
#  'add just a tad more water',
#  'add some chopped mushrooms and a clove of crushed garlic',
#  'add a soup cube and some broccoli',
#  'add butter or salt since the broth have salt',
#  'add some lime_juice',
#  'add chicken_broth instead_of water',
#  'add a dash or so of soy_sauce',
#  'add the leaves from about 6 stems to the rice',
#  'add a bit more salt and pepper',
#  'add the mustard',
#  'add bacon',
#  'add minced garlic',
#  'add liquid_smoke and worcestershire_sauce',
#  'add fresh garlic',
#  'add a little crushed garlic',
#  'add a little garlic_powder just because i add garlic to most ground_beef',
#  'add in oxtails until they are coated then add in celery',
#  'add bay_leaf when boiling along with garlic and onion',
#  'add 1 carrot',
#  'add a whole hot pepper',
#  'add additional beef_broth and flour',
#  'add either the seasoning salt or the table salt',
#  'add oxtails back into rice',
#  'add any salt',
#  'add flour',
#  'add a bottle of beef_bone',
#  'add more minced garlic because we love garlic',
#  'add half the salt',
#  'add a little more seasoning',
#  'add as much salt',
#  'add any water or flour',
#  'add a little more water',
#  'add the 2 tsp of salt',
#  'add the additional salt and used spicy brown mustard instead_of mustard',
#  'add the brown_sugar because ketchup',
#  'add any additional salt',
#  'add the flour and water',
#  'add sliced red peppers with the onions and garlic',
#  'add more paprika',
#  'add milk',
#  'add salt',
#  'add a couple tablespoons of curry_paste',
#  'add water',
#  'add sliced almonds or some orange_zest',
#  'add liquid and cut way back on the pepper and ginger',
#  'add some sliced onions with the beef',
#  'add 1 tablespoon of corn starch to the 3 tablespoons of water',
#  'add some bamboo shoots and/or water',
#  'add a whole cup and a half water because the beef',
#  'add some sherry',
#  'add onions in lieu of the onion_powder',
#  'add the soy_sauce and honey',
#  'add the cornstarch',
#  'add another tbsp of honey',
#  'add a vidalia onion',
#  'add in the flour',
#  'add more soy_sauce and honey',
#  'add water or flour',
#  'add sour_cream',
#  'add a cup of sour_cream',
#  'add one can of cream of mushroom but i do too to have more sauce',
#  'add a bit more salt',
#  'add too much salt',
#  'add more sauce',
#  'add a splash of milk',
#  'add milk or half_and_half',
#  'add sour_cream',
#  'add more sour_cream to the gravy or another can of mushroom',
#  'add some dijon_mustard',
#  'add some nothern beans and cabbage',
#  'add some brown_sugar',
#  'add more seasoning',
#  'add diced tomato and onion',
#  'add another pound of ground_beef',
#  'add sour_cream',
#  'add extra salt',
#  'add additional salt',
#  'add a tablespoon of worcestershire_sauce',
#  'add the sour_cream',
#  'add the wine',
#  'add about 2 1/2 cups of beef_stock',
#  'add a small carton of sour_cream to the sauce',
#  'add worcestershire_sauce',
#  'add some cream_cheese to beef',
#  'add some chopped celery',
#  'add a can of beef_broth for the wine',
#  'add any extra salt',
#  'add the wine',
#  'add the wine',
#  'add cornstarch',
#  'add less parsley',
#  'add the white_wine',
#  'add extra mushrooms and serve this with homemade egg',
#  'add a bit of cream_cheese to thicken a bit and make it a really creamy sauce',
#  'add all of the sour_cream',
#  'add the salt when you add the beef',
#  'add alittle extra water',
#  'add extra flour',
#  'add 2tbs of cornstarch',
#  'add another tbsp of the worcestershire_sauce',
#  'add a little more onion',
#  'add cornstarch in lieu of flour since the sauce',
#  'add the chives or parsley',
#  'add any cornstarch',
#  'add the 1/2 sour_cream',
#  'add more cloves of garlic',
#  'add enough beef',
#  'add sour_cream',
#  'add 6 ounces softened light cream_cheese blended into only 16 ounces fat free sour_cream with 1 cup chopped fresh parsley',
#  'add a slurry of cornstarch & water',
#  'add a little dion mustard and used beer instead_of wine',
#  'add cream_cheese',
#  'add more thickener when adding the sour_cream',
#  'add a can of mushrooms and tony chacheres seasoning',
#  'add the worcestershire_sauce',
#  'add any water',
#  'add more seasoning',
#  'add the sour_cream',
#  'add a touch of cream_cheese with the sour_cream',
#  'add a ton of salt and pepper',
#  'add more seasoning and more flower to thicken the sauce',
#  'add the full amount of sour_cream',
#  'add a packet of lipton onion_soup',
#  'add any wine at all since this soup already contains wine',
#  'add the wine',
#  'add a dollop of sour_cream',
#  'add some red_wine',
#  'add 1 tablespoon of dijon_mustard',
#  'add 6 oz of sour_cream half in the sauce and topping',
#  'add that much sour_cream',
#  'add a little more wine when i add the sour_cream',
#  'add the corn',
#  'add water and probably toss the beef stew with the flour',
#  'add a small glass of coffee to the sauce',
#  'add the wine to the sauce',
#  'add the extra salt as there is plenty in the beef_broth',
#  'add cream_cheese',
#  'add the marinade i simply poured in some nice wine',
#  'add a little less flour',
#  'add the sour_cream or cream_cheese',
#  'add more wine',
#  'add 1 t. of chicken_bouillon to the sauce',
#  'add the beef',
#  'add the sour_cream and cream_cheese',
#  'add the wine into the sauce without marinating the beef',
#  'add more beef_broth',
#  'add the cream_cheese and sour_cream before i add the meat back and i always use ground_beef',
#  'add the sour_cream or the cream_cheese',
#  'add sour_cream',
#  'add the red_wine the second time we make it the red_wine seem to give it a little bit of an off taste for us but the second time we make it without the red_wine',
#  'add more wine',
#  'add a touch of horseradish',
#  'add the leftover marinade',
#  'add the pepper',
#  'add more of the other sauce',
#  'add a little red_wine vinegar and less red_wine',
#  'add onion_powder to the marinade for the beef',
#  'add a beef cube to the beef_broth',
#  'add greek_yogurt instead_of cream_cheese',
#  'add to gravy instead_of the reserved marinade',
#  'add the red peppers and added a bit more cream_cheese and sour_cream',
#  'add quite a bit more beef_broth than called for and cut back a bit on crushed red pepper',
#  'add the hot pepper',
#  'add the pepper',
#  'add a little more sour_cream and cream_cheese',
#  'add a touch of milk',
#  'add less red pepper',
#  'add cream_cheese only sour_cream',
#  'add cream_cheese',
#  'add more beef_stock',
#  'add are thyme',
#  'add another cup of beef_broth',
#  'add an additional 1/2 teaspoon of salt and marinate in the red_wine',
#  'add more liquid.. this dish will be perfect with only a tiny bit of red pepper',
#  'add cornstarch',
#  'add the sour_cream & cream_cheese',
#  'add more garlic and onion',
#  'add a ton of salt',
#  'add quite a bit of fresh ground_black_pepper',
#  'add 1/2 teaspoon of paprika before adding the sour_cream',
#  'add seasoning salt',
#  'add more sour_cream',
#  'add a half cup of parmesan_cheese',
#  'add some chopped asparagus',
#  'add the flour',
#  'add garlic_salt',
#  'add white_wine since i do not have any and can not find just plain wine white or sherry',
#  'add a bit more beef_stock',
#  'add plain greek_yogurt',
#  'add the creme_fraiche',
#  'add more onion',
#  'add sour_cream',
#  'add tomato',
#  'add extra liquid ingredients we like have extra sauce',
#  'add a beef_bouillon cube to the meat and sauce during the simmering process to deepen the beef flavor and i use sour_cream',
#  'add some at the end so the flavor of the sherry',
#  'add a little worcestershire_sauce and use a more tender beef',
#  'add the sour_cream',
#  'add more green_onion',
#  'add just a pinch of red pepper',
#  'add a pinch of nutmeg and a tablespoon or two of dry sherry',
#  'add a little more flour',
#  'add about a qtr cup of chopped fresh dill',
#  'add a little extra flour',
#  'add a little flour',
#  'add a drained can of sliced mushrooms and a bit more worcestershire_sauce',
#  'add a whole packet of onion_soup',
#  'add a little flour to the ground_beef',
#  'add some mushrooms and onion_soup',
#  'add some white_wine next time instead_of the water',
#  'add mushrooms and a bit of sherry',
#  'add red_wine instead_of water',
#  'add 1/2 packet onion_soup',
#  'add a dollop of sour_cream also when adding cream_cheese',
#  'add some salt',
#  'add some cream_cheese',
#  'add 1 1/2 cups of beef_broth rather than 1/4 cup of water and i add 1 minced clove of garlic',
#  'add sour_cream',
#  'add some garlic_powder',
#  'add cream_cheese to taste or try adding corn',
#  'add water and i sprinked a little bit of all-purpose seasoning',
#  'add onion_soup',
#  'add sour_cream',
#  'add some red_wine',
#  'add cream_cheese',
#  'add the cream_cheese',
#  'add the mushrooms nor the sour_cream',
#  'add a half packet of onion_soup',
#  'add salt',
#  'add some cornstarch',
#  'add salt',
#  'add some sour_cream',
#  'add the canned mushrooms but do double the sauce',
#  'add salt',
#  'add a dollop of sour_cream',
#  'add a bullion cube add 1/2 packet of onion_soup',
#  'add the pepper',
#  'add garlic',
#  'add mushrooms to the recipe and served over egg_noodle',
#  'add snow peas to the stroganoff and serve it with rice and a little garlic bread',
#  'add beef_broth',
#  'add a little more water',
#  'add more meat to be able to use up the rest of the sauce',
#  'add 1/2 ginger',
#  'add garlic',
#  'add salt',
#  'add the cream_cheese',
#  'add some green pepper',
#  'add the cream_cheese',
#  'add onion_soup',
#  'add in the cooked egg',
#  'add a can of beef_broth',
#  'add the onion_soup',
#  'add cream_cheese in addition to the sour_cream',
#  'add some garlic_powder',
#  'add about a 1/4 cup of sour_cream with the cream_cheese',
#  'add sour_cream and not the cream_cheese',
#  'add sour_cream & double the mushroom',
#  'add any water',
#  'add 1/2 packet of onion_soup',
#  'add the cream_cheese',
#  'add crushed or pureed tomatoes plus smoked_paprika',
#  'add cream_cheese',
#  'add salt',
#  'add some garlic and i use more worchestershire sauce',
#  'add a splash of sherry and add sauteed mushrooms and a dallop of sour_cream',
#  'add sour_cream',
#  'add 16-oz package of fancy egg',
#  'add some cornstarch',
#  'add sliced mushrooms and a little crushe red pepper',
#  'add minced garlic and a little seasoning salt',
#  'add tang and used the golden mushroom soup instead_of cream of mushroom',
#  'add the cream_cheese',
#  'add a half packet of onion_soup',
#  'add salt',
#  'add sauted garlic',
#  'add less worcestershire_sauce',
#  'add 2 cloves of garlic',
#  'add the salt',
#  'add at least one more onion',
#  'add sour_cream and 1/2 an onion_soup',
#  'add some pepper',
#  'add water',
#  'add some garlic_powder and salt',
#  'add a bouillon cube or a little onion_soup',
#  'add an extra tablespoon of flour',
#  'add a little more salt',
#  'add 1 more tbs butter after removing the onion/mushroom/ garlic',
#  'add a little more salt & pepper',
#  'add the salt',
#  'add a dollop of sour_cream',
#  'add sour_cream',
#  'add more flour',
#  'add sour_cream',
#  'add sour_cream at the last minute and serve over egg',
#  'add some sour_cream',
#  'add the onions and a couple very small diced garlic',
#  'add any salt',
#  'add some sour_cream',
#  'add salt with the beef_bouillon',
#  'add paprika and sour_cream',
#  'add 1-2 teaspoons of sugar to cut the acidity of the tomato_paste',
#  'add quite as much water',
#  'add some cream of mushroom because it is more of a tomato',
#  'add any salt',
#  'add a bit of paprika',
#  'add a bit of extra flour',
#  'add salt',
#  'add the red_wine',
#  'add chopped garlic and homemade egg',
#  'add a splash of worchestershire sauce',
#  'add salt',
#  'add the flour',
#  'add cooked ground_beef',
#  'add a bit of extra garlic_powder',
#  'add garlic and a bit of seasoning salt and worchestire sauce',
#  'add approximately 1/2 c milk to thin sauce',
#  'add flour',
#  'add the flour',
#  'add a bit more garlic and use cream_of_mushroom_soup instead_of cream of chicken',
#  'add a 1/2 a soup can of milk',
#  'add sour_cream',
#  'add garlic_powder and 1/4 tsp salt',
#  'add some white_wine',
#  'add some flavor i added sherry',
#  'add cup of beef_broth',
#  'add sour_cream',
#  'add some frozen peas and corn',
#  'add some milk',
#  'add more sour_cream and cream_of_mushroom_soup',
#  'add milk',
#  'add heaps of worchestershire sauce',
#  'add the paprika',
#  'add some milk',
#  'add some beef',
#  'add 1 c water and a beef_bouillon cube as the sauce is too thick and then added another 1/2 c milk',
#  'add paprika',
#  'add garlic',
#  'add fresh minced garlic',
#  'add some spices and worcheshire sauce',
#  'add some garlic_salt',
#  'add about a 1/4 cup milk to thin it out a little and i used egg',
#  'add flour.. while im cooking the meat i add white_wine',
#  'add some minced garlic when browning the beef',
#  'add a can of milk',
#  'add 1/2 a can of milk',
#  'add flour',
#  'add sour_cream',
#  'add dill',
#  'add garlic and do not add the flour',
#  'add a little mustard and garlic_powder along with the paprika',
#  'add a bit of milk',
#  'add touch of milk',
#  'add milk',
#  'add is packing some artichoke',
#  'add more salt and since i love pepper i have to add pepper',
#  'add a little more milk',
#  'add pepper',
#  'add a dash of worcestershire_sauce',
#  'add soup and add back ground_beef',
#  'add a little flour',
#  'add the soup 2  put it over brown_rice',
#  'add a bit of garlic',
#  'add a full cup of sour_cream',
#  'add rice',
#  'add about 1/4 pkg of cream_cheese',
#  'add flour to the condensed_cream_of_mushroom_soup',
#  'add lemon_juice or milk',
#  'add some spinach',
#  'add a can of mushroom',
#  'add a good flavor and texture to the recipe when you add the onion and mushroom',
#  'add a can of mushroom',
#  'add the red_onion',
#  'add more water',
#  'add more garlic and some butter',
#  'add a few tablespoons odds soy_sauce',
#  'add beef_broth instaed of water',
#  'add some chicken_bouillon cubes to the water and a little butter',
#  'add some caraway seeds when you add the cabbage',
#  'add some celery',
#  'add a little butter',
#  'add cabbage',
#  'add the potatos and cabbage together so you get no tough cabbage',
#  'add more cabbage',
#  'add the spice packet that come with the corned_beef',
#  'add about 1/2 tablespoon of the bacon grease to the jiffy cornbread_mix',
#  'add 8 cloves of garlic and 2 bottles of beer',
#  'add a bottle of beer',
#  'add enough water',
#  'add oinions and dry_mustard with garlic',
#  'add 2 bottles of beer to the water',
#  'add beer',
#  'add a bottle of beer',
#  'add some chopped up cabbage',
#  'add to the sauce',
#  'add this to the reduced wine',
#  'add more whole mustard',
#  'add about 1 tablespoon of pickling_spice that i placed in a garni bag as there do not seem to be a lot of spices include with the corned_beef',
#  'add cabbage',
#  'add a half stick of butter',
#  'add a half-cup or so of cooking sherry',
#  'add a thin layer of light brown suger on top of the mustard',
#  'add broccoli',
#  'add one large coarsely chopped onion',
#  'add turnip along with the potatoes and carrots as well as collard greens and cabbage',
#  'add as much butter',
#  'add 2 bay leafs and use a bottle or 2 of guiness w/ the water',
#  'add alittle vinegar',
#  'add garlic',
#  'add some pearl_onion or a quartered onion',
#  'add the corned_beef',
#  'add a little chicken',
#  'add half of a yellow onion',
#  'add onion and garlic',
#  'add is an onion',
#  'add polish_sausage',
#  'add 2-3 quartered onions and several large sliced garlic',
#  'add salt',
#  'add 3 large cloves of chopped garlic',
#  'add a couple thing like a little apple_cider vinegar and seasoned_salt',
#  'add some garlic to the water and then after 2 1/2 hour i take the meat out and drained 3/4 of the water from the carrots and potatoes and layed wedges of cabbage',
#  'add 3 bottles of beer',
#  'add beef_broth',
#  'add some water',
#  'add cabbage',
#  'add a good sprinkle',
#  'add some caraway seeds when you add the cabbage',
#  'add 1/4 cup of cold water with two heaping tablespoons cornstarch',
#  'add a stick or 2 of butter',
#  'add two whole onions when i put the corned_beef',
#  'add is to wash the meat off with water',
#  'add the seasoning packet after removing the foam so you do not lose any of the seasoning',
#  'add an important flavor profile that corned_beef',
#  'add any salt',
#  'add salt',
#  'add a bay_leaf',
#  'add a 1/2 stick of butter and used beef_broth',
#  'add garlic',
#  'add the minced onion',
#  'add a little flour for a roux and add a full 15oz can of beef_broth',
#  'add a bunch of ketchup',
#  'add a lot of vinegar',
#  'add a little salt',
#  'add sweetness and spiciness to the already salty corned_beef',
#  'add the corned_beef',
#  'add garlic and green_onion',
#  'add a bit of sliced onion',
#  'add ed a few more herbs a little more garlic',
#  'add the salt',
#  'add any salt and this is a fabulous corned_beef',
#  'add salt',
#  'add more salt',
#  'add any salt',
#  'add a little celery',
#  'add salt',
#  'add the cabbage',
#  'add salt',
#  'add salt to a corned_beef',
#  'add any salt',
#  'add wedges of cabbage',
#  'add extra salt',
#  'add some brown_sugar',
#  'add some salt',
#  'add some water',
#  'add the stock from the vegetables with the chicken_stock',
#  'add parsnip',
#  'add any water',
#  'add additional carrots and celery',
#  'add any seasoning',
#  'add chopped up cabbage',
#  'add corned_beef',
#  'add more salt for seasoning',
#  'add more dressing/mustard and some garlic and onion_powder',
#  'add rye_bread',
#  'add the cabbage',
#  'add veggies at the end.. i personally do not like this.. apparently im not a cb & cabbage',
#  'add is the water',
#  'add beer',
#  'add anything but the water',
#  'add water',
#  'add a can of beef_broth and put the cabbage',
#  'add more beer',
#  'add the pepper',
#  'add any water',
#  'add cabbage',
#  'add extra flavor i used 2 cups water',
#  'add to the cabbage',
#  'add the whole can of beer',
#  'add the cabbage',
#  'add a big pan of homemade buttermilk cornbread',
#  'add the beer but added more water',
#  'add in the cabbage',
#  'add the cabbage',
#  'add the cabbage',
#  'add with soda bread',
#  'add cabbage',
#  'add 2 beef_bouillon cube and enough extra water',
#  'add the beer',
#  'add butter',
#  'add beef_broth and beer',
#  'add cabbage',
#  'add more pickling_spice',
#  'add the cabbage',
#  'add extra water to make sure the whole cut of beef',
#  'add a couple cloves of smashed garlic',
#  'add the cabbage with the corned_beef',
#  'add when cooking corned_beef and cabbage is pickling_spice',
#  'add the extra water',
#  'add a cup of water to cut the saltiness of the beef_broth',
#  'add beef bouiloon/soup base to the water',
#  'add the beer',
#  'add the cabbage',
#  'add beer',
#  'add the carrots or cabbage',
#  'add cooking time or adjust the seasoning',
#  'add a bit of salt with the seasoning packet as we do add a bit of salt but we like salt',
#  'add half can of chicken_broth',
#  'add the beer',
#  'add garlic',
#  'add fresh garlic',
#  'add the whole can of 18oz beer',
#  'add the beer',
#  'add beer',
#  'add the spices that come with the corned_beef',
#  'add the beer',
#  'add the cabbage',
#  'add the cabbage',
#  'add more potatoes & cabbage',
#  'add a little more black pepper',
#  'add so much cabbage',
#  'add more cabbage',
#  'add the cabbage',
#  'add an additional 3 tablespoons of pickling_spice',
#  'add the whole 12 ounce beer',
#  'add the cabbage',
#  'add the beer',
#  'add beer',
#  'add a tiny bit of garlic_powder and a bay_leaf',
#  'add beer',
#  'add the package of spices i put garlic into the corned_beef and cabbage',
#  'add the juices that the beef',
#  'add beer',
#  'add one large sweet_potato',
#  'add the flavor packet from the beef',
#  'add celery and do the cabbage',
#  'add 1 tbsp of garlic_salt and 1 tbsp of ground_black_pepper',
#  'add the tiny packet of seasoning',
#  'add red_onion for more flavor as well as a little kosher_salt and pepper',
#  'add 1 small onion',
#  'add 1 can golden mushroom and 1 cream of mushroom half beef_stock and half red_wine',
#  'add some worcestershire_sauce',
#  'add the squash and zucchini',
#  'add some cayenne_pepper and garlic_powder',
#  'add at least a cup of red_wine',
#  'add some pepper and salt to the crock-pot tv coverage for 3 to 5 hour on either high or low and at the end youll have a delicious soft beef',
#  'add a can of beef',
#  'add a little wine',
#  'add 1 packet of brown gravy_mix',
#  'add a bit of garlic',
#  'add any raw onion',
#  'add 1 big onion',
#  'add some red_wine',
#  'add any onion',
#  'add a little more seasoning',
#  'add a little cayenne_pepper',
#  'add in some flour mixed with water',
#  'add cornstarch or flour',
#  'add some red_wine',
#  'add the onion',
#  'add liptons french onion_soup',
#  'add a little less beer',
#  'add a tad more garlic',
#  'add in some celery and i subbed in a little ketchup for the tomato_paste',
#  'add tomato_paste and thyme',
#  'add more flour',
#  'add about 1 cup of water',
#  'add any additional water',
#  'add to the tenderness of the beef',
#  'add some beef_stock',
#  'add beef_bouillon cubes with the water',
#  'add a splash of red_wine',
#  'add one packet of onion_soup mix after i brown the roast as im adding the water',
#  'add beef_bouillon',
#  'add a good splash of wine',
#  'add water',
#  'add 1 package dry onion_soup & 1 can or bottle of beer',
#  'add the milk and flour',
#  'add a can of beef_stock',
#  'add water',
#  'add so much water',
#  'add oregano and thyme',
#  'add bay_leaf',
#  'add beef_broth',
#  'add bay_leaf',
#  'add onions to the carrots and celery',
#  'add potatoes and carrot',
#  'add some seasoned_salt and coarse pepper',
#  'add a few more item and you have bbq sauce',
#  'add any celery',
#  'add the whole package of brown gravy_mix',
#  'add a can of golden mushroom',
#  'add cornstarch',
#  'add salt',
#  'add some corn',
#  'add some onion',
#  'add some water',
#  'add salt and pepper',
#  'add more vegetables and use the entire package of gravy_mix',
#  'add some extra water',
#  'add so much celery',
#  'add more celery',
#  'add more beer',
#  'add a good sized sweet_onion',
#  'add some more seasoning',
#  'add a gravy_mix',
#  'add sea_salt',
#  'add a bit of freshly ground_black_pepper',
#  'add salt',
#  'add garlic',
#  'add salt',
#  'add some pepper and garlic_powder',
#  'add salt',
#  'add half soda/half beer',
#  'add too much salt',
#  'add a little corn',
#  'add more soda or some brown_sugar',
#  'add a lot more carrots and i also used sweet potatoes and celery',
#  'add 6 cloves of garlic',
#  'add cream of mushroom and cream of celery',
#  'add some flour',
#  'add golden potatoes quartered and i use rump_roast',
#  'add more carrots and celery',
#  'add half the can of pop and toss in some beef_broth',
#  'add salt and instead_of pepper i tossed in some montreal steak',
#  'add a couple of shakes from the worcestershire_sauce',
#  'add more carrots used beefy lipton onion_soup',
#  'add a few pepperoncini peppers and a package of dry ranch seasoning along with a packet of au jus and will not add the packet of brown gravy and will add a stick of butter',
#  'add some cooking sherry',
#  'add water',
#  'add more salt',
#  'add lot of blk pepper',
#  'add celery',
#  'add another can of cream_of_mushroom_soup',
#  'add seasoned_salt and garlic_powder',
#  'add the wine',
#  'add 1 more can of the mushroom',
#  'add a teaspoon of horseradish',
#  'add the cream_of_mushroom_soup',
#  'add a cup of strong beef_stock along with the mushroom',
#  'add a little garlic',
#  'add any salt',
#  'add garlic to the flour mixture as well as some salt',
#  'add 1 tsp of emerils creole_seasoning to the flour',
#  'add some beef_stock',
#  'add all the veggies and potatoes and a little water',
#  'add this sauce to other_meat',
#  'add one extra can of cream_of_mushroom_soup',
#  'add a little bit of corn starch 10 minute prior to serving to thicken the sauce',
#  'add 1 cup beef_stock',
#  'add the vermouth and doubled the onion dip and cream of mushroom',
#  'add some beef_stock',
#  'add celery',
#  'add 4 springs of rosemary',
#  'add salt',
#  'add some montreal steak_seasoning to the flour',
#  'add some water',
#  'add to mushroom',
#  'add 1/4 cup butter',
#  'add fresh onion',
#  'add some garlic_powder',
#  'add sour_cream for the last hour of roasting and then i have sour_cream',
#  'add beef_broth instead_of wine',
#  'add a little more seasoning',
#  'add some more pepper',
#  'add bbq sauce',
#  'add a little wondra gravy flour or regular flour',
#  'add a little salt and some pepper',
#  'add a little flour',
#  'add 2 t. of cornstarch',
#  'add a can of cream of celery',
#  'add some cornstarch',
#  'add water',
#  'add any salt but do add pepper',
#  'add some carrots and celery',
#  'add as much water',
#  'add water',
#  'add the onion',
#  'add all of the soup_mix',
#  'add vegetables such as potato',
#  'add 4 or 5 dashes of worsteshire sauce',
#  'add a a little worcestershire_sauce and garlic_powder before the soup and onion_soup',
#  'add 1 can of mushroom',
#  'add in one can of lemon-lime soda in place of the water',
#  'add in two packets of onion_soup',
#  'add a can of beef_broth',
#  'add a little flour',
#  'add about 1 tsp of rosemary',
#  'add a jar of beef_gravy to the mushroom',
#  'add onions and garlic',
#  'add less water as the cooking method adds more water',
#  'add a chopped onion',
#  'add the water',
#  'add the cream_of_mushroom_soup',
#  'add and some beef_broth in the bottom for extra juice or add dry beef',
#  'add a table spoon and a half of cornstarch',
#  'add a lot of salt',
#  'add some red_wine',
#  'add the broth mixture to it 11. add rosemary',
#  'add to beef',
#  'add 2cans of golden cream_of_mushroom_soup 2 cans of cream of celery soup 2cans of beef_broth',
#  'add red_wine',
#  'add a 1/2 c to 3/4 c of flour to water',
#  'add a few slices of green_bell_pepper',
#  'add one can of beef_broth instead_of water',
#  'add more water',
#  'add some garlic_powder to the roast before pouring the combined soups and wine',
#  'add a couple of dashes of worcestershire_sauce & about a 1/2 cup of milk & 1/2 cup of chicken_broth',
#  'add a 1/4 cup of flour into the crockpot & carefully mix it in really well for the last hour and break up any lumping from the flour',
#  'add mushrooms and sour_cream',
#  'add 1/2 an onion and 3 whole cloves of garlic',
#  'add the steak_seasoning',
#  'add the coffee',
#  'add the tomato_sauce',
#  'add the coffee',
#  'add corn',
#  'add 1/2 the boullion or low sodium due to the salt in the seasoning',
#  'add the tomato_sauce or oregano but the coffee',
#  'add a brown gravy_mix use the beef juice instead_of the water',
#  'add the onion',
#  'add garlic and a tablespoon of italian_seasoning',
#  'add water and will probably add another can of cranberry_sauce',
#  'add 1 can mushroom',
#  'add a bay_leaf and added more garlic',
#  'add carrots and celery',
#  'add sliced apple',
#  'add beef_broth',
#  'add more salt',
#  'add potato',
#  'add the beef_broth',
#  'add the lipton onion_soup mix and 1 cup of water',
#  'add salt',
#  'add 1 can cream_of_mushroom_soup',
#  'add any additional liquid like broth or water',
#  'add a little extra onion and garlic',
#  'add water',
#  'add about a cup of red_wine',
#  'add more garlic',
#  'add a teaspoon of butter',
#  'add about a cup of beef_stock',
#  'add some beef_broth',
#  'add a little cornstarch or flour',
#  'add the additional salt',
#  'add cornstarch and chicken_stock',
#  'add about 4oz of beef_broth',
#  'add vegetables & beef_broth',
#  'add some sprigs of rosemary',
#  'add a half cup of burgundy wine',
#  'add water',
#  'add more wine/water at the beginning i think because the sauce',
#  'add some cornstarch & water',
#  'add in some basil',
#  'add an extra onion',
#  'add a can of beef_broth',
#  'add some rosemary',
#  'add thickener like flour or cornstarch',
#  'add a can of beef_broth and a cup of red_wine',
#  'add about a cup beef_broth',
#  'add flour',
#  'add 1 c. water and then a beef_bouillon',
#  'add some red_wine',
#  'add water',
#  'add water',
#  'add so mushrooms to it and a little bit of cajun_seasoning',
#  'add 1/2 tsp of sugar',
#  'add wine',
#  ...]
