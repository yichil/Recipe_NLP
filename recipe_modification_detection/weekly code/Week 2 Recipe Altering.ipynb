# %%
import re
import pandas as pd
import nltk
import unicodedata
import csv
import itertools
from tqdm import trange

# %%
# lemmatization dict
lemma_list = pd.read_csv('/Users/nessyliu/Desktop/RA/lemma_list.csv')
lemma_dict = lemma_list.set_index('word_list').to_dict()['lemma_list']

# %%
# Read in the datasets
df = pd.read_csv('/Users/nessyliu/Desktop/RA/AllReviews_26thNov2019.csv')
df_ingredients_raw = pd.read_csv('/Users/nessyliu/Desktop/RA/part_2/Ingredients.csv')
df_cluster = pd.read_excel('/Users/nessyliu/Desktop/RA/part_2/Cluster_names.xlsx')

# %%
df = df.head(30000)

# %%
# list of cluster names with spaces (e.g. apple juice) sorted by number of words in each name, 
# e.g. "apple juice" should appear before "juice"
cluster_name_orig_list = df_cluster.cluster_name.tolist()
cluster_name_orig_list.sort(key=lambda x: len(x.split()), reverse=True)

# create dict to map recipe_id to ingredient_ids
df_ingredients = df_ingredients_raw.groupby('recipe_id')['ingredient_id'].apply(list).reset_index(name ='ingredients')
dict_recipe_ingredients = dict(zip(df_ingredients.recipe_id, df_ingredients.ingredients))

# create dict to map ingredient_id to cluster_name
df_cluster = df_cluster.replace(' ', '_', regex=True)
dict_ingredient_clustername = dict(zip(df_cluster.ingredient_id, df_cluster.cluster_name))

# list of cluster names with underscore, e.g. apple_juice, so that when check 'apple', won't confuse with 'apple juice'
cluster_name_list = df_cluster.cluster_name.tolist()

recipe_id_list = df.recipe_id.tolist()
review_id_list = df.review_id.tolist()
review_list = df.review_text.tolist()

# %%
# Map for expanding contractions in case of negations
CONTRACTION_MAP = {
    "ain't": "is not",
    "aren't": "are not",
    "can't": "can not",
    "cannot": "can not",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hasn't": "has not",
    "haven't": "have not",
    "isn't": "is not",
    "mayn't": "may not",
    "mightn't": "might not",
    "mustn't": "must not",
    "needn't": "need not",
    "shan't": "shall not",
    "sha'n't": "shall not",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "wasn't": "was not",
    "weren't": "were not",
    "won't": "will not",
    "wouldn't": "would not",
}

contain_ingre_flag_list = []
addition_flag_list = []
deletion_flag_list = []
replacement_flag_list = []

ingre_in_recipe_list = []
ingre_not_recipe_list = []
ngram_in_list = []
ngram_not_list = []
recipe_list = []

real_addition_list = [] # terms caught by addition grammar but the ingredient is already in the recipe
false_addition_list = [] # terms caught by addition grammar and the ingredient is not in the recipe
real_deletion_list = [] # terms caught by deletion grammar and the ingredient is in the recipe
false_deletion_list = [] # terms caught by deletion grammar but the ingredient is not in the recipe
replacement_list = [] # terms indicating replacement

new_ingre_not_matched_list = [] # the ingredients not in recipe, but also isn't detected as an addition or replacement

clean_text_list = [] # review text after cleaning

# %%
def deal_with_ingredient(text, recipe):
    # tokenize the review text
    sentences = nltk.sent_tokenize(text)
    tokens_sentences = [nltk.word_tokenize(sent) for sent in sentences]
    tokens = list(itertools.chain.from_iterable(tokens_sentences))
    flag = False
    
    # detect ingredients and get ngrams
    ingre_in_recipe = []
    ingre_not_recipe = []
    ngram_in = []
    ngram_not = []
    ngrams = list(nltk.everygrams(tokens, 4, 4))
    ngrams = [list(ngram) for ngram in ngrams] 
    detected_ingredients = [token for token in tokens if token in cluster_name_list] 
    if len(detected_ingredients) > 0:
        flag = True
    for ingre in detected_ingredients:
        if ingre in recipe:
            ingre_in_recipe.append(ingre)
            ngram_in.append([ngram for ngram in ngrams if ingre in ngram])
        else:
            ingre_not_recipe.append(ingre)
            ngram_not.append([ngram for ngram in ngrams if ingre in ngram])
    
    
    return flag, list(set(ingre_in_recipe)), list(set(ingre_not_recipe)), ngram_in, ngram_not

# %%
def text_processing(df):
    """
    text processing
    """
    for i in trange(0,len(df)):
        
        # get the recipe for the review and sort by number of words, e.g. [white_chocolate_chip, apple_juice, water]
        recipe_id = df.iloc[i]['recipe_id']
        try:
            recipe = [dict_ingredient_clustername[ingre_id] for ingre_id in dict_recipe_ingredients[recipe_id]]
            recipe.sort(key=lambda x: len(x.split('_')), reverse=True)
        except:
            recipe = [] # if the recipe id is not in the recipe_ingredient map list
        
        text = df.iloc[i]['review_text']
        
        # Convert to lower case
        text = text.lower()

        # Normalize the accented characters
        text = normalize_accented_characters(text)

        # Expand contractions, e.g. didn't --> did not
        text = expand_contractions(text, CONTRACTION_MAP)
        
        # Lemmatize the text, e.g. removed --> remove
        text = lemmatization(text)
        
        # concatenate some special phrases such as "instead_of"
        text = concat_phrase(text)

        # Standardize ingredients in the reviews (which appear in the cluster name list) by:
        #   Step 1: Concatenate recipe-ingredient phrases with '_', e.g. 'apple juice' --> 'apple_juice'
        #   Step 2: For recipe-ingredients only, check whether shorter versions appear in the review 
        #      and replace with full-length version. e.g. 'juice' --> 'apple_juice' if 'apple_juice' in recipe
        #   Step 3: Concatenate nonrecipe-ingredient phrases
        text = standardize_ingredient_in_review(text, recipe)
        
        clean_text_list.append(text)

        
        # check whether review contain ingredient words in cluster name list, 
        # get the ingredients in the recipe and the ingredients not in the recipe
        # also get the ngrams containing the detected ingredient words
        flag, ingre_in_recipe, ingre_not_recipe, ngram_in, ngram_not = deal_with_ingredient(text, recipe)
        contain_ingre_flag_list.append(flag)
        ingre_in_recipe_list.append(ingre_in_recipe)
        ingre_not_recipe_list.append(ingre_not_recipe)
        ngram_in_list.append(ngram_in)
        ngram_not_list.append(ngram_not)
        
        recipe_list.append(recipe)
        
        
        # Extract terms indicating altering
        false_addition_terms, real_addition_terms = addition_extraction(text, recipe)
        false_deletion_terms, real_deletion_terms = deletion_extraction(text, recipe)
        replacement_terms = replacement_extraction(text, recipe)
        
        if len(real_addition_terms) > 0:
            addition_flag_list.append(True)
        else:
            addition_flag_list.append(False)

        if len(real_deletion_terms) > 0:
            deletion_flag_list.append(True)
        else:
            deletion_flag_list.append(False)
            
        if len(replacement_terms) > 0:
            replacement_flag_list.append(True)
        else:
            replacement_flag_list.append(False)
            
        # Filter the ingredients that are not in the recipe but also not detected as add/delete/replace
        new_ingre_not_matched = []
        all_detected_terms = false_addition_terms + real_addition_terms + false_deletion_terms + real_deletion_terms + replacement_terms
        all_detected_terms_tokens = ' '.join(all_detected_terms)
        new_ingre_not_matched = [ingre for ingre in ingre_not_recipe if ingre not in all_detected_terms_tokens.split()]
        
        # append all the above results
        replacement_list.append(replacement_terms)
        real_addition_list.append(real_addition_terms)
        false_addition_list.append(false_addition_terms)
        real_deletion_list.append(real_deletion_terms)
        false_deletion_list.append(false_deletion_terms)
        new_ingre_not_matched_list.append(new_ingre_not_matched)


def standardize_ingredient_in_review(text, recipe):
    # Example:
    # Input text: I omit chocolate chip.
    # Recipe: [white chocolate chip, ...], both "white chocolate chip" and "chocolate chip" are in cluster name list.
    # Output text: I omit white_chocolate_chip.
    
    # Step 1:
    # concatenate the recipe-ingredient phrases
    # since the recipe is sorted by # of words in each ingredient, longest ingredient will be replaced first
    # e.g. "white chocolate chip" will be detected and replaced by "white_chocolate_chip", not "chocolate_chip"
    for ingre in recipe:
        ingre_with_space = ' '.join(ingre.split('_'))
        text = re.sub(r'\b' + ingre_with_space + r'\b', ingre, text)  
    
    # Step 2:
    # for recipe-ingredients, check whether shorter version exists in review, 
    # if yes then replace with concatenated full-length version
    # shorter version definition: BC and C are shorter versions of ABC, but A or AB are not shorter versions of ABC
    # e.g. for 'black pepper sauce': 'pepper sauce' and 'sauce' are its shorter version, but 'black pepper' is not
    for ingre in recipe:        
        splitted_ingre = ingre.split('_')
        while len(splitted_ingre)>1:
            splitted_ingre.pop(0) # remove the 1st word in this ingre, e.g. [black,pepper,sauce] -> [pepper sauce]
            shorter_version = ' '.join(splitted_ingre)
            text = re.sub(r'\b' + shorter_version + r'\b', ingre, text) # replace shorter version with full-length ingre
    
    # Step 3:
    # concatenate the nonrecipe-ingredient phrases
    # since the cluster_name_orig_list is sorted by # of words in each ingredient, longest ingredient will be replaced first
    for cluster in cluster_name_orig_list:
        text = re.sub(r'\b' + cluster + r'\b', cluster.replace(' ', '_'), text)
        
    return text


def concat_phrase(text):
    # concatenate some important phrases for the ease of detection
    text = re.sub(r'\binstead of\b', 'instead_of', text)
    text = re.sub(r'\bleave out\b', 'leave_out', text)
    text = re.sub(r'\bleave off\b', 'leave_off', text)
    text = re.sub(r'\bbother with\b', 'bother_with', text)
    return text


def normalize_accented_characters(text):
    """
    In case of Unicode characters
    """
    # text = unicodedata.normalize('NFKD', text)
    text = unicodedata.normalize('NFC', text)
    text = text.replace("“", '"').replace("”", '"').replace("’", "'").replace("‘", "'").replace('–', '-')
    text = re.sub('ı', 'I', text)
    return text


def expand_contractions(text, contraction_mapping):
    """
    Expand contractions in case of negations, e.g. isn’t -> is not
    """
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
                                      flags=re.IGNORECASE | re.DOTALL)

    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match) \
            if contraction_mapping.get(match) \
            else contraction_mapping.get(match.lower())
        expanded_contraction = first_char + expanded_contraction[1:]
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text


def lemmatization(text):
    """
    Lemmatize the text
    """
    # use the custom lemma dict first
    text = " ".join(str(lemma_dict.get(word, word)) for word in text.split())
    
    # then use the WordNetLemmatizer from nltk
    from nltk import word_tokenize, pos_tag
    from nltk.stem import WordNetLemmatizer
    wnl = WordNetLemmatizer()
    # lemmatize each word based on its pos tagging
    text_after = " ".join([wnl.lemmatize(i,j[0].lower()) if j[0].lower() in ['a','n','v'] else wnl.lemmatize(i) for i,j in pos_tag(word_tokenize(text))])    
    return text_after


def replacement_extraction(text, recipe):
    """
    extract Replacement terms
    """
    sentences = nltk.sent_tokenize(text)
    tokens_sentences = [nltk.word_tokenize(sent) for sent in sentences]
    tagged_sentences = [tagger.tag(sent) for sent in tokens_sentences]
    DESC_list = []
    for sent_tagged in tagged_sentences:  # each sentence
        sent_tree = key_phrases_cp.parse(sent_tagged)  # chunk each sentence based on grammar structure
        DESC_in_this_sent = []
        for subtree in sent_tree.subtrees():
            if subtree.label() == "REPLACEMENT_TERM":
                string = str(subtree)
                string = re.sub('\n', '', string)
                string = re.sub('\s+', ' ', string)
                string = re.sub('REPLACEMENT_TERM ', '', string)
                string = re.sub('\/[A-Z]+\$*', '', string)
                string = re.sub('\(', '', string)
                string = re.sub('\)', '', string)

                DESC_in_this_sent.append(string)
        if DESC_in_this_sent != []:
            DESC_list.extend(DESC_in_this_sent)
    DESC_list = list(set(DESC_list))
    return DESC_list


def addition_extraction(text, recipe):
    """
    extract Addition terms
    """
    sentences = nltk.sent_tokenize(text)
    tokens_sentences = [nltk.word_tokenize(sent) for sent in sentences]
    tagged_sentences = [tagger.tag(sent) for sent in tokens_sentences]
    false_additions = []
    real_additions = []
    for sent_tagged in tagged_sentences:  # each sentence
        sent_tree = key_phrases_cp.parse(sent_tagged)  # chunk each sentence based on grammar structure
        false_additions_in_this_sent = []
        real_additions_in_this_sent = []
        for subtree in sent_tree.subtrees():
            if subtree.label() == "ADDITION_TERM":
                word_list = []
                # check whether the ingredient word in this term is in the original recipe
                flag = True # flag is true if the ingredient word is in the recipe
                for (word, tag) in subtree.leaves():
                    word_list.append(word)
                    if tag == 'INGREDIENT':
                        if word not in recipe:
                            flag = False
                string = ' '.join(word_list)
                if flag == True: # if the ingredient is in the recipe, it is a false addition (e.g. modify quantities)
                    false_additions_in_this_sent.append(string)
                else: # if the ingredient is not in the recipe, it is a real addition
                    real_additions_in_this_sent.append(string)

        if false_additions_in_this_sent != []:
            false_additions.extend(false_additions_in_this_sent)
        if real_additions_in_this_sent != []:
            real_additions.extend(real_additions_in_this_sent)
    false_additions = list(set(false_additions))
    real_additions = list(set(real_additions))
    return false_additions, real_additions


def deletion_extraction(text, recipe):
    """
    extract Deletion terms
    """
    sentences = nltk.sent_tokenize(text)
    tokens_sentences = [nltk.word_tokenize(sent) for sent in sentences]
    tagged_sentences = [tagger.tag(sent) for sent in tokens_sentences]
    false_deletions = []
    real_deletions = []
    for sent_tagged in tagged_sentences:  # each sentence
        sent_tree = key_phrases_cp.parse(sent_tagged)  # chunk each sentence based on grammar structure
        false_deletions_in_this_sent = []
        real_deletions_in_this_sent = []
        for subtree in sent_tree.subtrees():
            if subtree.label() == "DELETION_TERM":
                word_list = []
                # check whether the ingredient word in this term is in the original recipe
                flag = True # flag is true if the ingredient word is in the recipe
                for (word, tag) in subtree.leaves():
                    word_list.append(word)
                    if tag == 'INGREDIENT':
                        if word not in recipe:
                            flag = False
                string = ' '.join(word_list)
                if flag == False: # if the ingredient is not in the recipe, it is a false deletion
                                  # e.g. "It's good that the recipe contains no milk cuz I don't have any milk"
                    false_deletions_in_this_sent.append(string)
                else: # if the ingredient is in the recipe, it is a real deletion
                    real_deletions_in_this_sent.append(string)

        if false_deletions_in_this_sent != []:
            false_deletions.extend(false_deletions_in_this_sent)
        if real_deletions_in_this_sent != []:
            real_deletions.extend(real_deletions_in_this_sent)
    false_deletions = list(set(false_deletions))
    real_deletions = list(set(real_deletions))
    return false_deletions, real_deletions



# Custom our own tagger for POS tagging, and use python's default tagger as backup
custom_tagger = {
    # replacement
    'replace': 'REPLACEMENT', 'substitute': 'REPLACEMENT', 'instead_of': 'REPLACEMENT',
    # deletion
    'delete': 'DELETION', 'remove': 'DELETION', 'omit': 'DELETION', 'subtract': 'DELETION', 'skip': 'DELETION',
    'eliminate': 'DELETION', 
    'leave_out': 'DELETION', 'leave_off': 'DELETION',
    'bother_with': 'BOTHERWITH',
    # addition
    'add': 'ADDITION', 'use': 'ADDITION', 'put': 'ADDITION', 'incorporate': 'ADDITION',
    # other tags
    'no': 'NO',
    'not': 'NOT',
    'that': 'DT',
    'with': 'IN',
    'even': 'EVEN',
    'have': 'HAVE',
    'like': 'LIKE'}

ingredient_tagger = {}
for ingre in cluster_name_list:
    ingredient_tagger[ingre] = 'INGREDIENT'
    
custom_tagger_combined = {**custom_tagger, **ingredient_tagger}

default_tagger = nltk.data.load("/Users/nessyliu/nltk_data/taggers/maxent_treebank_pos_tagger/english.pickle")
tagger = nltk.tag.UnigramTagger(model=custom_tagger_combined, backoff=default_tagger)

# Define grammar structures for extracting negation phrases and then creativity words
key_phrases_grammar = r"""
    REPLACEMENT_TERM:
        # e.g. don't have/like apple so ADDITION(add/use/put/...) banana
        {<NOT>(<HAVE>|<LIKE>)<[A-Z]*>{0,4}<INGREDIENT><[A-Z]*>{0,4}<ADDITION><[A-Z]*>{0,4}<INGREDIENT>}
        
        # e.g. have no apple so ADDITION(add/use/put/...) banana
        {<HAVE><NO><INGREDIENT><[A-Z]*>{0,4}<ADDITION><[A-Z]*>{0,4}<INGREDIENT>}
        
        # e.g. ADDITION(add/use/put/...) banana cuz don't have/like apple
        {<ADDITION><[A-Z]*>{0,4}<INGREDIENT><[A-Z]*>{0,4}<NOT>(<HAVE>|<LIKE>)<[A-Z]*>{0,4}<INGREDIENT>}
        
        # e.g. ADDITION(add/use/put/...) banana cuz have no apple
        {<ADDITION><[A-Z]*>{0,4}<INGREDIENT><[A-Z]*>{0,4}<HAVE><NO><INGREDIENT>}
        
        # e.g. ADDITION(add/use/put/...) banana instead of apple
        {<ADDITION><[A-Z]*>{0,4}<INGREDIENT><REPLACEMENT><INGREDIENT>}
        
        # e.g. instead of apple I ADDITION(add/use/put/...) banana 
        {<REPLACEMENT><INGREDIENT><[A-Z]*>{0,4}<ADDITION><[A-Z]*>{0,4}<INGREDIENT>}
        
        # e.g. replace the Apple with some Banana
        {<REPLACEMENT><[A-Z]*>{0,4}<INGREDIENT><IN><DT>?<[A-Z]*>{0,4}<INGREDIENT>}
        
        # e.g. didn't use Apple, replace with Banana
        {<INGREDIENT><[A-Z]*>{0,4}<REPLACEMENT><IN><[A-Z]*>{0,4}<INGREDIENT>}
        
        # <DELETION> ingre and <REPLACEMENT> ingre
        # e.g. I omitted apple and substitute with banana
        {<DELETION><[A-Z]*>{0,4}<INGREDIENT><[A-Z]*>{0,4}<REPLACEMENT><[A-Z]*>*<INGREDIENT>}
        
    DELETION_TERM:
        ### Extract negation with "have" 
        # not have + ingredient"
        # e.g. "I didn't have any Beef"
        {<NOT><HAVE><[A-Z]*>{0,4}<INGREDIENT>}
        
        # "have no + ingredient"
        # e.g. "I had no Beef"
        {<HAVE><NO><INGREDIENT>}
        
        ### Extract negation with addition words
        # e.g. "I didn't add any water", "I use no milk"
        {<NOT><ADDITION><[A-Z]*>{0,4}<INGREDIENT>}
        {<ADDITION><NO><INGREDIENT>}
        
        ### Extract "deletion + ingredient"
        # e.g. "I removed Apple", "I deleted the Beef", "I left off the Beef"
        {<DELETION><[A-Z]*>{0,4}<INGREDIENT>}
        
        ### Extract negation terms with "bother with"
        # e.g. "I didn't bother with the Beef"
        {<NOT><BOTHERWITH><[A-Z]*>*<INGREDIENT>}      
    
    ADDITION_TERM:
        # e.g. I added {0-4 words such as "some", "a bit"} Milk
        {<ADDITION><[A-Z]*>{0,4}<INGREDIENT>}
"""
key_phrases_cp = nltk.RegexpParser(key_phrases_grammar)

# %%
text = "i do not like onion so i use onion_powder instead "
replacement_extraction(text, ['worcestershire_sauce', 'onion', 'beer', 'beef', 'water', 'liquid_smoke', 'salt', 'ground_black_pepper', 'garlic_powder', 'barbeque_sauce'])
# Out:
# ['not like onion so i use onion_powder']

# %%
print(standardize_ingredient_in_review('i omit chocolate chip', ['white_chocolate_chip','dried_apple'])) # correct
print(standardize_ingredient_in_review('i use apple', ['white_chocolate_chip','dried_apple'])) # incorrect
# Out:
# i omit white_chocolate_chip
# i use dried_apple

# %%
text_processing(df)
# Out:
# 100%|██████████| 30000/30000 [1:03:03<00:00,  7.93it/s]

# %%
result_df = pd.DataFrame({
    'recipe_id': recipe_id_list,
    'review_id': review_id_list,
    'review_text': review_list,
    'clean_text': clean_text_list,
    'recipe': recipe_list,
    'flag': contain_ingre_flag_list,
    'ingre_in_recipe': ingre_in_recipe_list,
    'ingre_not_recipe': ingre_not_recipe_list,
    'ngram_in': ngram_in_list,
    'ngram_not': ngram_not_list,
    'addition_flag': addition_flag_list,
    'deletion_flag': deletion_flag_list,
    'replacement_flag': replacement_flag_list,
    'real_addition_terms': real_addition_list,
    'false_addition_terms': false_addition_list,
    'real_deletion_terms': real_deletion_list,
    'false_deletion_terms': false_deletion_list,
    'replacement_terms': replacement_list,
    'new_ingre_not_matched': new_ingre_not_matched_list
})


result_df.to_csv('/Users/nessyliu/Desktop/RA/part_2/result/result_df_w2.csv')

review_with_ingre_df = result_df.loc[result_df['flag'] == True]
review_with_ingre_df.to_csv('/Users/nessyliu/Desktop/RA/part_2/result/review_with_ingre_df_w2.csv')

# %%
print(len(review_with_ingre_df))
print(len(result_df))
# Out:
# 20838
# 30000

# %%
list(itertools.chain.from_iterable(replacement_list))
# Out:
# ['instead_of onion i use onion',
#  'not like onion so i use onion garlic_powder',
#  'use some fresh garlic and beef_stock instead_of water',
#  'use beef_broth instead_of water',
#  'use 1 beer and beef_broth instead_of water',
#  'omit the liquid_smoke flavoring and substitute an 18oz bottle of sweet baby ray original barbeque_sauce',
#  'not have can tomato on hand i use spaghetti_sauce',
#  'not like cook tomato so i have to add some water',
#  'use pasta instead_of white_rice',
#  'substitute lime for lemon_juice',
#  'replace brandy for gin and bitter for dry_vermouth',
#  'substitute vodka for the gin',
#  'not have any potato flake so i use bread_crumb',
#  'substitute olive vegetable_oil for the veg vegetable_oil',
#  'not have tomato_juice so i use cherry_tomato worcestershire_sauce',
#  'substitute the water with a nice dark belgian beer',
#  'use steak instead_of veal',
#  'use cube_steak instead_of veal',
#  'use beef instead_of veal',
#  'use chicken_breast and make it chicken fry chicken because i have no steak',
#  'use cube_steak instead_of veal',
#  'use rosemary instead_of dried_tarragon',
#  'have no dried_tarragon add carrot',
#  'use chicken_broth instead_of water',
#  'use buttermilk instead_of milk',
#  'substitute chicken beef_liver for beef_liver',
#  'use cornstarch instead_of all_purpose_flour',
#  'use peanut_oil instead_of butter',
#  'instead_of milk i decide to use buttermilk',
#  'use turkey kielbasa_sausage instead_of pork',
#  'substitute balsamic_vinegar for the red_wine',
#  'instead_of beef_bouillon cube and water i use 1 can of beef_broth',
#  'not have condensed_golden_mushroom_soup so i use regular cream of mushroom',
#  'use greek_yogurt instead_of sour_cream',
#  'use tomato_sauce instead_of tomato_paste',
#  'use ground venison and tomato_sauce instead_of tomato_paste',
#  'not have chive and do not use mushroom',
#  'not have potato so i add egg_noodle',
#  'not have garlic so i add garlic_salt instead_of salt',
#  'use chicken beef_broth instead_of beef',
#  'use all beef_broth instead_of water',
#  'use chicken beef_broth instead_of beef',
#  'not have corn_syrup and use maple corn_syrup',
#  'use almond instead_of pecan',
#  'not have ham available but use canadian bacon',
#  'add basil instead_of spinach',
#  'instead_of the brown_sugar in the egg',
#  'not have peach preserve so i use adriatic fig',
#  'use chicken instead_of grouse and apricot instead_of peach_jam',
#  'substitute tarragon with marjoram',
#  'use cashew instead_of almond',
#  'replace the sour_cream with nonfat plain greek_yogurt',
#  'substitute chipotle_pepper for the ancho_chile_pepper',
#  'use young kale instead_of cabbage',
#  'substitute beef_broth for the water',
#  'use beef_broth instead_of water',
#  'use condense beef_broth instead_of water',
#  'use all those onion cause i do not have them and i add mushroom',
#  'substitute red_wine white_vinegar for the white_vinegar',
#  'use bragg apple_cider white_vinegar instead_of white_vinegar',
#  'add beef_broth instead_of water',
#  'instead_of water i use beef_broth',
#  'not have cumin_seed or garam_masala but add a few shake of ground_cumin',
#  'use canola grapeseed_oil instead_of grapeseed_oil',
#  'use garlic_powder instead_of garlic_salt',
#  'use ground_turkey instead_of ground_beef',
#  'omit the carrot and replace them with bell ground_black_pepper',
#  'substitute the potato for leftover cook rice',
#  'substitute fresh potato for canned new_potato and can carrot',
#  'substitute baby_carrot and i add some seasoning',
#  'substitute chicken for the ground_beef and add a little more seasoning',
#  'add 1/2 cup of chocolate_chip instead_of date',
#  'use olive coconut_oil instead_of coconut_oil',
#  'substitute some pumpkin_puree for some of the mash banana',
#  'substitute sliced almond for the pecan and raisin',
#  'use a regular smoked_sausage instead_of pepperoni',
#  'replace the cup of steel_cut_oat with a cup of cook hulled barley',
#  'use season salt instead_of garlic_salt',
#  'not have paprika so i use chili onion_powder',
#  'substitute the dried_rosemary with thyme',
#  'not have any red_wine_vinegar so i use apple_cider red_wine_vinegar',
#  'not have red_wine_vinegar so i use apple_cider red_wine_vinegar',
#  'use olive vegetable_oil instead_of vegetable_oil',
#  'replace paprika with chili onion_powder',
#  'use smoke paprika instead_of paprika',
#  'use clam_juice instead_of fish_stock a i do not have the fish_stock',
#  'not have fish_stock so i use clam_juice from the canned clam',
#  'green_onion but substitute with chive',
#  'add raisin instead_of dried_cranberry',
#  'brown_sugar substitute for the brown_sugar',
#  'substitute soy whole_milk for the whole_milk and canadian maple_syrup',
#  'substitute half the honey for some smooth almond_butter',
#  'add a tbsp of garlic instead_of horseradish',
#  'substitute worsheschire soy_sauce for the soy_sauce',
#  'use beer instead_of water',
#  'substitute a cup of beer for the water',
#  'instead_of barbeque_sauce add a jar of beef_gravy',
#  'use beer instead_of water',
#  'use beer instead_of water',
#  'use one cup beer instead_of water',
#  'use beer instead_of water',
#  'replace the water with beer',
#  'use beer instead_of water',
#  'replace water with beer',
#  'substitute garlic onion_powder for onion_powder',
#  'use chop green_onion instead_of chive',
#  'not have saltine_cracker on hand so i use garlic flavor ritz saltine_cracker',
#  'substitute ground_turkey for the ground_beef & add a packet of onion_soup',
#  'use ground_turkey instead_of ground_beef',
#  'omit the parsley and substitute corn',
#  'substitute the saltine_cracker for plain bread_crumb',
#  'use panko bread_crumb instead_of saltine_cracker',
#  'substitute ground_turkey for the ground_beef',
#  'use italian bread_crumb instead_of saltine_cracker',
#  'use turkey instead_of ground_beef',
#  'leave_out the parsley and replace it with kale',
#  'use chicken_broth instead_of water',
#  'use turkey instead_of ground_beef',
#  'use ground_turkey instead_of ground_beef',
#  'substitute beer for the water',
#  'use more ketchup instead_of tomato_sauce',
#  'use beer instead_of water',
#  'substitute some sesame_oil for part of the butter',
#  'use chicken_broth instead_of water',
#  'replace butter with olive_oil',
#  'use olive_oil instead_of butter',
#  'use chicken_broth instead_of water',
#  'use chicken_stock instead_of water',
#  'use chicken_broth instead_of water',
#  'use 3 cup of chicken_broth instead_of water',
#  'substitute the water with either beef or chicken_broth',
#  'add chicken_broth instead_of water',
#  'substitute beef_broth for plain water',
#  'use low sodium chicken_broth instead_of water',
#  'use chicken_broth instead_of water',
#  'omit the onion and replace it with chop garlic',
#  'instead_of ketchup i use barbeque_sauce',
#  'not have any onion so i add red ground_black_pepper',
#  'use onion_powder cuz i do not have onion',
#  'not have dry_mustard i use dijon dry_mustard',
#  'use beef_broth instead_of water',
#  'use ground venison instead_of beef',
#  'use 1/2 c olive_oil instead_of lard',
#  'substitute venison for beef',
#  'use spicy brown mustard instead_of mustard',
#  'substitute substitute 1t grey poupon mustard for the mustard_seed',
#  'use a little olive_oil instead_of butter',
#  'use beef_broth instead_of water',
#  'instead_of salt and dijon_mustard because i do not have mustard',
#  'not have any mustard powder and i add a bit of black pepper',
#  'use 3/4 hot sriracha worcestershire_sauce instead_of ketchup',
#  'not like the beef tip recipe i use with mushroom',
#  'use can beef_broth instead_of beef',
#  'not have any onion_powder and use frozen green_bean',
#  'substitute celery and green ground_black_pepper for the green_bean',
#  'add some worcestershire soy_sauce since i do not have enough soy_sauce',
#  'add a fresh onion instead_of onion_powder',
#  'use snap pea instead_of green_bean',
#  'use ground_turkey instead_of ground_beef',
#  'instead_of ground_beef and hubby add onion',
#  'use molasses instead_of honey',
#  'use dijon_mustard instead_of ground_coriander',
#  'substitute freshly ground and toast oat for the bread_crumb',
#  'use brown/spicy mustard instead_of ground_coriander',
#  'instead_of ground_coriander i add honey mustard',
#  'instead_of water and add about 1/4 cup of beef_stock',
#  'use fresh mince garlic instead_of garlic_salt',
#  'substitute dry_mustard because i do not have ground_coriander',
#  'not have ground juniper mixed_berry but add thyme',
#  'substitute beef_stew_meat for oxtail and add celery',
#  'use chicken instead_of beef',
#  'not have white_wine so i use water',
#  'substitute the butter for olive_oil',
#  'replace ground_beef with lean ground_turkey',
#  'use plain_yogurt instead_of butter',
#  'instead_of white_wine i use marsala cooking white_wine',
#  'instead_of ground_beef because i do not have beef_broth',
#  'use thinly slice steak instead_of ground_beef',
#  'use water instead_of white_wine',
#  'not have white_wine so i use water',
#  'replace the ground_beef with steak',
#  'not have noodle on hand so we use white_rice',
#  'use rice instead_of noodle',
#  'use beef_broth instead_of water',
#  'replace the all_purpose_flour with 2 tb of corn',
#  'use veal instead_of beef',
#  'use the cornstarch instead_of all_purpose_flour',
#  'substitute beef_broth for the white_wine',
#  'use cook sherry instead_of white_wine and do not have fresh parsley',
#  'instead_of the dry and fresh mushroom in place of the can mushroom',
#  'not have any white_wine so i add a 1/2 cup of half_and_half',
#  'use beef_broth instead_of white_wine',
#  'not have round_steak so i use ground_beef',
#  'leave_out the canned mushroom and substitute sour_cream cheese instead_of sour_cream',
#  'replace the water with beef_broth',
#  'substitute sour_cream of chicken',
#  'use sour_cream cheese instead_of sour_cream',
#  'not have dry dried_chive so add a little onion_powder',
#  'use rigatoni noodle instead_of egg_noodle',
#  'use 1 cup of beef_broth instead_of beef_bouillon',
#  'substitute fresh mushroom for can and dry parsley',
#  'use red white_wine instead_of white_wine',
#  'substitute more white_wine for water',
#  'use chicken_broth instead_of water',
#  'use beer instead_of white_wine',
#  'use 1/2 c. of merlot white_wine instead_of water',
#  'substitute the white_wine with water',
#  'use lager beer instead_of white_wine',
#  'use 1 lb sirloin instead_of round_steak',
#  'instead_of all_purpose_flour and i use 8 ounce of sour_cream',
#  'use the white_wine instead_of water',
#  'use beef_stew_meat instead_of round_steak',
#  'substitute 1/2 c. red white_wine for the 1/4 c. water',
#  'substitute the white_wine with apple_cider vinegar',
#  'use 1/8 cup dry sherry instead_of white_wine',
#  'instead_of round_steak i use stew beef',
#  'use whole_milk instead_of water',
#  'substitute johnsonville sausage in for the beef',
#  'substitute beef_broth for the water',
#  'use stew beef instead_of round_steak',
#  'substitute half sour_cream/half water for the white_wine',
#  'use cornstarch instead_of all_purpose_flour',
#  'substitute rice for the noodle',
#  'substitute white grape_juice for the white_wine',
#  'add dill instead_of dried_chive',
#  'not have white_wine so just use more beef_broth',
#  'substitute water for the white_wine and add fresh slice white mushroom',
#  'replace all_purpose_flour with corn',
#  'white_wine and replace with sour_cream',
#  'substitute sour_cream for sour_cream cheese',
#  'use fresh green_onion instead_of dried_chive',
#  'substitute plain greek_yogurt for the sour_cream and green pepper',
#  'use red white_wine instead_of water',
#  'substitute red_wine vinegar for the marinade',
#  'not have onion so i use green_onion',
#  'use margarine instead_of butter',
#  'substitute white red_wine for the called-for red in the marinade',
#  'substitute chicken beef_stock for beef_stock and white red_wine vinegar',
#  'use pancake_mix instead_of all_purpose_flour',
#  'use red_wine instead_of water',
#  'substitute dijon_mustard for the prepared mustard',
#  'use beef_tenderloin instead_of beef_chuck',
#  'use chicken instead_of beef',
#  'use a dash of chili_powder instead_of red_pepper_flake',
#  'not have red_wine i substitute beef_broth & use half the amount of salt',
#  'instead_of mushroom on a bed of veggie pasta',
#  'not have fresh mushroom so i use 2 large can of mushroom',
#  'use 1lb ground_beef instead_of beef_chuck',
#  'instead_of make the mushroom in the pan with all_purpose_flour',
#  'use cornstarch instead_of all_purpose_flour',
#  'salt substitute with beef',
#  'not have sour_cream so use extra sour_cream',
#  'use red_wine vinegar a i have no red_wine',
#  'not like mushroom so i add pea',
#  'use shallot instead_of onion',
#  'use 2/3 cup sour_cream do not have any cream_cheese',
#  'add greek_yogurt instead_of cream_cheese',
#  'substitute ghee for the butter',
#  'instead_of red_wine i use cognac',
#  'add red_wine instead_of red_wine',
#  'replace the red_wine with diluted au joir worcestershire_sauce',
#  'substitute mexican_crema for the sour_cream',
#  'use 2 cup of sour_cream instead_of cream_cheese',
#  'not have sour_cream so i only use cream_cheese',
#  'substitute beef_broth with mushroom',
#  'not have beef_stock so i use liquid sour_cream',
#  'substitute neufschatel cream_cheese for cream_cheese',
#  'not have any sour_cream but use the cream_cheese',
#  'not have any steak so i use ground_beef',
#  'replace the shallot with onion',
#  'use onion instead_of shallot',
#  'instead_of dijon_mustard i use dry powder dijon_mustard',
#  'substitute slice celery for shallot',
#  'instead_of butter add garlic',
#  'substitute greek_yogurt for sour_cream',
#  'not have time to make creme_fraiche so i use sour_cream',
#  'substitute cooking sherry for the white_wine',
#  'substitute sour_cream for the creme_fraiche',
#  'use sirloin instead_of beef_chuck',
#  'use sour_cream instead_of creme_fraiche',
#  'substitute the creme_fraiche for sour_cream because i always have sour_cream',
#  'heavy_cream plus vinegar to substitute for the creme_fraiche',
#  'use sour_cream instead_of creme_fraiche',
#  'use sour_cream cause i do not have the creme_fraiche',
#  'substitute sour_cream for the creme_fraiche',
#  'use greek_yogurt instead_of sour_cream',
#  'not have white_wine so i use chicken beef_broth',
#  'use sour_cream instead_of creme_fraiche',
#  'use sour_cream instead_of creme_fraiche',
#  'not have creme_fraiche so i use sour_cream',
#  'use sour_cream instead_of creme_fraiche',
#  'use sour_cream instead_of creme_fraiche',
#  'not have any creme_fraiche and use sour_cream and some cream_cheese',
#  'use cognac instead_of white_wine',
#  'substitute green_onion for chive',
#  'replace the white_wine with brandy',
#  'use olive vegetable_oil instead_of vegetable_oil',
#  'use light sour_cream instead_of creme_fraiche',
#  'use a dry sherry instead_of white_wine',
#  'use sour_cream instead_of creme_fraiche',
#  'use lower sodium beef_broth and sirloin instead_of beef_chuck',
#  'use sour_cream instead_of creme_fraiche',
#  'use a dollop of sour_cream instead_of creme_fraiche',
#  'use sirloin instead_of beef_chuck',
#  'use virgin olive vegetable_oil instead_of vegetable_oil',
#  'not have the wide noodle and use a mixture of noodle',
#  'replace the white_wine with more beef_broth',
#  'substitute chicken_stock for the beef_stock',
#  'use banana instead_of onion',
#  'use cream_cheese instead_of sour_cream',
#  'have no condensed_golden_mushroom_soup so i use cream of mushroom',
#  'substitute red_wine for the water',
#  'substitute sour_cream for the cream_cheese',
#  'substitute a little wine for the water',
#  'substitute sour_cream for cream_cheese',
#  'cream_cheese be a great substitute for sour_cream',
#  'use sour_cream instead_of cream_cheese',
#  'not have noodle so i use rice',
#  'use cream of condensed_golden_mushroom_soup and sour_cream instead_of condensed_golden_mushroom_soup',
#  'substitute light sour_cream for cream_cheese',
#  'substitute cream of mushroom for the condensed_golden_mushroom_soup',
#  'add red_wine instead_of water',
#  'substitute sour_cream for cream_cheese',
#  'instead_of cream_cheese and add red_wine',
#  'not have golden mushroom so i use cream of mushroom',
#  'add beef_broth instead_of water',
#  'substitute sour_cream for cream_cheese',
#  'add beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'substitute beef_broth for the water',
#  'use chicken instead_of beef',
#  'use sour_cream instead_of cream_cheese',
#  'use cream_cheese instead_of sour_cream',
#  'use marsala_wine instead_of water',
#  'substitute 1/4 cup of water with 1/4 cup of beef_stock',
#  'replace the cream_cheese with sour_cream',
#  'substitute one can of beef_broth for the water',
#  'use sour_cream instead_of cream_cheese',
#  'replace the cream_cheese with sour_cream',
#  'use sour_cream instead_of cream_cheese',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use sour_cream instead_of cream_cheese',
#  'substitute beef_broth for the water',
#  'substitute the canned condensed_golden_mushroom_soup for the homemade cream of condensed_golden_mushroom_soup',
#  'not have cream_cheese so i use sour_cream',
#  'use lightly brown ground_beef instead_of beef_stew_meat',
#  'use beef_broth instead_of water',
#  'not have cream of mushroom so i use cream of celery',
#  'substitute golden mushroom with a cream of mushroom',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'instead_of water and chop onion i use a cup of french onion',
#  'use cream_cheese instead_of sour_cream',
#  'not have an onion so i add some minced onion',
#  'use 1/2 cup of beef_broth instead_of water',
#  'substitute beef_stock for water',
#  'add sour_cream instead_of cream_cheese',
#  'replace the 1/4 cup of water with french onion condensed_golden_mushroom_soup',
#  'add 1c heavy_cream and 1c sour_cream since i do not have half_and_half n half_and_half',
#  'not have any white_wine so i use extra dry_vermouth',
#  'substitute cubed ground_beef for the ground_beef',
#  'instead_of mushroom and use tomato_sauce',
#  'substitute the 1.5 cup water for milk with the all_purpose_flour',
#  'use tomato_soup instead_of tomato_paste',
#  'use garlic_powder instead_of garlic_salt',
#  'use garlic_powder instead_of garlic_salt',
#  'substitute heavy sour_cream for sour_cream',
#  'use garlic_powder instead_of garlic_salt',
#  'add crush garlic instead_of garlic_salt',
#  'instead_of sour_cream of chicken',
#  'use milk instead_of sour_cream',
#  'instead_of garlic_salt use garlic_powder',
#  'use condensed_cream_of_mushroom_soup instead_of sour_cream',
#  'use olive_oil instead_of butter',
#  'add crush garlic instead_of garlic_salt',
#  'use garlic_powder instead_of garlic_salt',
#  'substitute garlic_powder for garlic_salt',
#  'not have much garlic_salt but add garlic_powder to onion',
#  'use garlic_powder instead_of garlic_salt',
#  'add garlic_powder instead_of garlic_salt',
#  'instead_of sour_cream of chicken',
#  'use 85/15 ground_turkey instead_of ground_beef',
#  'instead_of mushroom sauce i use ground_beef',
#  'substitute 1 can sour_cream of celery condensed_cream_of_mushroom_soup',
#  'instead_of use sour_cream though i will suggest use sour_cream',
#  'not like sour_cream so i use sour_cream',
#  'use chicken instead_of ground_beef',
#  'use elbow noodle instead_of egg_noodle',
#  'put it over brown_rice instead_of macaroni',
#  'use ground_turkey instead_of ground_beef',
#  'add rice instead_of noodle',
#  'replace ground_beef with cubed ground_beef',
#  'use ground_pork instead_of steak',
#  'omit the white_wine and use chicken beef_bouillon instead_of the beef',
#  'use ground sirloin instead_of beef_stew_meat',
#  'use ground_beef and i do not have sour_cream',
#  'use sour_cream instead_of cream_cheese',
#  'use stroganoff dry soup_mix instead_of onion',
#  'use sour_cream instead_of cream_cheese',
#  'instead_of beef tip and i add fresh mushroom and onion',
#  'not have cream_cheese and use sour_cream',
#  'use a whole can of milk instead_of water',
#  'instead_of water i use beef_broth',
#  'not have stew beef on hand and use meatball',
#  'substitute ground_beef for beef_stew_meat',
#  'use bow tie pasta instead a i do not have any egg_noodle',
#  'use 1/2 cup of milk instead_of water',
#  'use milk instead_of water',
#  'substitute the water with the low sodium corned_beef',
#  'instead_of water i use corned_beef',
#  'replace the water with corned_beef',
#  'substitute the water with a bottle of dark beer',
#  'replace the cabbage with 1-1.5 pound of brussels_sprout',
#  'use sliced bok_choy instead_of cabbage',
#  'instead_of water with the leave over make a cabbage',
#  'substitute chicken_broth for water',
#  'use vegetable_broth instead_of water',
#  'substitute butter for margarine',
#  'use turkey instead_of corn',
#  'replace cider_vinegar with worcestershire_sauce',
#  'use onion flake because i have no onion',
#  'instead_of water i use a combination of red_wine',
#  'use honey instead_of corn_syrup',
#  'use smoke ham instead_of corned_beef',
#  'replace hot milk with buttermilk',
#  'substitute slice leek for cabbage',
#  'substitute cream of celery condensed_cream_of_mushroom_soup for the condensed_cream_of_mushroom_soup',
#  'instead_of beer and add two small turnip',
#  'instead_of beer i use 1/2 cup simply apple apple_juice',
#  'instead_of water & use guinness for the beer',
#  'replace the 4c water with corned_beef',
#  'red_potato and carrot and replace with the cabbage',
#  'instead_of water i add majority of corned_beef',
#  'not have beer so i use corned_beef',
#  'use chicken_broth instead_of beer',
#  'substitute 1 container of chicken_broth for the 4 cup of water',
#  'use baby_carrot instead_of stick',
#  'instead_of water i use corned_beef',
#  'instead_of beer and add 1/2 cup of water',
#  'use water instead_of beer',
#  'not have any beer and i add garlic',
#  'instead_of beer next time and add a little more black pepper',
#  'use vegetable_stock instead_of beer',
#  'use chicken_broth instead_of water',
#  'instead_of water & i do not add beer',
#  'beer & corned_beef broth substitute for some of the water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'substitute beef_broth for water',
#  'substitute red_wine for half the water and beef_stock',
#  'substitute carrot for yellow_squash',
#  'replace yellow_squash with mushroom and celery',
#  'add beef_consomme instead_of water',
#  'replace water with beef_broth',
#  'not have celery and use 2 cup of chicken_broth',
#  'replace some of the water with red_wine',
#  'instead_of water after brown the flour',
#  'substitute garlic_powder for garlic_salt',
#  'substitute sear flour for corn',
#  'use chicken_broth instead_of water',
#  'use beef_broth instead_of water',
#  'substitute beef_bouillon and red_wine for the water',
#  'instead_of water use beef_broth and wine',
#  'use beef or chicken_broth instead_of water',
#  'instead_of water with the cornstarch',
#  'use beef_broth instead_of water',
#  'substitute ketchup for tomato_paste',
#  'use squirt soda instead_of beer',
#  'substitute in a little ketchup for the tomato_paste',
#  'substitute wine for beer',
#  'use beef_broth instead_of water',
#  'substitute the turnip for whole mushroom',
#  'instead_of red_onion i use small whole white red_onion',
#  'instead_of turnip i use parsnip',
#  'use a tomato base sauce instead_of water',
#  'not like turnip so i just use the carrot and red_potato',
#  'use beef_broth instead_of water',
#  'use fat-free beef_broth instead_of water',
#  'not have the dry onion condensed_cream_of_mushroom_soup so i add some dry beef vegtable condensed_cream_of_mushroom_soup',
#  'use carrot and potato instead_of celery',
#  'not have the brown gravy_mix so i add some flour',
#  'substitute the onion soup_mix with greek_seasoning',
#  'replace the water with red_wine',
#  'not have any condensed_cream_of_mushroom_soup so i use cream of broccoli',
#  'not have cream of mushroom so i use cream of chicken',
#  'use black angus chuck steak and do not have brown gravy_mix',
#  'use pork instead_of beef',
#  'celery so i substitute with a dash of celery_salt',
#  'gravy_mix so i substitute with 1 cup of beef',
#  'replace the condensed cream of mushroom with condensed cream of celery',
#  'replace the carrot and celery with small cubed red_potato',
#  'use onion instead_of celery',
#  'add mushroom and onion instead_of celery',
#  'water and substitute with 1 c. beef_stock',
#  'use baby bella mushroom instead_of celery',
#  'substitute jar of savory beef_gravy for the gravy_mix',
#  'not like mushroom so i use cream of celery',
#  'add cream of celery condensed_cream_of_mushroom_soup instead_of mushroom',
#  'replace the three carrot with a bag of baby_carrot',
#  'not have dry_vermouth and use white_wine',
#  'use the garlic soup_mix instead_of onion',
#  'use a dry white_wine instead_of dry_vermouth',
#  'not have any dry_vermouth or white_wine so i just add water',
#  'not have the white_wine so i add water',
#  'use rise wine instead because i do not have any dry_vermouth',
#  'substitute brandy for the dry_vermouth',
#  'substitute white_wine for the dry_vermouth',
#  'not have condensed_cream_of_mushroom_soup so i use a can of beef_gravy',
#  'substitute whiskey for the dry_vermouth',
#  'not have any dry_vermouth or white_wine so i use red_wine',
#  'use a 3.5 lb pork_loin rump_roast instead_of beef',
#  'substitute wine for the dry_vermouth',
#  'use white_wine instead_of dry_vermouth',
#  'substitute apple_juice for the dry_vermouth and use the whole package of onion',
#  'not have dry_vermouth so i use some red_wine',
#  'instead_of dry_vermouth i use burgundy and use a creamed fresh mushroom',
#  'not have dry_vermouth so i add chicken_broth',
#  'substitute cream of celery condensed_cream_of_mushroom_soup because the cream of mushroom',
#  'use red_wine instead_of dry_vermouth',
#  'use water instead_of wine',
#  'use onion gravy soup_mix instead_of onion',
#  'use white_wine instead_of dry_vermouth',
#  'replace water for the wine',
#  'substitute the dry_vermouth with water',
#  'use white_wine instead_of dry_vermouth',
#  'condensed_cream_of_mushroom_soup at hand so just substitute with beef_broth and some extra onion',
#  'substitute red_wine for the dry_vermouth',
#  'use water instead_of wine',
#  'not have dry_vermouth so we use dry white_wine',
#  'use white_wine instead_of dry_vermouth',
#  'use white_wine instead_of dry_vermouth',
#  'substitute cream of chicken condensed_cream_of_mushroom_soup for the mushroom and add carrot',
#  'instead_of dry_vermouth and before add the rump_roast',
#  'use white_wine instead_of dry_vermouth',
#  'not have the onion soap soup_mix so i use mince onion',
#  'use a venision rump_roast instead_of beef',
#  'replace dry_vermouth with 2 can beef_broth',
#  'use wine instead_of dry_vermouth',
#  'use a red cabernet wine instead_of dry_vermouth',
#  'not have wine so i add 1/8 cup red_wine_vinegar with water',
#  'use beef_consomme instead_of dry_vermouth',
#  'use cream of celery soup_mix instead_of mushroom',
#  'use water instead_of dry_vermouth',
#  'use water instead_of dry_vermouth',
#  'use white_wine instead_of dry_vermouth',
#  'substitute white_wine for the dry_vermouth',
#  'substitute marsala_wine for the dry_vermouth and use cream of celery',
#  'substitute beef_broth for dry_vermouth',
#  'use red_wine instead_of dry_vermouth',
#  'not have any wine so just use more water',
#  'substitute celery condensed_cream_of_mushroom_soup for mushroom',
#  'substitute beef_consomme for the dry_vermouth/white_wine & add potato',
#  'substitute cooking wine for the dry_vermouth',
#  'use dry white_wine instead_of dry_vermouth',
#  'instead_of dry_vermouth i just use a red cooking wine',
#  'use white_wine instead_of dry_vermouth',
#  'substitute water for the dry_vermouth',
#  'use white_wine instead_of dry_vermouth',
#  'substitute dry_vermouth for some/all of the water',
#  'use white_wine instead_of dry_vermouth',
#  'instead_of onion soup_mix i use an onion',
#  'use white_wine instead_of dry_vermouth',
#  'not have onion condensed_cream_of_mushroom_soup so i add some chopped onion',
#  'use a can of dark beer instead_of dry_vermouth',
#  'use beef_broth but have no condensed_cream_of_mushroom_soup',
#  'use chuck rump_roast steak instead_of rump_roast',
#  'not have wine so i use beef_broth',
#  'replace condensced condensed_cream_of_mushroom_soup with gluten free condensed_cream_of_mushroom_soup',
#  'replace white_wine with 1/4 cp red cooking wine',
#  'not have dry_vermouth and use vodka',
#  'not have an onion condensed_cream_of_mushroom_soup packet use more seasoning',
#  'use white_wine instead_of dry_vermouth',
#  'substitute the dry_vermouth with red_wine',
#  'substitute beef_broth for the dry_vermouth',
#  'substitute red-wine vinegar for the dry_vermouth',
#  'not have dry_vermouth so i use red_wine',
#  'use white cooking wine because i do not have any dry_vermouth',
#  'use white_wine instead_of dry_vermouth',
#  'substitute beef_broth for the dry_vermouth',
#  'use beef_consomme because i do not have dry_vermouth',
#  'substitute beef_broth for the dry_vermouth',
#  'not have onion soup_mix or dry_vermouth on hand so i use a whole fresh chop onion',
#  'use beef_broth instead_of dry_vermouth',
#  'use beef_stock instead_of dry_vermouth',
#  'use cream of celery condensed_cream_of_mushroom_soup instead_of mushroom',
#  'use water instead_of dry_vermouth',
#  'substitute chicken_broth for the white_wine',
#  'not have the condense condensed_cream_of_mushroom_soup or dry_vermouth so i just use two cup of beef_broth',
#  'substitute either chardonnay or dry sherry for the dry_vermouth',
#  'use golden condensed_cream_of_mushroom_soup instead_of mushroom',
#  'add beef_stock instead_of dry_vermouth',
#  'use chicken_broth instead_of wine',
#  'use wine instead_of dry_vermouth',
#  'use sherry instead_of dry_vermouth',
#  'use dry white_wine instead_of dry_vermouth',
#  'substitute 1 c. of beef_broth for the dry_vermouth',
#  'not have any wine available so use beef_broth',
#  'use red_wine instead_of white_wine',
#  'use white_wine_vinegar instead_of dry_vermouth',
#  'replace dry_vermouth with water',
#  'use white_wine instead_of dry_vermouth',
#  'use beef_broth instead_of wine',
#  'not have the dry_vermouth so i use white_wine',
#  'add beef_broth instead_of wine',
#  'not have dry_vermouth so i use a riesling wine',
#  'substitute the alcohol with kitchen basic vegetable_stock',
#  'not have the onion soup_mix so i use some dry herb and onion',
#  'substitute wine for the water',
#  'substitute red_wine for the water and add 1/4 beef',
#  'substitute the seasoning from shilling pork_chop',
#  'use beer instead_of water',
#  'substitute the condensed_cream_of_mushroom_soup for cream of broccoli condensed_cream_of_mushroom_soup',
#  'substitute wine for the water',
#  'substitute french onion condensed_cream_of_mushroom_soup for the water',
#  'substitute red_wine for the water',
#  'substitute wine for the water',
#  'substitute half beef_broth and half red_wine for the water',
#  'use two can c. of celery instead_of mushroom',
#  'replace water with red_wine and beef_broth',
#  'use good red_wine instead_of water',
#  'use red cooking wine instead_of water',
#  'substitute broth and red_wine for the water',
#  'use beef_broth instead_of water',
#  'substitute 1 can beer for the water and add garlic_powder',
#  'use beef_broth instead_of water',
#  'substitute red_wine for the water',
#  'use 1 can of french onion condensed_cream_of_mushroom_soup because i do not have a can of beef_broth',
#  'use beef_broth instead_of water',
#  'substitute red_wine for the water',
#  'substitute the water with beef_broth',
#  'use a can of beef_broth instead_of water',
#  'substitute low sodium beef_broth for the water',
#  'use beef_broth instead_of water',
#  'put beef_broth instead_of water',
#  'use low sodium beef_broth instead_of water',
#  'substitute beef_broth for the water',
#  'substitute low sodium beef_stock for the water',
#  'substitute beef_broth for the water',
#  'use can beef_broth instead_of water',
#  'use beef_stock instead_of water',
#  'substitute beef_broth for the water and add carrot and potato',
#  'garlic clove to substitute for the garlic_salt',
#  'instead_of water i use 1 cup red_wine',
#  'use low sodium beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'replace the water with trader joes 40-clove garlic sauce',
#  'instead_of water i use beef_broth',
#  'use beef_broth instead_of water',
#  'replace the spinach with fresh kale',
#  'substitute beef_stock and red_wine for the water',
#  'not have a full envelope of onion soup_mix so i use the savory herb',
#  'add one can of beef_broth instead_of water',
#  'use red_wine instead_of water',
#  'substitute one can of condensed_cream_of_mushroom_soup with one can of golden condensed_cream_of_mushroom_soup',
#  'substitute beef_broth for the water and add carrot and potato',
#  'substitute beef_broth for the water',
#  'not have cream of mushroom so i use cream of chicken',
#  'have no onion soup_mix so use chopped onion',
#  'use cream of celery because we do not like mushroom',
#  'instead_of water i use beef_broth',
#  'use garlic pepper steak_seasoning a i do not have steak',
#  'not have tomato_sauce so i use a tin of tomato_soup',
#  'instead_of tomato_sauce i use a can of tomato_paste',
#  'substitute thyme for dried_oregano',
#  'use cornstarch instead_of all_purpose_flour',
#  'not have cranberry_sauce so i use dry cranberry',
#  'instead_of celery i use onion',
#  'instead_of water use beef_broth',
#  'substitute a can of beef_broth for the water',
#  'use beef_broth instead_of water',
#  'instead_of onion_soup i use emerils essence seasoning',
#  'replace the dried_onion soup_mix with 1 finely chopped onion',
#  'instead_of apple_juice concentrate i use apple soy_sauce',
#  'use 21/2 cup apple_cider instead_of apple_juice',
#  'substitute coconut_amino for soy_sauce',
#  'not have an onion but i use lipton dry onion',
#  'use rosemary instead_of bay_leaf',
#  'use a rump_roast instead_of beef_chuck',
#  'replace the bay_leaf with some italian_seasoning and parsley',
#  'substitute salt and ground_black_pepper with monterey seasoning',
#  'substitute potato for celery',
#  'use red_potato instead_of celery',
#  'use 48 oz of beef_broth instead_of red_wine',
#  'use red_potato instead_of celery',
#  'substitute red_potato for the celery',
#  'red_wine can be replace by pure organic apple_juice',
#  'instead_of dried_rosemary and add garlic',
#  'use green ground_black_pepper instead_of celery',
#  'instead_of celery and add some red_wine',
#  'use parsley instead_of dried_rosemary and potato instead_of celery',
#  'use thyme instead_of dried_rosemary',
#  'not have celery so i use onion',
#  'not have dried_rosemary so i use a few bay_leaf',
#  'dried_rosemary so i substitute with 1/2 dry thyme',
#  'substitute bell ground_black_pepper for the celery',
#  'substitute herb de provence for the dried_rosemary',
#  'not have dried_rosemary but add some thyme with the salt',
#  'use celery_salt instead_of celery',
#  'use sherry or dark beer instead_of water',
#  'use cream of celery condensed_cream_of_mushroom_soup instead_of condensed_cream_of_mushroom_soup',
#  'substitute french onion condensed_cream_of_mushroom_soup for the dry onion condensed_cream_of_mushroom_soup',
#  'use beef_broth instead_of water',
#  'add red_wine instead_of water',
#  'use red_wine instead_of water',
#  'substitute worcestershire_sauce for the water',
#  'replace the onion with a package of dry onion_soup',
#  'use beef_broth instead_of water',
#  'substitute the celery with cabbage',
#  'substitute dry celery for the celery',
#  'use chicken_broth instead_of water',
#  'instead_of water i use 2 cup french onion',
#  'use low sodium beef_broth instead_of beef_bouillon',
#  'not have any celery and use regular baby_carrot',
#  'instead_of water i use beef_stock',
#  'substitute equal part olive_oil and worcestershire_sauce for the water',
#  'use beef_broth and fresh green_bean instead_of celery',
#  'not have celery add slice pepper',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of beef_bouillon',
#  'use parsnip instead_of potato',
#  'tomato_paste and substitute with a can of diced tomato',
#  'have no tomato_sauce so i use tomato_paste',
#  'not have orange_zest so i use 1/2 cup orange_juice',
#  'use real butter instead_of margarine',
#  'substitute knorr pfeffer sauce gravy_mix for the dry gravy_mix',
#  'gravy_mix on hand so i substitute with an envelope of dry onion_soup',
#  'instead_of real onion because onion',
#  'use water because i do not have any beef_broth',
#  'use a rump_roast instead_of beef_chuck',
#  'add onion gravy_mix and use beef_broth instead_of water',
#  'not have carrot so i add a can of green_bean',
#  'not have brown gravy_mix so i use onion gravy_mix',
#  'use onion_powder instead_of onion_salt',
#  'not have the dried_sage and add pepper and parsley',
#  'use onion_powder instead_of onion_salt',
#  'use 12 oz of red_wine instead_of beer',
#  'use beef_broth instead_of cream_of_mushroom_soup',
#  'use pork chuck_roast instead_of beef',
#  'instead_of beef_broth i use red_wine with beef and onion_soup',
#  'not have the pkg of dry spaghetti mix so i use 2 tbls of italian_seasoning',
#  'not have celery so use carrot',
#  'use potato and carrot instead_of celery',
#  'use carrot instead_of celery',
#  'use garlic_powder instead_of garlic_salt',
#  'not have the spaghetti season so i use italian dice stewed_tomato',
#  'use garlic_powder instead_of garlic_salt',
#  'use garlic_powder instead_of garlic_salt',
#  'substitute spaghetti_sauce and add garlic and red_wine',
#  'substitute dry oregano and basil for the spaghetti_sauce',
#  'replace onion with red_onion',
#  'use minced garlic instead_of garlic_salt',
#  'replace the garlic_salt with garlic_powder and add regular garlic_salt',
#  'use crush garlic instead_of garlic_salt',
#  'replace water for beef_broth',
#  'substitute 1 cup beef_broth for the 1/3 cup water',
#  'use beef_stock instead_of white_vinegar',
#  'use thyme instead_of dill',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'not have any red_wine so just use beef_broth',
#  'use beef_broth instead_of water',
#  'instead_of tomato_paste i use dice tomato',
#  'replace the water with beef_broth',
#  'not have pearl_onion so i add more pearl_onion',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'substitute beef_broth for the water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'substitute all red_wine for water',
#  'substitute beef_broth for water',
#  'substitute beef_broth for the water',
#  'replace the red_wine with a rue of grape_jam and red_wine',
#  'use beef_broth instead_of water',
#  'substitute 1/2 cup no sodium beef_stock for the water',
#  'use beef_broth instead_of water',
#  'substitute beef_stock for the water',
#  'use beef_broth instead_of water',
#  'substitute dried_marjoram with fresh rosemary',
#  'use red_wine instead_of water',
#  'use beef_broth instead_of water',
#  'substitute dried_thyme for the dried_marjoram',
#  'substitute sweet red_potato for the red_potato',
#  'substitute beef_broth for the water',
#  'use chicken_broth instead_of water',
#  'substitute beef_broth for water plus add mushroom',
#  'omit the green green_bell_pepper and instead_of sliver the garlic',
#  'use beer instead_of water',
#  'put in some mushroom instead_of carrot',
#  'substitute beer for water',
#  'not have any fresh garlic so i just add minced garlic to the beef_broth',
#  'use beer instead_of water',
#  'not have any beef boullion so i use beef_gravy',
#  'omit the water and substitute beer or red_wine',
#  'not have bay_leaf and i add basil and oregano',
#  'use beer instead_of water',
#  'use beer instead_of water',
#  'substitute green_bean for the yukon_gold_potato',
#  'use all beef_broth instead_of water',
#  'use beer instead_of water',
#  'use white_wine instead_of water',
#  'substitute red_wine for the water',
#  'use the pork instead_of beef',
#  'not have 3 pound of beef_chuck roast so i use the 1.5 pound beef_chuck',
#  'use pork_roast instead_of beef',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use an herb and vegetable soup_mix instead_of onion',
#  'use beef_broth instead_of water',
#  'add beef_stock instead_of water',
#  'use beef_broth instead_of water and mushroom instead_of celery',
#  'use beef_broth instead_of water',
#  'add fresh mushroom and garlic instead_of celery',
#  'use a can of beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use low sodium beef_broth instead_of water',
#  'replace the water with beer',
#  'use only beef_broth instead_of water',
#  'add 1 cup of beef_broth instead_of water',
#  'not have onion soup_mix so i use 1 tsp onion_powder',
#  'use 2 cup of beef_broth instead_of water',
#  'substitute beef_broth for water',
#  'add beef_broth instead_of water',
#  'use 2 can of beef_broth instead_of water',
#  'use the beef_stock instead_of water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'replace beef_broth for the water',
#  'substitute beef_broth for the water',
#  'use beef_broth instead_of water',
#  'use baby_carrot and do not have onion soup_mix nor beef_stock',
#  'use beef_broth instead_of water',
#  'replace water with double the amount of chicken_broth',
#  'use celery_salt instead_of celery',
#  'use beef_broth instead_of water',
#  'substitute beef_broth for the water',
#  'substitute beef with mushroom dry soup_mix for the onion soup_mix',
#  'substitute the water with a can of beef_broth',
#  'substitute fresh mushroom for the celery',
#  'use beef_broth instead_of water',
#  'substitute 3/4 cup of water with red_wine',
#  'use beef_broth instead_of water',
#  'use 1 cup of beef_broth instead_of water',
#  'use montreal seasoning and use beef_broth instead_of water',
#  'substitute the water with beef_broth',
#  'use beef_broth instead_of water',
#  'substitute 1 cup beef_broth for the water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use 4 cup of beef_broth instead_of water',
#  'use chicken_broth instead_of water',
#  'use beef_broth instead_of water',
#  'instead_of water i use beef_broth',
#  'use beef_broth instead_of water',
#  'replace the water with beef_broth',
#  'use beef_broth instead_of water',
#  'use a cup of beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'not like onion so i use onion_powder',
#  'replace the water with beef_broth',
#  'replace the water with beef_broth or beer',
#  'substitute beef_broth for the water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'instead_of water use chicken_broth and add two bay_leaf',
#  'instead_of water i use beef_broth',
#  'replace the water with beef_broth',
#  'use beef_stock instead_of water',
#  'use beef_broth instead_of water',
#  'add two can of beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'add fresh mushroom instead_of potato',
#  'use beef_broth instead_of water',
#  'not have onion soup_mix so use vegetable soup_mix and add onion_powder',
#  'use beef_broth instead_of water',
#  'use beef_broth instead_of water',
#  'use 2 cup of beef_broth instead_of water',
#  'substitute the onion with green_bell_pepper since onion',
#  'use a can of beef_consomme instead_of beef_broth',
#  'add beef_consomme instead_of beef_broth',
#  'use red cooking wine instead_of beef_broth',
#  'add sweet_potato instead_of carrot',
#  'use better than bullion and water instead_of beef_broth',
#  'not have worcestershire_sauce so use steak worcestershire_sauce',
#  'substitute 3 tablespoon of cornstarch with 1 tablespoon of beef_base',
#  'use chicken_broth instead_of water',
#  'use mushroom gravy_mix instead_of beef_gravy',
#  'use the small can of chicken_broth instead_of water',
#  'substitute onion_soup for italian_seasoning',
#  'baby_carrot be a great substitute for unnecessarily tinker with larger carrot',
#  'use beef_broth instead_of water',
#  'use potato instead_of onion',
#  'not have use red_onion and should have use a yellow onion',
#  'not have beef_gravy seasoning so i use mccormick brown gravy_mix',
#  'use dark beer instead_of water',
#  'not have beef_gravy so i use 2 can of beef_broth',
#  'not have gravy_mix or italian italian_salad_dressing on hand so i use a packet of onion_soup gravy_mix',
#  'substitute red_wine and beef_broth in place of chicken_broth',
#  'instead_of water for the gravy_mix',
#  'use garlic and i use beef_broth instead_of water',
#  'substitute 1/4 c of red_wine for that amount of water',
#  'use wine instead_of water',
#  'use beef_broth instead_of water',
#  'instead_of all_purpose_flour for the sauce',
#  'instead_of water use beef_broth',
#  'use beef_broth instead_of water',
#  'add a packet of lipton onion_soup mix and i do not have tomato_paste',
#  'use a chuck_roast instead_of beef_tri_tip',
#  'use brew coffee instead_of water',
#  'use wine instead_of red_wine_vinegar',
#  'add pea instead_of red_potato',
#  'use a little red_wine instead_of red_wine_vinegar',
#  'use red_wine instead_of red_wine_vinegar',
#  'use apple red_wine_vinegar instead_of red_wine_vinegar',
#  'not have red_wine or red_wine_vinegar so have to use apple_cider red_wine_vinegar',
#  'use red_wine and a little soy_sauce instead_of red_wine_vinegar',
#  'use burgundy wine instead_of red_wine_vinegar',
#  'use beef chicken_broth instead_of chicken',
#  'use 1/2 cup beef chicken_broth plus do not have all_purpose_flour',
#  'use beef_stock instead_of chicken_broth',
#  'instead_of chicken_broth in the recipe i use vegetable chicken_broth',
#  'instead_of chicken_broth i use a can of french onion_soup',
#  'use peanut vegetable_oil instead_of vegetable_oil',
#  'use beef_stock instead_of chicken and tomato_sauce instead_of tomato_paste',
#  'use beef chicken_broth instead_of chicken_broth',
#  'use beef chicken_broth instead_of chicken_broth',
#  'substitute the chicken_broth for vegetable chicken_broth',
#  'substitute beer for the chicken_broth',
#  'use beef chicken_broth instead_of chicken',
#  'use beef chicken_broth instead_of chicken',
#  'use beef chicken_broth instead_of chicken_broth',
#  'use beef chicken_broth instead_of chicken_broth',
#  'use beef chicken_broth instead_of chicken_broth',
#  'not have mushroom and use a rump chuck_roast',
#  'use beef chicken_broth instead_of chicken_broth',
#  'use beef chicken_broth instead_of chicken_broth',
#  'not have tomato_paste so use tomato pesto',
#  'use beef chicken_broth instead_of chicken_broth',
#  'use beef chicken_broth instead_of chicken_broth',
#  'not have the chicken_broth so i use beef chicken_broth',
#  'substitute potato for the celery',
#  'substitute the mushroom for red_potato',
#  'not have rosemary or thyme so i add basil',
#  'substitute beef chicken_broth for the chicken_stock',
#  'not have any rosemary so i use dry tarragon',
#  'use beef chicken_broth instead_of chicken_broth',
#  'use beef chicken_broth instead_of chicken',
#  'not have beef_stock so i use vegetable_stock',
#  'use beef chicken_broth instead_of chicken',
#  'substitute 1 btle red_wine for chix chicken_broth',
#  'use about 1c beef chicken_broth instead_of chicken',
#  'use beef chicken_broth instead_of chicken',
#  'use beef chicken_broth instead_of chicken',
#  'not have fresh herb so i use the equivalent of dried_rosemary',
#  'substitute ketchup for the tomato_paste',
#  'use beef chicken_broth instead_of chicken_broth',
#  'use lawrys seasoned_salt and dry italian_seasoning because i do not have fresh herb',
#  'use avocado vegetable_oil instead_of vegetable_oil',
#  'use olive vegetable_oil instead_of vegetable_oil',
#  'use beef chicken_broth instead_of chicken',
#  'not have fresh mushroom or celery so i use small red_potato and some celery',
#  'add celery instead_of mushroom',
#  'add some beef chicken_broth because i do not have that much chicken_broth',
#  'use cream of mushroom instead_of chicken_stock',
#  'potato and replace with almond all_purpose_flour',
#  'use beef chicken_broth instead_of chicken',
#  'replace one cup of the chicken_broth with red_wine',
#  'not have chicken_broth so i use lipton onion_soup',
#  'substitute ghee for butter',
#  'use beef chicken_broth instead_of chicken_broth',
#  'substitute a cup of chicken_broth with a cup of red_wine',
#  'substitute venison for the beef',
#  'use brandy instead_of rum',
#  'not like onion so i put baby_carrot',
#  'not have beef_broth and use ground_beef',
#  'substitute ground_turkey for the ground_beef',
#  'not have can beef_broth so i use 2 c water',
#  'cornstarch so i substitute with flour',
#  'use ground venison instead_of ground_beef',
#  'not have any bread_crumb so i use saltine_cracker',
#  'not have ground_beef so use turkey',
#  'use flour instead_of cornstarch',
#  'instead_of beef_broth and do not add the onion or mushroom',
#  'instead_of salt and ground_black_pepper and i add 1 clove of garlic',
#  'add some garlic_powder and i have no mushroom',
#  'use oatmeal instead_of bread_crumb',
#  'not have beef_broth so i use ground_beef onion_soup and i also add mince garlic and bell ground_black_pepper',
#  'use ground_turkey and use chicken beef_broth instead_of ground_beef',
#  'replace plain bread_crumb for herb flavor dry stuffing',
#  'instead_of cornstarch and water i add 1/2 cup water',
#  'use flour instead_of corn',
#  'replace onion for mini yellow/red/orange ground_black_pepper',
#  ...]

# %%
list(itertools.chain.from_iterable(real_deletion_list))
# Out:
# ['omit the water',
#  'leave_out the barbeque_sauce',
#  'not have any beer',
#  'not add barbeque_sauce',
#  'not have beer',
#  'not put any barbeque_sauce',
#  'use no water',
#  'not have any liquid_smoke',
#  'not use diced tomato',
#  'not put the mozzarella_cheese',
#  'not use tomato',
#  'not put any mozzarella_cheese',
#  'leave_out the white_rice',
#  'not add tomato',
#  'eliminate the salt',
#  'not have ground_nutmeg',
#  'not have saltine_cracker or potato',
#  'not use potato',
#  'not have any paprika',
#  'have no potato',
#  'not use the butter',
#  'not have any fresh garlic',
#  'omit the mushroom',
#  'omit the celery',
#  'not have the beef_broth',
#  'leave_out the seasoned_salt',
#  'not add any ground_black_pepper',
#  'leave_out the chili_powder',
#  'leave_out the hot_sauce',
#  'leave_out the tomato_juice',
#  'not have that overpower tomato_juice',
#  'omit the mushroom',
#  'omit the ketchup',
#  'not have any cherry_tomato',
#  'not have any self rise self_rising_flour',
#  'not have dry prune',
#  'not have fresh mushroom',
#  'not have to like coffee',
#  'not have sour_cream',
#  'leave_out the fresh garlic',
#  'delete the butter',
#  'not have the celery',
#  'eliminate the need for additional water',
#  'not have liquid_smoke',
#  'have no onion',
#  'not have any cilantro',
#  'not use the pineapple',
#  'not add butter',
#  'leave_out the cilantro',
#  'leave_out the cilantro',
#  'not add cilantro',
#  'omit the green_onion',
#  'not have too many sweet_onion',
#  'not have any all_purpose_flour',
#  'not have enough beef_liver',
#  'not have beef_liver',
#  'eliminate the milk',
#  'remove the beef_liver and sweet_onion',
#  'omit the all_purpose_flour and butter',
#  'not have all_purpose_flour or butter',
#  'skip the all_purpose_flour',
#  'eliminate that nasty bite beef_liver',
#  'not add a much milk',
#  'remove the heavy beef_liver',
#  'remove too much of the beef_liver',
#  'not add more all_purpose_flour',
#  'not have any all_purpose_flour but the beef_liver',
#  'remove the beef_liver',
#  'not put too much all_purpose_flour',
#  'not use the milk',
#  'not use butter',
#  'leave_out the milk',
#  'skip the milk',
#  'skip the red_bell_pepper',
#  'omit the white_sugar',
#  'omit the white_sugar',
#  'not add any white_sugar add extra garlic',
#  'not add the extra white_sugar',
#  'not have pineapple',
#  'not have either the pineapple',
#  'leave_out garlic_powder',
#  'omit the dijon_mustard',
#  'eliminate the beef_bouillon',
#  'not have red_wine',
#  'eliminate all condensed_golden_mushroom_soup',
#  'not use the dijon_mustard',
#  'omit the beef_bouillon',
#  'omit the canned condensed_golden_mushroom_soup',
#  'not have condensed_golden_mushroom_soup or red_wine',
#  'omit the garlic and dijon_mustard garlic_powder',
#  'leave_out the dijon_mustard',
#  'not use condensed_golden_mushroom_soup',
#  'not use the all_purpose_flour',
#  'not have any black_olive',
#  'leave_out the mustard_seed',
#  'not have nut or mustard_seed',
#  'not have red_bell_pepper',
#  'not have potato',
#  'leave_out the ketchup and red_bell_pepper',
#  'leave_out the red_bell_pepper',
#  'not add any salt',
#  'not have tobasco or paprika',
#  'skip the all_purpose_flour',
#  'leave_out the corn_syrup',
#  "omit the refined confectioners'_sugar",
#  "not add the 10x confectioners'_sugar",
#  'omit the karo corn_syrup',
#  'not have lime_juice or white_wine',
#  'leave_out the maple_syrup',
#  'not put in a much butter',
#  'not use the pistachio',
#  'leave_out the parsley and pistachio',
#  'not add the pistashios or parsley',
#  'not have time to brine the cornish_game_hen',
#  'not use the pistachio and parsley',
#  'not have any slivered almond',
#  'not have dried_cranberry',
#  'skip the toasting of the almond',
#  'leave_out the dried_cranberry',
#  'eliminate butter',
#  'omit the salt',
#  'not have time to make white_rice',
#  'not have any ground_turmeric',
#  'not have any condensed onion_soup',
#  'not put bacon',
#  'not have dry ancho_chile_powder or the seafood_seasoning',
#  'skip the cilantro',
#  'not use the cilantro',
#  'not add the extra salt',
#  'eliminate the texture of the cabbage',
#  'leave_out the soy_sauce',
#  'omit the all-all_purpose_flour and water',
#  'remove the bottom_round_roast',
#  'not have enough onion',
#  'not use white_vinegar',
#  'not use all the onion',
#  'skip the white_vinegar',
#  'remove it and sweat the onion',
#  'not use all the onion',
#  'not add the water or all_purpose_flour',
#  'remove the bay_leaf',
#  'remove bottom_round_roast',
#  'remove bottom_round_roast',
#  'not have enough onion',
#  'not have chicken_broth',
#  'not add the honey',
#  'leave_out the green_onion',
#  'not have be garam_masala',
#  'not have any big carrot',
#  'use no garlic_salt',
#  'omit the onion and garlic_salt',
#  'omit the garlic_salt',
#  'leave_out the garlic_salt and garlic_salt',
#  'not have any pecan',
#  'omit the honey',
#  'remove the honey and vanilla_extract',
#  'not have any fresh tomato',
#  'omit the dijon_mustard',
#  'not add cayenne_pepper',
#  'not have onion_powder',
#  'not have any red_wine_vinegar',
#  'not have red_wine_vinegar',
#  'not use the cayenne_pepper',
#  'omit the salt',
#  'have no tomato',
#  'not have an dende canola_oil',
#  'not have with another canola_oil',
#  'skip the white other_fish',
#  'omit the butter and brown_sugar',
#  'omit the dried_cranberry',
#  'leave_out the dried_cranberry',
#  'not use the dried_cranberry',
#  'not bother_with the water',
#  'not add the water',
#  'not add extra salt',
#  'not have any chicken_broth',
#  'not add the carrot',
#  'leave_out the water',
#  'leave_out the dijon_mustard',
#  'not have any mayonnaise',
#  'not use the chili_powder',
#  'omit salt',
#  'not use the chili_powder',
#  'not put in any salt',
#  'not use a much chili_powder',
#  'omit the chili_powder and salt',
#  'leave_out the chili_powder',
#  'not use the chili_powder',
#  'leave_out the chili_powder',
#  'not add the chili_powder',
#  'not have any problem with the saltine_cracker',
#  'not add salt',
#  'not use the chili_powder',
#  'not have chili_powder',
#  'not have fresh ground_beef',
#  'not have the saltine_cracker',
#  'not add salt',
#  'not have any parsley',
#  'omit the parsley',
#  'not have saltine_cracker',
#  'delete the white_sugar',
#  'not have tomato_sauce',
#  'leave_out the water and ketchup',
#  'not use any hot ground_black_pepper',
#  'eliminate the white_sugar',
#  'not put enough crush red ground_black_pepper',
#  'leave_out the red ground_black_pepper',
#  'omit the garlic_salt',
#  'omit the garlic_salt',
#  'leave_out tomato_sauce',
#  'leave_out garlic_salt',
#  'not add white_vinegar',
#  'leave_out the butter',
#  'not add butter',
#  'remove and the brown_rice',
#  'not have to worry about the brown_rice',
#  'omit the salt',
#  'not have that brown_rice',
#  'not have normal bread_crumb',
#  'leave_out the dry_mustard',
#  'not add the dry_mustard',
#  'not use greek_seasoning',
#  'not have greek_seasoning',
#  'not have oxtail',
#  'remove the oxtail',
#  'not add any seasoned_salt',
#  'use no seasoned_salt',
#  'skip greek_seasoning',
#  'omit bacon_dripping',
#  'not add a much seasoned_salt',
#  'not use the brown_sugar',
#  'not add the 2 tsp of salt',
#  'not add the additional salt',
#  'omit the shortening',
#  'not have paprika',
#  'not use the brown_sugar',
#  'not add the brown_sugar because ketchup',
#  'not add water',
#  'not have water',
#  'omit the shortening',
#  'not add any additional salt',
#  'not add the all_purpose_flour and water',
#  'leave_out the brown_sugar',
#  'not use shortening',
#  'omit the brown_sugar',
#  'not use a much ground_ginger',
#  'omit the all_purpose_flour',
#  'not have quite enough ground_ginger',
#  'not use the all_purpose_flour and water',
#  'not have fresh green_bean',
#  'remove some soy_sauce',
#  'omit the extra water',
#  'not add in the all_purpose_flour',
#  'not have fresh green_bean',
#  'not have honey',
#  'not have a need to add water',
#  'not have the condensed_cream_of_mushroom_soup',
#  'skip the white sauce/cream condensed_cream_of_mushroom_soup',
#  'leave_out the egg',
#  'omit the bread_crumb',
#  'omit the water',
#  'eliminate the ground_nutmeg',
#  'eliminate 1/2 cup water',
#  'not have ground_nutmeg',
#  'omit the parsley',
#  'not have time to saute the onion',
#  'not use ground_coriander',
#  'not have fresh parsley',
#  'not use ground_nutmeg',
#  'not have ground_coriander',
#  'not have ground_nutmeg',
#  'not have any onion',
#  'omit the mushroom',
#  'not have any cream of mushroom',
#  'omit the mushroom',
#  'leave_out the white_wine',
#  'leave_out the all_purpose_flour',
#  'not put in white_wine',
#  'not have any worcestershire_sauce',
#  'omit the mushroom',
#  'not add additional salt',
#  'not have any white_wine',
#  'not have ground_beef',
#  'skip the salt',
#  'leave_out white_wine',
#  'not have an onion',
#  'not have white_wine or beef_broth',
#  'not have worcestershire_sauce',
#  'skip the onion and garlic',
#  'not use white_wine',
#  'not have any condensed_cream_of_mushroom_soup',
#  'not add the mushroom just the condensed_cream_of_mushroom_soup',
#  'leave_out the dried_chive and the white_wine',
#  'not have beef_bouillon',
#  'skip the dried_chive',
#  'not have white_wine',
#  'not have dried_chive',
#  'eliminate the extra water',
#  'omit the white_wine',
#  'leave_out the sour_cream',
#  'not add the white_wine',
#  'skip the dried_chive',
#  'not have them and skip the parsley',
#  'not have any parsley',
#  'omit the water',
#  'not have white_wine',
#  'leave_out sour_cream',
#  'omit the water',
#  'not add any extra salt',
#  'not add the white_wine',
#  'not add the white_wine',
#  'omit the water',
#  'not use onion',
#  'omit the dried_chive',
#  'omit the water',
#  'not add the white_wine',
#  'leave_out the water',
#  'not have mushroom or sour_cream of mushroom',
#  'not add all of the sour_cream',
#  'omit the parsley and mushroom',
#  'omit the water',
#  'omit the dried_chive and parsley',
#  'omit the water',
#  'leave_out the mushroom',
#  'not use any white_wine',
#  'omit the dried_chive',
#  'omit the onion',
#  'not have any white_wine',
#  'omit the water',
#  'not have any can of condensed condensed_cream_of_mushroom_soup',
#  'not have beef_bouillon',
#  'leave_out the fresh parsley',
#  'not have fresh parsley',
#  'not add the dried_chive or parsley',
#  'not have the mushroom',
#  'not have any white_wine',
#  'leave_out the white_wine',
#  'omit to can mushroom',
#  'not have any fresh parsley',
#  'skip the onion',
#  'leave_out the canned mushroom',
#  'omit water',
#  'omit the white_wine and water',
#  'leave_off the beef_bouillon and water',
#  'omit the water',
#  'not have can mushroom',
#  'eliminate the beef_bouillon',
#  'not have the white_wine',
#  'not use any white_wine',
#  'leave_out the dried_chive',
#  'skip the dry dried_chive',
#  'omit the canned mushroom',
#  'have no mushroom',
#  'omit dried_chive',
#  'not have any onion',
#  'not add the worcestershire_sauce',
#  'not have white_wine',
#  'have no white_wine',
#  'not use round_steak',
#  'omit white_wine',
#  'not add any water',
#  'not have the worcestershire_sauce',
#  'leave_out the salt',
#  'leave_out the all_purpose_flour',
#  'leave_out the beef_bouillon',
#  'leave_out the dried_chive and parsley',
#  'not have fresh parsley',
#  'not add the sour_cream',
#  'leave_out the mushroom',
#  'omit the all_purpose_flour',
#  'omit the white_wine',
#  'omit add additional mushroom',
#  'leave_out the dried_chive',
#  'not use canned mushroom',
#  'not have dried_chive or parsley',
#  'omit the parsley',
#  'not add any white_wine',
#  'not add the white_wine',
#  'omit the mushroom',
#  'not use the sour_cream condensed_cream_of_mushroom_soup',
#  'not have the dried_chive or worchester worcestershire_sauce',
#  'omit the water and increase white_wine',
#  'not use water',
#  'not use a beef_bouillon',
#  'leave_out the can of condensed_cream_of_mushroom_soup',
#  'omit the onion',
#  'omit the beef_bouillon',
#  'not add water',
#  'omit the water',
#  'omit the water',
#  'not have condense condensed_cream_of_mushroom_soup',
#  'not have dry dried_chive',
#  'omit the white_wine',
#  'not use the condensed_cream_of_mushroom_soup',
#  'not have dry dried_chive',
#  'omit the red_pepper_flake',
#  'omit the red ground_black_pepper',
#  'not add the extra salt',
#  'leave_out the red_pepper_flake',
#  'leave_out the red_pepper_flake',
#  'omit the red epper red_pepper_flake',
#  'not have any red_wine',
#  'leave_out the red ground_black_pepper',
#  'omit red red_pepper_flake and red_wine',
#  'skip the mushroom',
#  'leave_out the addition of any salt',
#  'not add cream_cheese',
#  'not have fresh mushroom',
#  'remove red red_pepper_flake',
#  'omit the crushed red ground_black_pepper',
#  'not have cream_cheese',
#  'not have cream_cheese',
#  'leave_out the red_pepper_flake',
#  'skip the sour_cream and cream_cheese',
#  'not put in a much hot red_pepper_flake',
#  'skip the cream_cheese',
#  'not add the sour_cream or cream_cheese',
#  'omit the cream_cheese',
#  'omit the sour_cream and cream_cheese',
#  'not use sour_cream',
#  'not have any cream_cheese',
#  'leave_out the mushroom',
#  'leave_out the mushroom',
#  'leave_out the onion',
#  'leave_out the red_wine and red ground_black_pepper',
#  'not put in the mushroom',
#  'not use red_pepper_flake',
#  'not have red_wine',
#  'skip on the mushroom',
#  'not use yellow mustard',
#  'not have red_wine',
#  'leave_out the cream_cheese',
#  'omit the mustard',
#  'not add the red_wine',
#  'leave_out the red ground_black_pepper',
#  'omit the red ground_black_pepper and mustard',
#  'leave_out the red ground_black_pepper',
#  'omit the red_pepper_flake',
#  'skip the mustard',
#  'not put red_wine',
#  'omit the cream_cheese and sour_cream',
#  'not use too much red_pepper_flake',
#  'leave_out the red_wine',
#  'omit red_pepper_flake',
#  'not use the red_pepper_flake',
#  'not have the beef_stock',
#  'not have prepare mustard',
#  'not use red_pepper_flake',
#  'omit the red_pepper_flake',
#  'skip the step with the onion',
#  'omit the red_pepper_flake',
#  'not have any red_wine',
#  'not put in red_pepper_flake',
#  'not use cream_cheese',
#  'delete the mushroom',
#  'not have beef_stock',
#  'skip the cream_cheese',
#  'not have any red_wine',
#  'not use red chili red_pepper_flake',
#  'not have red_wine',
#  'not have any red_pepper_flake',
#  'not add the red ground_black_pepper',
#  'not use the cream_cheese and increase sour_cream',
#  'leave_out the ground_black_pepper',
#  'not have any red_wine',
#  'not add the hot red_pepper_flake',
#  'not add the red_pepper_flake',
#  'omit the red_pepper_flake',
#  'not use the red_wine',
#  'eliminate the red_pepper_flake',
#  'not use the mustard',
#  'leave_out the red_pepper_flake',
#  'leave_out the red_pepper_flake',
#  'omit the crushed ground_black_pepper',
#  'omit the red_pepper_flake',
#  'not use the red_pepper_flake',
#  'not have fresh mushroom',
#  'not add cream_cheese only sour_cream',
#  'omit the red_pepper_flake',
#  'omit the red ground_black_pepper and cream_cheese',
#  'omit the red_wine',
#  'not add cream_cheese',
#  'not have any sour_cream',
#  'remove this and melt the butter',
#  'omit the red_pepper_flake',
#  'delete red_wine',
#  'skip the 1/4 cup butter',
#  'not use red_wine',
#  'have no cornstarch',
#  'have no mushroom',
#  'not use fat free sour_cream',
#  'not use any onion',
#  'not have enough sour_cream',
#  'not have creme_fraiche',
#  'not use creme_fraiche',
#  'not use mushroom',
#  'omit the vegetable_oil',
#  'not add white_wine',
#  'not add chive',
#  'not have white_wine',
#  'omit the vegetable_oil',
#  'omit the mushroom',
#  'delete the garlic',
#  'not have creme_fraiche',
#  'not have creme_fraiche',
#  'not have cream creme_fraiche',
#  'not have concentrate beef_broth',
#  'omit the mushroom',
#  'not have time to make créeme creme_fraiche',
#  'not have crème creme_fraiche',
#  'leave_out the onion',
#  'leave_out the white_wine',
#  'leave_out the worcestershire_sauce',
#  'not add water',
#  'eliminate the onion',
#  'not use cream_cheese',
#  'omit the water',
#  'not use the condensed_golden_mushroom_soup',
#  'not have 2 can of condensed_golden_mushroom_soup',
#  'not have enough beef_stew_meat',
#  'not have to add the cream_cheese',
#  'not have condensed_golden_mushroom_soup',
#  'omit the water',
#  'not have condensed_golden_mushroom_soup',
#  'not have onion',
#  'omit the onion',
#  'not use condensed_golden_mushroom_soup',
#  'leave_out the chopped onion',
#  'not add water',
#  'leave_out the onion',
#  'not have the condensed_golden_mushroom_soup',
#  'not have worchester worcestershire_sauce',
#  'not have onion condensed_golden_mushroom_soup',
#  'omit the maggi seasoning',
#  'omit the seasoning seasoned_salt',
#  'omit the mushroom',
#  'remove the onion/mushroom/ garlic',
#  'not have enough half_and_half',
#  'skip the ketchup',
#  'not add mushroom',
#  'leave_out ketchup and hot_sauce',
#  'use no salt',
#  'leave_out some salt',
#  'not add the salt',
#  'not have any onion',
#  'leave_out the extra boullion and salt',
#  'add no water',
#  'skip the salt',
#  'not put in the mushroom',
#  'not use the water & all_purpose_flour',
#  'not have tomato_paste',
#  'omit the water and all_purpose_flour',
#  'not have mushroom',
#  'leave_out all the water',
#  'not add any salt',
#  'not have any onion or garlic',
#  'omit the all_purpose_flour',
#  'not add salt with the beef_bouillon',
#  'skip the all_purpose_flour',
#  'not add mushroom',
#  'not add quite a much water',
#  'eliminate 2 ground_beef',
#  'not add salt',
#  'omit red_wine',
#  'omit the red_wine',
#  'not add the red_wine',
#  'omit the all_purpose_flour',
#  'omit the sour_cream',
#  'omit the butter',
#  'not use the all_purpose_flour',
#  'omit the onion',
#  'not add the all_purpose_flour',
#  'skip only them and mushroom',
#  'not use garlic_salt',
#  'not use the butter',
#  'have no condensed_cream_of_mushroom_soup',
#  'not use the all_purpose_flour',
#  'not have any sour_cream',
#  'leave_out the butter',
#  'omit the garlic_salt',
#  'not have any sour_cream',
#  'omit actual mushroom but the condensed_cream_of_mushroom_soup',
#  'not use an entire teaspoon of garlic_salt',
#  'omit the mushroom',
#  'not have garlic_salt',
#  'not have an onion',
#  'not have condensed_cream_of_mushroom_soup',
#  'leave_out the butter',
#  'not have egg_noodle',
#  'not have fresh mushroom or sour_cream',
#  'not use fresh onion',
#  'not use garlic_salt',
#  'omit the all_purpose_flour',
#  'omit the all_purpose_flour',
#  'omit the all_purpose_flour',
#  'leave_out the onion',
#  'not add the paprika',
#  'skip the all_purpose_flour',
#  'leave_out the salt',
#  'omit 1 can of condensed_cream_of_mushroom_soup',
#  'not have sour_cream',
#  'omit the all_purpose_flour',
#  'not add paprika',
#  'not have any condensed_cream_of_mushroom_soup',
#  'omit all_purpose_flour',
#  'omit the all_purpose_flour',
#  'not use all_purpose_flour',
#  'skip the onion',
#  'leave_out the all_purpose_flour',
#  'not add all_purpose_flour',
#  'omit the condensed_cream_of_mushroom_soup',
#  'omit the all_purpose_flour',
#  'not add all_purpose_flour',
#  'not add the all_purpose_flour',
#  'not use the all_purpose_flour',
#  'not use any all_purpose_flour',
#  'not use the all_purpose_flour',
#  'not use the all_purpose_flour',
#  'not add a full cup of sour_cream',
#  'not have sour_cream of anything condensed_cream_of_mushroom_soup',
#  'not add lemon_juice or milk',
#  'omit the tomato_paste',
#  'omit the white_wine and the seasoned_salt',
#  'not have the white_wine',
#  'not have any white_wine',
#  'not use a much cream_cheese',
#  'skip the extra water',
#  'not have condensed_cream_of_mushroom_soup',
#  'not use cream_cheese',
#  'not add any onion',
#  'not have carrot or red_potato',
#  'not have any corned_beef',
#  'remove the corned_beef',
#  'omit the red_potato',
#  'not use the carrot',
#  'have no red_potato',
#  'omit the carrot',
#  'omit the red_potato',
#  'remove corned_beef',
#  'not put in enoght carrot',
#  'not add cabbage',
#  'skip the cabbage',
#  'not have small red_potato',
#  'remove the corned_beef',
#  'leave_out the red_potato',
#  'remove the corned_beef',
#  'leave_out red_potato',
#  'remove the corned_beef',
#  'remove the corned_beef',
#  'not have carrot',
#  'remove the corned_beef',
#  'not add cut up russet red_potato',
#  'remove corned_beef',
#  'not add the carrot',
#  'remove the corned_beef',
#  'leave_off the rye_bread',
#  'not have any rye_bread or sauerkraut',
#  'omit the rye_bread',
#  'skip the sour_cream',
#  'not add the minced onion',
#  'not add a lot of cider_vinegar',
#  'leave_out the cider_vinegar',
#  'remove the corned_beef',
#  'remove the corned_beef',
#  'remove the corned_beef',
#  'not have beer',
#  'not use beer',
#  'not have beer',
#  'not have any garlic',
#  'skip the garlic and carrot',
#  'not have smoke paprika or ground_white_pepper',
#  'remove the corned_beef',
#  'not have the dumpling but the split_pea',
#  'skip the cabbage and celery',
#  'not add any water or carrot',
#  'not use the pickling_spice',
#  'not have rye bread_crumb',
#  'not have corned_beef',
#  'eliminate the beer',
#  'skip the cabbage',
#  'leave_out the cabbage',
#  'not add any water',
#  'not have any beer',
#  'leave_out the beer',
#  'not use any beer',
#  'not have any beer',
#  'not add the cabbage',
#  'not have beer',
#  'not use the beer',
#  'not add the beer',
#  'not use beer',
#  'not use beer',
#  'not add the cabbage',
#  'not add the beer',
#  'omit the beer',
#  'skip the beer',
#  'omit the beer',
#  'leave_out red_potato',
#  'not bother_with the beer',
#  'not use cabbage',
#  'not add cabbage',
#  'omit the onion',
#  'not use the beer',
#  'not have like it with the beer',
#  'remove the cabbage',
#  'omit the beer',
#  'skip the beer',
#  'not bother_with beer',
#  'omit the red_potato and carrot',
#  'remove the corned_beef and red_potato',
#  'skip the onion',
#  'omit onion',
#  'not add the extra water',
#  'not add the beer',
#  'omit the veges except the onion',
#  'not use beer',
#  'omit be the onion',
#  'eliminate the water and use corned_beef',
#  'not put the beer',
#  'not put carrot',
#  'remove the corned_beef',
#  'not have get the cabbage',
#  'remove the cabbage',
#  'leave_out the beer',
#  'not add beer',
#  'not add the carrot or cabbage',
#  'omit the beer',
#  'omit the beer',
#  'subtract some water',
#  'not add the beer',
#  'remove the corned_beef',
#  'not use a dark beer',
#  'not use beer',
#  'omit the beer',
#  'not add the beer',
#  'not add the red_potato & carrot',
#  'not use the beer',
#  'not have luck cooking thing with beer',
#  'not add the beer',
#  'omit onion',
#  'not put the red_potato',
#  'omit the water',
#  'leave_out the beer',
#  'omit the onion',
#  'omit the beer',
#  'not have any beer',
#  'leave_out the beer',
#  'eliminate the beer',
#  'not put the red_potato',
#  'not use beer',
#  'not add the red_potato and carrot',
#  'not use any carrot and the red_potato',
#  'not add the cabbage',
#  'not add thicker carrot',
#  'leave_out the beer',
#  'not use any beer just water',
#  'not have red_potato',
#  'not use beer',
#  'not use any beer',
#  'not add the beer',
#  'not add beer',
#  'not have 1 drop of beer',
#  'remove corned_beef',
#  'omit the beer',
#  'leave_out the beer and onion',
#  'skip the beer',
#  'not use all of the water',
#  'not put the beer',
#  'not add beer',
#  'omit the cabbage',
#  'omit the brown_sugar',
#  'not use brown_sugar',
#  'not use the beer',
#  'not put in any sweet_potato',
#  'not use the whole amount of brown_sugar',
#  'leave_out the brown_sugar',
#  'leave_out the cabbage',
#  'not use sweet_potato',
#  'not use the brown_sugar',
#  'not use the sweet_potato',
#  'not have stout beer',
#  'not use a sweet_potato',
#  'not use a much brown_sugar',
#  'leave_out yellow_squash and potato',
#  'not add the yellow_squash and zucchini',
#  'not use yellow_squash or zucchini',
#  'leave_out the zucchini',
#  'omit the all_purpose_flour',
#  'not add any raw onion',
#  'use no onion',
#  'remove the rump_roast',
#  'not have the soup_mix',
#  'not add any onion',
#  'skip the water',
#  'omit potato',
#  'leave_out celery',
#  'not use potato in the chuck_roast',
#  'omit the celery',
#  'omit the beer',
#  'leave_out tomato_paste',
#  'omit the all_purpose_flour',
#  'skip the tomato_paste',
#  'omit the brown_sugar',
#  'leave_out the tomato_paste',
#  'not have dark beer',
#  'omit the veggie except some onion',
#  'not have beer',
#  'not have a dark beer',
#  'not add the mushroom',
#  'omit the tomato_paste',
#  'leave_out the potato',
#  'not have dark beer',
#  'not use all_purpose_flour',
#  'not use mushroom',
#  'leave_out mushroom',
#  'not have beer',
#  'not have stout beer',
#  'leave_out the turnip',
#  'omit the turnip',
#  'not have any turnip',
#  'omit the turnip & celery',
#  'remove meat and saute red_onion',
#  'skip the turnip',
#  'omit turnip',
#  'leave_out the turnip',
#  'not have brown gravy_mix',
#  'omit the celery',
#  'not add any celery',
#  'leave_out the brown gravy_mix',
#  'omit the gravy_mix',
#  'not use the condensed condensed_cream_of_mushroom_soup',
#  'omit the celery',
#  'eliminate the water',
#  'omit the celery',
#  'leave_out celery',
#  'omit the minced garlic',
#  'not put in the celery',
#  'omit the condensed_cream_of_mushroom_soup',
#  'not use the celery',
#  'not add so much celery',
#  'leave_out the carrot',
#  'omit the celery and carrot',
#  'omit the condensed_cream_of_mushroom_soup',
#  'not have any brown gravy_mix',
#  'leave_out the celery',
#  'not add a gravy_mix',
#  'omit the carrot and celery',
#  'not have brown gravy_mix',
#  'not have the cream of chickn condensed_cream_of_mushroom_soup',
#  'not use celery',
#  'not have a packet of gravy_mix',
#  'not use celery',
#  'leave_out the gravy_mix',
#  'not have to be sirloin',
#  'not have a packet of brown gravy_mix',
#  'not have condensed_cream_of_mushroom_soup',
#  'not have any gravy_mix',
#  'not have carrot',
#  'not use the celery',
#  'not have any brown gravy_mix',
#  'leave_out the brown gravy_mix',
#  'leave_out the gravy_mix',
#  'leave_out the celery',
#  'omit the celery',
#  'omit the gravy_mix',
#  'leave_out the celery',
#  'omit the celery',
#  'have no condensed_cream_of_mushroom_soup',
#  'delete the dry_vermouth',
#  'remove the dry_vermouth',
#  'not have condensed_cream_of_mushroom_soup',
#  'not have condensed_cream_of_mushroom_soup',
#  'not have dry_vermouth',
#  'have no dry_vermouth',
#  'not have any dry_vermouth',
#  'not have the dry soup_mix',
#  'remove the rump_roast',
#  'have no dry_vermouth',
#  'not have any condensed_cream_of_mushroom_soup',
#  'not have dry_vermouth',
#  'not use the dry_vermouth',
#  'not have dry_vermouth',
#  'omit the dry_vermouth',
#  'not have dry_vermouth',
#  'not use all_purpose_flour',
#  'not use 1/4 cup of butter',
#  'not have dry_vermouth',
#  'not use all_purpose_flour',
#  'not add the condensed_cream_of_mushroom_soup',
#  'not use the dry_vermouth',
#  'not have dry_vermouth',
#  'not have dry_vermouth',
#  'skip the all_purpose_flour',
#  'skip the butter',
#  'not have dry_vermouth',
#  'not use condensed_cream_of_mushroom_soup',
#  'not use any all_purpose_flour',
#  'not have condensed_cream_of_mushroom_soup',
#  'not have white wite or dry_vermouth',
#  'not have dry_vermouth',
#  'not have butter',
#  'remove rump_roast',
#  'skip the butter',
#  'not have any dry_vermouth',
#  'not add the dry_vermouth',
#  'not use the butter or all_purpose_flour',
#  'not have dry_vermouth',
#  'leave_out condensed_cream_of_mushroom_soup',
#  'not use butter',
#  'not use the dry_vermouth',
#  'not have any dry_vermouth',
#  'skip butter & dry_vermouth',
#  'not have dry_vermouth',
#  'not have dry_vermouth',
#  'not have dry_vermouth',
#  'not have condensed_cream_of_mushroom_soup',
#  'not use a gravy soup_mix',
#  'omit the water',
#  'not have to carve the bottom_round_roast',
#  'not have soup_mix',
#  'not have to brown the bottom_round_roast',
#  'not add water',
#  'remove the bottom_round_roast',
#  'eliminate the soup_mix',
#  'not add a much water',
#  'not have 2 can of condensed_cream_of_mushroom_soup',
#  'remove the bottom_round_roast',
#  'not add water',
#  'not use condensed_cream_of_mushroom_soup',
#  'remove the bottom_round_roast',
#  'not add all of the soup_mix',
#  'not use a top bottom_round_roast',
#  'not have condensed_cream_of_mushroom_soup',
#  'not have pre make soup_mix',
#  'leave_out the water',
#  'not use canned condensed_cream_of_mushroom_soup',
#  'not add the coffee',
#  'not have the montreal steak_seasoning',
#  'not have a can of tomato_sauce',
#  'not have tomato_sauce',
#  'not have montreal-style steak_seasoning',
#  'omit the tomato_sauce',
#  'not have a bunch of package steak_seasoning',
#  'not add the tomato_sauce or dried_oregano',
#  'leave_out the cup of water',
#  'omit the water',
#  'omit the water from the cranberry_sauce',
#  'not add vegetable_oil',
#  'omit the water',
#  'not use a much onion',
#  'leave_out the water',
#  'omit the water',
#  'not add water',
#  'leave_out the potato',
#  'not add the potato',
#  'omit the potato',
#  'omit the apple_juice',
#  'not have concentrate apple_juice',
#  'not have garlic_salt',
#  'not put in baby_carrot but the new_potato',
#  'not add salt',
#  'leave_off the bay_leaf',
#  'remove garlic',
#  'not use a beef_chuck',
#  'not have enough onion',
#  'not have onion',
#  'not add the additional salt',
#  'not have bay_leaf',
#  'not have bay_leaf',
#  'remove the onion',
#  'not use the garlic',
#  'leave_out the rosemary',
#  'remove and brown the white_onion',
#  'not have fresh rosemary',
#  'not add water',
#  'not use the allspice_berry',
#  'remove the carrot',
#  'not have whole allspice_berry',
#  'not have celery',
#  'not have any celery',
#  'not have celery',
#  'leave_out the celery',
#  'not have celery',
#  'omit the celery',
#  'leave_out the unsalted_butter',
#  'not add the dried_rosemary',
#  'leave_out the celery',
#  'remove it and brown chunk carrot',
#  'not use celery',
#  'not have any celery',
#  'not use dried_rosemary',
#  'not have dry dried_rosemary',
#  'not have any celery',
#  'not have dried_rosemary',
#  'not have any celery',
#  'skip the condensed_cream_of_mushroom_soup',
#  'not have the oinion soup_mix',
#  'omit the water',
#  'not have pot bottom_round_roast',
#  'not have the 9x13 bottom_round_roast',
#  ...]

# %%
list(itertools.chain.from_iterable(real_addition_list))
# Out:
# ['use a pork_roast',
#  'use chicken',
#  'use a 4 lb chuck_roast',
#  'use kraft honey hickory liquid_smoke',
#  'use a bottle of local honey',
#  'add the two beer and seasoning',
#  'add 3 cup of beef_broth',
#  'use an english chuck_roast',
#  'use a chuck_roast',
#  'use a venison',
#  'use this recipe on a pork_roast',
#  'use 1 c beef_broth',
#  'add montreal steak',
#  'add an onion',
#  'use minute white_rice and alittle chicken',
#  'use dice tomato with basil',
#  'add something green like bell pepper',
#  'add onion',
#  'add one chopped onion',
#  'add minced onion',
#  'add chopped onion and green_bell_pepper',
#  'add some milk',
#  'add chili_powder & onion',
#  'add garlic',
#  'add to it by saute onion',
#  'add the onion',
#  'add some pizza blend mozzarella_cheese',
#  'put in a can of celery',
#  'add some pepper and onion',
#  'add corn',
#  'add a little green_bell_pepper and worcestershire_sauce',
#  'add the minced garlic',
#  'add garlic and onion',
#  'add celery',
#  'add some lipton onion condensed_cream_of_mushroom_soup',
#  'add black_bean and taco_seasoning',
#  'put about a teaspoon of worcestershire_sauce',
#  'add white_bean and french fry onion',
#  'add some crushed red pepper',
#  'add tabassco sauce',
#  'add 1/2 cup milk',
#  'add a little water',
#  'add mince garlic',
#  'add garlic_salt',
#  'add some taco_seasoning',
#  'add chop green pepper',
#  'add corn and black_bean',
#  'add dash of worcestershire_sauce',
#  'add garlic_powder',
#  'add a bell pepper',
#  'add an onion',
#  'add a dash of a1 sauce',
#  'add sugar',
#  'add a little sugar',
#  'add garlic',
#  'add some pepper and onion',
#  'use italian herb tomato',
#  'add chopped pepper and onion',
#  'add a little garlic baking_powder',
#  'add some mustard',
#  'add gourmet mustard',
#  'use pillsbury crescent_roll',
#  'add onion & mushroom',
#  'add a drained can of mushroom',
#  'add some garlic or other seasoning',
#  'use only chicken_breast',
#  'use saffron rice',
#  'add artichoke and add paprika',
#  'use arborio_rice',
#  'add some salt',
#  'add some garlic_salt',
#  'add cure salt',
#  'use it for venison',
#  'use the curing salt',
#  'add side of the lemon_zest garlic',
#  'add crunchy honey oat_cereal',
#  'use canola_oil',
#  'add powdered sage',
#  'add more seasoning to the all_purpose_flour',
#  'add some pepper and chili garlic_powder',
#  'use butter saltine_cracker',
#  'use cheez-its instead_of soda saltine_cracker',
#  'add a homemade white pepper',
#  'use thick pork_loin pork_chop',
#  'add a knob of butter',
#  'use some chicken_stock and milk',
#  'add a little herb',
#  'use those chicken in a biscuit',
#  'use panko lemon_pepper bread_crumb',
#  'use little cayenne_pepper',
#  'use a little coconut_oil',
#  'use bread_crumb',
#  'use the same seasoning',
#  'use ritz cheese saltine_cracker',
#  'add tablespoon of the keg steak',
#  'put a dry brown_sugar',
#  'add a pat of butter',
#  'use buttermilk',
#  'use smoked_paprika',
#  'add pepper',
#  'use 2-3 shot of good brandy',
#  'put large piece of carrot',
#  'use whole_clove of garlic',
#  'add some worstershire sauce',
#  'put the ground_black_pepper and kosher_salt',
#  'add lot of garlic_powder',
#  'use a 7-bone chuck_roast',
#  'add about a cup of water',
#  'add some herb like rosemary',
#  'use montreal steak spice instead_of ground_black_pepper',
#  'use rib_roast',
#  'add a few tablespoon of water',
#  'add some partially boil potato',
#  'add some salt',
#  'add a bit of beef_broth',
#  'add water',
#  'add some salt',
#  'add worchestire sauce',
#  'add worchestershire sauce',
#  'put some sliced carrot',
#  'put in some kind of sauce',
#  'add a little worcestershire_sauce',
#  'use 1/4 cup worsteshire sauce',
#  'add a little low salt worcestershire_sauce',
#  'add some cut up potato',
#  'put me on a salt',
#  'use bourbon marinade beef_sirloin',
#  'use only red and orange green_bell_pepper',
#  'add quartered potato',
#  'add more just chicken beef_broth',
#  'use any cut of beef',
#  'use skewer',
#  'use it for a marinade',
#  'use the rest to baste steak',
#  'use 1/2 the beef',
#  'add zuchinni and squash',
#  'add just 1/2 cup of water',
#  'use the reserve marinade',
#  'use and put the beef',
#  'use smoked_paprika',
#  'use the worcestershire_sauce a a marinade',
#  'use lipton onion and mushroom',
#  'add seasoning',
#  'add a little olive_oil',
#  'add garlic',
#  'add about a tablespoon of cream_of_mushroom_soup',
#  'add butter',
#  'use lean pork_chop',
#  'use a can of cream_of_mushroom_soup',
#  'add some butter',
#  'add some sliced fresh mushroom',
#  'put a pad of butter',
#  'put a slice of cheddar_cheese',
#  'add garlic',
#  'add garlic_powder spicy montreal steak_seasoning',
#  'add worcestershire_sauce',
#  'use some small steak',
#  'add chopped garlic and onion',
#  'add bell pepper and cabbage',
#  'use dawn fresh mushroom sauce',
#  'put corn',
#  'add a pat of butter',
#  'use 4oz piece of ground_beef steak',
#  'add a tad butter',
#  'use mccormick steak_seasoning',
#  'put an egg',
#  'use non stick',
#  'use garlic_powder',
#  'add worcestershire_sauce',
#  'add the olive_oil',
#  'add more veggie ( corn',
#  'add celery and green_bean',
#  'use sausage',
#  'use zucchini and green_bean',
#  'use half spicy breakfast_sausage',
#  'put a tablespoon of cream_of_mushroom_soup',
#  'add a pack of onion_soup',
#  'add a little butter',
#  'add a little red_wine',
#  'add large 3 slice apple',
#  'add a bit of black pepper',
#  'use 18 date',
#  'add a lil onion_powder and garlic_powder',
#  'use cub steak',
#  'use garlic and onion_powder',
#  'use beef cubed steak',
#  'add garlic_powder and paprika',
#  'add meat_tenderizer',
#  'use beef cub steak',
#  'use only milk',
#  'use a combination of beef_broth',
#  'use top round or bottom round_steak',
#  'use cub steak rather then veal',
#  'add some garlic_powder',
#  'use a can of cream_of_mushroom_soup',
#  'use tenderized cube_steak',
#  'add the garlic and onion_powder',
#  'use beef cube_steak rather than veal',
#  'use t-bone steak',
#  'use chuck steak',
#  'add garlic',
#  'use cube_steak',
#  'add paprika',
#  'use thin-sliced chicken_breast',
#  'use cube_steak',
#  'use minute steak',
#  'use peanut_oil in a chicken',
#  'use equal amount of ground oregano',
#  'add plenty of salt and pepper',
#  'add milk',
#  'use the thin slice chicken_breast',
#  'use southeastern mill mix and garlic',
#  'use buffalo minute steak',
#  'use cube_steak rather than the veal',
#  'put garlic_powder',
#  'use stew beef',
#  'add a few seasoning',
#  'add a packet of dry gravy_mix',
#  'add it to the hot_sauce',
#  'add 2 beef',
#  'add some montreal steak_seasoning and salt',
#  'add two cup of beef_broth',
#  'add a couple of beef_bouillon',
#  'add beef_broth',
#  'add 2 cup of water',
#  'add fresh rosemary',
#  'use some rosemary',
#  'add beef_broth',
#  'add some couscous',
#  'add 2 lipton onion mushroom soup_mix',
#  'add oregano',
#  'add potato carrots & celery',
#  'use beef_chuck steak',
#  'add carrot',
#  'add more coffee and some herb',
#  'add about 1/4 cup ketchup',
#  'add more of the seasoning',
#  'add worchestershire sauce',
#  'add some dried_rosemary and thyme',
#  'add some red_wine',
#  'add worcestershire and beef_bouillon',
#  'add a couple clove of garlic',
#  'use that with pork and chicken',
#  'use dried_tarragon in a beef',
#  'add roast red pepper',
#  'add a little garlic',
#  'add some garlic and tomato',
#  'add quartered mushroom',
#  'put baby_carrot & potato',
#  'use montreal steak_seasoning',
#  'use a chicken',
#  'add a few sliced mushroom',
#  'add a few clove of garlic',
#  'add in a carrot',
#  'add be brown sauce',
#  'add garlic',
#  'add a can of crush tomato',
#  'use grape_juice instead_of red marsala_wine',
#  'add mushroom',
#  'add baby red_potato and baby_carrot',
#  'add mushroom',
#  'use marinade for worcestershire_sauce',
#  'use chicken_leg',
#  'add minced onion and/or green ground_black_pepper',
#  'add 1/3 cup milk',
#  'add a chili garlic_paste',
#  'add a little cayanne pepper',
#  'put the sauce',
#  'add a diced orange_bell_pepper',
#  'add an orange_bell_pepper',
#  'add a lot more lime',
#  'add sriracha and soy_sauce',
#  'add 1/2 tsp red_pepper_flake',
#  'add a little garlic',
#  'add some fried mushroom',
#  'use extra_virgin_olive_oil instead_of the butter',
#  'add green and red_bell_pepper',
#  'add a spoonful of sugar',
#  'use seasoned_salt',
#  'add bacon to the sweet_onion',
#  'add some soy_sauce',
#  'add a sliced granny_smith_apple',
#  'use the fat from the bacon',
#  'put garlic_powder',
#  'add a bit of water',
#  'add some brown_sugar and dry_mustard',
#  'add 2 c of beef_broth',
#  'add a bit of sour_cream',
#  'use some garlic_powder',
#  'add 1 cup of beef_broth',
#  'add a bell pepper',
#  'use 2 tbls of bacon',
#  'add bacon',
#  'add the seasoning to the all_purpose_flour',
#  'use a can of beef_broth',
#  'use bacon',
#  'add 4 clove of minced garlic',
#  'put the sweet_onion on bread',
#  'use this recipe with rabbit beef_liver',
#  'use beef calve beef_liver',
#  'add garlic_salt',
#  'add some cold water',
#  'add a little garlic',
#  'add some garlic_powder',
#  'use some dijon_mustard',
#  'add a wee bit of rosemary',
#  'add curry and use sunflower_seed',
#  'use some of the buttermilk',
#  'use buttermilk',
#  'add in some mushroom',
#  'use almond all_purpose_flour',
#  'add garlic_powder',
#  'add green pepper',
#  'add the buttermilk',
#  'add garlic',
#  'add mushroom or pepper',
#  'add a tad bit of lemon_juice',
#  'add a little bit of garlic',
#  'add to soon a garlic',
#  'add a touch of minced garlic',
#  'add a little olive_oil',
#  'add garlic',
#  'use to cook beef_liver in vegetable_oil',
#  'add some garlic_powder to the all_purpose_flour',
#  'use whole_milk',
#  'add a little sweet_onion and garlic_powder',
#  'use panko bread_crumb',
#  'use half_and_half',
#  'add garlic',
#  'add some bacon to the sweet_onion',
#  'add a bit of vegetable_broth',
#  'add some cooked bacon',
#  'add bacon',
#  'add beef',
#  'put bacon',
#  'use 50 % corn all_purpose_flour',
#  'add chopped bacon to the butter',
#  'add a table spoon of soy_sauce',
#  'use venison beef_liver',
#  'add fennel and sweet_onion',
#  'add bacon',
#  'add a clove of garlic',
#  'add a pinch of diced garlic',
#  'add 8 slice of bacon',
#  'add pepper to the all_purpose_flour',
#  'add 1 cup of beef_broth',
#  'add mushroom and a little garlic',
#  'add garlic_salt to the butter',
#  'add a sprinkle of extra all_purpose_flour',
#  'use bacon fat instead_of butter',
#  'add garlic_powder',
#  'add extra sweet_onion and pepper',
#  'add mccormick montreal steak',
#  'add a little sherry',
#  'use bacon',
#  'put some garlic_powder in the all_purpose_flour',
#  'add some panko and crush pepper',
#  'use half_and_half',
#  'use garlic_powder in the all_purpose_flour',
#  'add garlic and mushroom',
#  'add garlic_powder',
#  'add paprika and season salt',
#  'add a little more seasoning',
#  'add sour_cream and some all_purpose_flour',
#  'use just water',
#  'put bacon',
#  'add a decent amount of lime_juice',
#  'add 2 tbsp lime_juice',
#  'use the strawberry margarita',
#  'use pork and chicken',
#  'add lime_juice and lime_zest',
#  'add tequila',
#  'use 1/4 cup of tequila',
#  'add the 1/4 tequila',
#  'add tequila to the marinade',
#  'add a 1/4 cup of lime_juice',
#  'add some tequila',
#  'use a better cut of beef',
#  'add 1.5 lime',
#  'add lime_juice',
#  'add a touch of brown_sugar',
#  'add a few frozen pea',
#  'put big chunk of onion',
#  'use boneless chicken',
#  'add a bit of cornstarch',
#  'add 2 t. of brown_sugar',
#  'add cornstarch',
#  'put in brown_sugar',
#  'add in green pepper and onion',
#  'add a cornstarch',
#  'add brown_sugar',
#  'add dice zucchini and sliver carrot',
#  'use turkey',
#  'add pepper',
#  'add green chile and onion',
#  'add in the cranberry',
#  'put it over brown_rice',
#  'add chop green pepper',
#  'use a can of mixed_fruit',
#  'put on top of brown_rice',
#  'add mash potato',
#  'add barbeque_sauce',
#  'add 1/2 tablespoon of horseradish sauce',
#  'add some cornstarch',
#  'add in sliced mushroom',
#  'use a lemon olive_oil',
#  'use liptons beefy onion soup_mix',
#  'add beer',
#  'add potato and baby_carrot',
#  'use the leftover sauce',
#  'add about 1 cup of mushroom',
#  'use roman noodle',
#  'add butter and parmesan/romano american_cheese',
#  'add a little ketchup and mustard',
#  'use all beef',
#  'add some crushed red pepper',
#  'add water',
#  'add about 1/4 cup of ranch_dressing',
#  'put it over white_rice',
#  'use tomato_sauce',
#  'use pork',
#  'use to salt-seasoned steak',
#  'add chunk of cheese',
#  'add jalapeno and cheese',
#  'use venison',
#  'add 1/2 tea',
#  'add peppercorn and crush red ground_black_pepper',
#  'use 1/2 ground_beef & 1/2 pork',
#  'use casing or sausage',
#  'add some water to the sugar_based_curing_mixture',
#  'add better taste to pork',
#  'use a curing salt',
#  'add some peppercorn',
#  'add cheese',
#  'add a packet of dry onion',
#  'add dry onion condensed_cream_of_mushroom_soup',
#  'put fresh asparagus',
#  'add the onion condensed_cream_of_mushroom_soup',
#  'add onion',
#  'add 1/2 envelope onion condensed_cream_of_mushroom_soup',
#  'add onion instead_of the chive',
#  'add be a bit more garlic',
#  'use the dry onion condensed_cream_of_mushroom_soup',
#  'add some garlic',
#  'use steak',
#  'add 1 cup of chicken_stock',
#  'add salt',
#  'use the montreal steak_seasoning',
#  'use small new red_potato',
#  'put over noodle',
#  'add mushroom',
#  'add mushroom',
#  'add about a half cup corn',
#  'put it over egg_noodle',
#  'use pasta spiral instead_of potato',
#  'add dry onion_soup',
#  'use potato and serve over egg_noodle',
#  'add spice and herb',
#  'add sweet_potato and bake potato',
#  'add soup crouton',
#  'use sweet_potato',
#  'add 3/4 c elbow whole wheat',
#  'add mushroom',
#  'add egg_noodle',
#  'add fresh mushroom 1-can beef_broth',
#  'use an entire fresh lemon',
#  'use lemon ground_black_pepper and chicken beef_broth',
#  'use oil and rice all_purpose_flour',
#  'add about 1 tsp rosemary',
#  'use white_wine',
#  'add some diced bacon',
#  'use some leave over white_wine',
#  'use chicken beef_broth',
#  'use lemon ground_black_pepper',
#  'use more lemon',
#  'use for a sauce',
#  'use lemon ground_black_pepper in the seasoning',
#  'use french_baguette',
#  'add a special topping',
#  'add raisin',
#  'use leftover generic raisin french_bread',
#  'use cranberry french_bread',
#  'add 1 small can of pineapple_juice',
#  'use aluminum_foil',
#  'add 3 tbsp rum',
#  'use apricot',
#  'use apricot preserve and extra garlic',
#  'add 1/2 cup of peach_jam',
#  'use it with cornish_game_hen and brown_rice',
#  'use chicken_thigh',
#  'use dried_tarragon',
#  'add tiny increment of flour',
#  'use this for quail and pheasant',
#  'use pheasant',
#  'use reisling wine',
#  'use mango pepper_jam',
#  'add the wine',
#  'use mango chutney',
#  'use cashew',
#  'add chop mushroom',
#  'put the stuffing',
#  'add 2 tablespoon of sweeten coconut',
#  'use half craisin & half dried_blueberry',
#  'add dried_blueberry',
#  'add snow_pea and bell red_chile_pepper',
#  'use beef_stew_meat',
#  'add a little onion_powder',
#  'use cream of mushroom onion_soup',
#  'add 3 tablespoon of soy_sauce',
#  'use some of the reserve tomato_juice',
#  'add a tablespoon of crunchy peanut_butter',
#  'add water and flour',
#  'add a bit of water',
#  'use toothpick',
#  'use top round_steak',
#  'add clean and quarter russet_potato',
#  'add a clove of garlic',
#  'use a serrano_pepper',
#  'add about a t of ketchup',
#  'use it for chicken',
#  'add in some pepper',
#  'use this sauce',
#  'add green hot_sauce',
#  'add to shrimp taco with mango',
#  'put quarter grape_tomato',
#  'add snow_pea',
#  'add herb',
#  'use 2 huge spanish_onion',
#  'put 1 tsp each of peppercorn',
#  'put the chopped herb',
#  'add a beef',
#  'add 2 garlic',
#  'add a package of sliced mushroom',
#  'add a teaspoon of dried_thyme',
#  'add 3/4 cup low sodium beef_broth',
#  'add 3 clove of minced garlic',
#  'use one or two red_onion',
#  'add 2 can of drained mushroom',
#  'add a beef',
#  'use one large sweet_onion',
#  'use a spanish red_wine',
#  'add additional salt & pepper',
#  'add chop garlic with the onion',
#  'use mrs. dash herb seasoning',
#  'add some cornstarch',
#  'use tastefully simples balsmic and basil',
#  'add mince garlic to the onion',
#  'add fresh mushroom and use apple',
#  'add more pepper and some garlic_powder',
#  'add some baby bella mushroom',
#  'add garlic and use beef_broth',
#  'add red_wine',
#  'put some baby_carrot',
#  'add some red_wine',
#  'use 1/4 burgundy wine',
#  'use one beef',
#  'add a couple clove of garlic',
#  'use a little canola_oil',
#  'add some rosemary and thyme',
#  'add more merlot & some beef_broth',
#  'add garlic',
#  'use wine',
#  'use red_wine',
#  'add 4 really good size mushroom',
#  'add fresh rosemary',
#  'add onion and fresh garlic',
#  'use red_wine white_vinegar instead_of regular white_vinegar',
#  'add some brown_sugar and apple_cider white_vinegar',
#  'use red_wine white_vinegar',
#  'use a can of campbell beef',
#  'use 1 cup of beef_broth',
#  'add some sprig of fresh rosemary',
#  'add baby_carrot & potato',
#  'add a couple clove of garlic',
#  'add about 1/2 cup beef_broth',
#  'add salt and course crack pepper',
#  'add a small amount of beer',
#  'add 1 beef',
#  'add a packet of no-sodium beef',
#  'add some thyme bay_leaf',
#  'add merlot_wine',
#  'add another cup of wine',
#  'add some red_wine & italian_seasoning',
#  'add garlic',
#  'add garlic',
#  'add garlic_powder',
#  'add mince garlic',
#  'add garlic and only 4 onion',
#  'add some carrot and garlic',
#  'add wine',
#  'add herb',
#  'put over egg_noodle',
#  'add garlic',
#  'add the bay_leaf and beef_broth',
#  'add 3 large mince garlic',
#  'add quarter potato and fresh carrot',
#  'add a little cornstarch',
#  'add thyme',
#  'add a sprig of rosemary',
#  'add two cup of chicken_broth',
#  'use a cheap cut of beef',
#  'add some taco_seasoning and topping',
#  'add some italian_seasoning',
#  'add a cup of beef_broth',
#  'use red_wine white_vinegar',
#  'use 2 humongous white_onion',
#  'use beef_broth in place of water',
#  'use a bit of red_wine',
#  'add garlic',
#  'add some sour_cream',
#  'add some garlic_powder and additional salt',
#  'add mince garlic',
#  'use chinese cooking wine',
#  'put them in the sauce',
#  'add a cup of red_wine',
#  'add some unsalted beef_stock',
#  'add diced tomato',
#  'add 1 tbsp red_wine white_vinegar',
#  'add 4 thinly sliced sweet_onion',
#  'add some cornstarch in cold water',
#  'use wine',
#  'use a a tenderizer but wine',
#  'add 3 tb of kentucky bourbon',
#  'add a cup of beef_stock',
#  'add some sliced mushroom',
#  'add 1/4 of wine',
#  'use cornstarch & water',
#  'add seasoning',
#  'use rice white_vinegar',
#  'use a package of brown gravy_mix',
#  'add some fresh rosemary',
#  'use balsamic white_vinegar and beef_broth',
#  'add a teaspoon of dried_thyme',
#  'use the red_wine',
#  'add carrot',
#  'add a little red_wine',
#  'use a can of beef_broth',
#  'add fresh carrot',
#  'put in some potato',
#  'use chicken_stock',
#  'use chive instead_of the green_onion',
#  'add about 1/4 cup of orange_juice',
#  'add two garlic cloves..half an green_onion',
#  'add some garlic',
#  'use chicken',
#  'add a little ground_ginger',
#  'put some raisin',
#  'add a cup of frozen pea',
#  'add rasins and apple',
#  'add frozen pea',
#  'add some toast sliced almond',
#  'use this with some mushroom',
#  'use ground_cumin',
#  'add golden_raisin',
#  'add some green_bean a tomato',
#  'use baby_carrot and put celery',
#  'use the pre-packaged baby_carrot',
#  'add lipton beefy onion_soup',
#  'use the red_potato',
#  'add onion_soup',
#  'add mushroom',
#  'use red_potato',
#  'add canned pea',
#  'use onion_soup',
#  'add fresh mushroom',
#  'add the worchestershire sauce',
#  'add some fresh chop parsley',
#  'add worcestershire_sauce',
#  'use garlic',
#  'add the tomato_sauce',
#  'add tomato_sauce',
#  'add a package of onion_soup',
#  'add more seasoning',
#  'put a slice of velvita cheese',
#  'add 1 pckg dry onion_soup',
#  'add butter and parsley',
#  'add season chicken_broth',
#  'add some cheese',
#  'add oregano',
#  'add little bit of butter',
#  'add beefy onion_soup',
#  'add more seasoning',
#  'add some cheese',
#  'add cabbage',
#  'add a few more seasoning',
#  'use some ai marinade sauce',
#  'add a generous amount of lemon',
#  'add bell ground_black_pepper and cabbage',
#  'add some tomato',
#  'use mrs. dash original seasoning',
#  'use ground_turkey',
#  'add a can of tomato_sauce',
#  'add some oregano',
#  'use fresh garlic',
#  'add diced tomato',
#  'put in a few butter',
#  'add onion_soup',
#  'add more seasoning',
#  'add green ground_black_pepper and celery',
#  'add an envelope of onion_soup',
#  'add a few spoonful of cream_of_mushroom_soup',
#  'add some slice mushroom',
#  'use lean meat and add butter',
#  'use turkey',
#  'add a little bit of soy_sauce',
#  'put piece of bread',
#  'add egg',
#  'add the onion_soup',
#  'add ton of seasoning',
#  'add 2 tbsp of butter',
#  'use teriyaki marinade and red ground_black_pepper',
#  'add celery',
#  'add a little worcestershire_sauce and garlic',
#  'add some worstershire sauce',
#  'put cream of chicken or cream_of_mushroom_soup',
#  'put a few piece of zucchini',
#  'add seasoning',
#  'add shredded cheese',
#  'add cheese',
#  'add onion_soup',
#  'add golden mushroom',
#  'add a package of onion_soup',
#  'add a good bit of worcestershire_sauce',
#  'put condensed_cream_of_mushroom_soup',
#  'put some butter',
#  'add fresh or can mushroom',
#  'add ketchup',
#  'add a piece of bacon',
#  'add 1 clove mince garlic',
#  'add green_bean and ground_black_pepper',
#  'add an egg',
#  'add onion mushroom soup_mix',
#  'add the onion_soup',
#  'put potato and corn or green_bean',
#  'add butter',
#  'add a little cabbage',
#  'add squash or tomato',
#  'add a little butter',
#  'add dry bread_crumb',
#  'put some steak_sauce',
#  'add cabbage',
#  'use baby_carrot',
#  'add a packet of dry onion_soup',
#  'add worcestershire_sauce and corn',
#  'add worcestershire_sauce',
#  'add some diced sweet_potato',
#  'add the soup_mix',
#  'add celery',
#  'add a lil cream_of_mushroom_soup',
#  'add fresh mince garlic',
#  'put heinz chili_sauce',
#  'add garlic_powder to the seasoning',
#  'add cut celery',
#  'add more seasonings/ garlic_salt..maybe some chicken_broth',
#  'add mushroom',
#  'put a couple slice of butter',
#  'add green_bean and a1 sauce',
#  'add 2 tbl condense cream_of_mushroom_soup',
#  'use lipton onion_soup',
#  'add slice garlic',
#  'use small red_potato',
#  'add onion_soup mix to the ground_beef',
#  'put in blueberry',
#  'add about 1/2 cup applesauce',
#  'add more pumpkin chia_seed',
#  'put in raisin',
#  'add dried_cranberry',
#  'add dark_chocolate_chip',
#  'add molasses & walnut',
#  'use almond and poppy chia_seed',
#  'add cabbage',
#  'use up some leftover summer sausage',
#  'add some garlic with the onion',
#  'add some zucchini and fennel',
#  'use caribou summer sausage',
#  'add garlic',
#  'add some garlic',
#  'use up some summer sausage',
#  'add a little minced garlic',
#  'add a ton of hot_sauce',
#  'use up leave over summer sausage',
#  'use up the sausage and green_bell_pepper',
#  'use up some summer sausage',
#  'add a can of black_bean',
#  'add to the marinade',
#  'add about 2 tablespoon honey',
#  'use milk',
#  'use can peach',
#  'add honey',
#  'use water i use unsalted beef_broth',
#  'use this for beef',
#  'use 3 t. maple_syrup',
#  'use toothpick',
#  'put it in corn taco_shell',
#  'use garlic_salt instead_of regular salt',
#  'use it on tri-beef_tri_tip steak',
#  'use pecan and cherry',
#  'add a teaspoon of parsley',
#  'use bottom sirloin steak',
#  'put cayenne on ice_cream',
#  'put the meat in the water',
#  'add the vinaigrette',
#  'add a small onion',
#  'use tri-beef_tri_tip steak',
#  'add some thyme',
#  'use the sauce',
#  'add some of the basting sauce',
#  'add a little red_wine',
#  'use 1.5 time a much coconut',
#  'add scallop and mussel',
#  'add green curry_paste instead_of the red_bell_pepper',
#  'put over brown_rice',
#  'use water instead and the tomato',
#  'use the coconut_water',
#  'add rice',
#  'use clam_juice instead_of the fish_stock',
#  'use salmon',
#  'use catfish',
#  'use clam hot_sauce',
#  'add fresh blueberry',
#  'add some toast slivered almond',
#  'add walnut',
#  'use raisin',
#  'use half_and_half in place of whole_milk',
#  'use about 1/2 cup golden_raisin',
#  'add walnut and more ground_cinnamon',
#  'add about 1 tsp vanilla_extract',
#  'put them in foil cup cake',
#  'add dry onion_soup',
#  'add a little red_wine',
#  'put the beef_brisket & marinade',
#  'use low salt soy_sauce',
#  'add chop celery and slice onion',
#  'put some liquid_smoke',
#  'add some liquid_smoke',
#  'add barbeque_sauce thin with beer',
#  'add garlic and onion',
#  'use some garlic_salt',
#  'add 2 cup of merlot_wine',
#  'use liquid_smoke instead_of the barbeque_sauce',
#  'use kc masterpiece hickory brown_sugar',
#  'add barbeque_sauce and bay_leaf',
#  'use bulleyes barbeque with guiness beer',
#  'use the bourbon whiskey barbeque_sauce',
#  'use the bourbon whiskey barbeque_sauce',
#  'add more seasoning.. maybe even garlic_salt',
#  'use the bourbon whiskey barbeque_sauce',
#  'use the beef',
#  'use beer',
#  'use grass fed beef',
#  'add brown_sugar',
#  'add baby_carrot',
#  'add liquid_smoke',
#  'add smoke paprika',
#  'use 2 c water',
#  'add extra water',
#  'use a pinch of paprika',
#  'add finely chopped carrot',
#  'add raisin',
#  'add cilantro',
#  'add some diced dried_apricot',
#  'add some crunch from toasted almond',
#  'add some fresh mince garlic',
#  'add some zucchini',
#  'add the herb',
#  'add a layer of black_bean',
#  'add some slice baby bello mushroom',
#  'add basil',
#  'use panko bread_crumb',
#  'use panko bread_crumb',
#  'use heavy_cream',
#  'add a little granulated garlic',
#  'use a lipton soup_mix',
#  'use the lipton beefy onion_soup',
#  'use hamburger instead_of steak',
#  'use the lipton ground_beef & onion_soup',
#  'use some seasoning',
#  'put the chicken fry steak',
#  'use italian bread_crumb',
#  'add pepper',
#  'use some dry onion',
#  'use the suggestion for onion_soup',
#  'add 1 onion',
#  'add more seasoning',
#  'use dry parsley and grate carrot',
#  'put in a 2 mince garlic',
#  'add ketchup',
#  'use olive_oil',
#  'add 2 cup milk',
#  'add some garlic chili_powder',
#  'use 3/4 ground_turkey',
#  'use a mixture of gr sirloin',
#  'use itallian bread_crumb',
#  'use ground_turkey season with garlic chili_powder',
#  'add mince garlic',
#  'add a few tablespoon bread_crumb',
#  'use ground_turkey',
#  'use the onion_soup',
#  'put them back in the flour',
#  'add about 3-4 tablespoon of flour',
#  'use ground sirloin',
#  'add lawrys seasoned_salt',
#  'add the same seasoning',
#  'use italian bread_crumb',
#  'add montreal steak_seasoning',
#  'use italian bread_crumb',
#  'use bread_crumb',
#  'add some seasoning salt and pepper',
#  'use butter',
#  'add some onion_soup',
#  'use 1 tbsp cornstarch',
#  'use butter saltine_cracker',
#  'use ½ teaspoon kosher_salt',
#  'add a dash of garlic chili_powder',
#  'add chop fresh garlic',
#  'use some leftover chicken_stock',
#  'add several tablespoon of tomato_paste',
#  'add several tablespoon of paprika',
#  'add a wee bit of garlic',
#  'add dehydrated onion',
#  'use tomato_paste',
#  'add a little garlic chili_powder',
#  'put canned hot_dog tomato_sauce',
#  'add 1/2 tb garlic chili_powder',
#  'add a tablespoon of mustard',
#  'add 1 can tomato_paste',
#  'use a little condensed_tomato_soup',
#  'add some minced onion and garlic',
#  'add more seasoning',
#  'add about 3 tb of tomato_paste',
#  'add spaghetti tomato_sauce',
#  'add everything and even add garlic',
#  'use a a hot_dog tomato_sauce',
#  'add some granulated onion',
#  'add 1 tb onion chili_powder',
#  'put a little mustard',
#  'use regular chili on hot_dog',
#  'use on hot_dog',
#  'add cumin and onion chili_powder',
#  'put fritos and cheese',
#  'use lean turkey',
#  'add paprika',
#  'add some tomato_paste',
#  'put minced onion and green ground_black_pepper',
#  'add a tbsp each of garlic',
#  'put some melt cheese',
#  'add garlic chili_powder and onion chili_powder',
#  'add a can tomato_paste and onion',
#  'add a 1/4 teaspoon of garlic',
#  'use a potato',
#  'add chop onion',
#  'add some minced onion and garlic',
#  'add garlic',
#  'add a touch more white_sugar italian_seasoning',
#  'add paprika',
#  'use the thin cut steak',
#  'use flour',
#  'use a thin cut steak',
#  'use pre-sliced beef',
#  'use flour and an egg',
#  'use round_steak',
#  'use fresh tomato',
#  'use crush tomato',
#  'put it over rice',
#  'use up a beef_chuck steak',
#  'use 1 lb of beef',
#  'add green and yellow pepper',
#  'add one red and one green_bell_pepper',
#  'add fresh slice mushroom',
#  'add some dry minced onion',
#  'add chopped mushroom',
#  'add chicken',
#  'add about 1/4 teaspoon onion_salt',
#  'add some chopped mushroom',
#  'use water and beef_broth',
#  'add some mushroom and use onion_powder',
#  'use chicken or beef_broth',
#  'add a tiny bit of red_pepper_flake',
#  'use olive_oil',
#  'add some granulated garlic',
#  'use chicken_stock',
#  'add crush garlic and diced onion',
#  'use 1 cup of chicken_broth',
#  'use 2/3 reduced sodium chicken_broth',
#  'add seasoned chicken',
#  'add 2 clove chop garlic',
#  'add some lime_juice',
#  'add a bit of chicken_broth',
#  'add raisin and brown_sugar',
#  'use saltless organic chicken_broth',
#  'use coconut_oil',
#  'add veggie like carrot',
#  'add different seasoning',
#  'add some green_onion',
#  'use chicken_stock in place of brown_rice',
#  'add mushroom',
#  'use half chicken_broth',
#  'use kosher_salt',
#  'use chicken_broth',
#  'add a 1/2 teaspoon of worcestershire_sauce',
#  ...]
